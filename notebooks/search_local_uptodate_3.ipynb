# %%
import os
import shutil  # For deleting directories
import json
import pandas as pd
from whoosh import index
from whoosh.index import create_in, open_dir
from whoosh.fields import Schema, TEXT, ID
from whoosh.qparser import QueryParser
from nltk.tokenize import word_tokenize
import nltk
import tqdm
import logging
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/vince/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Data directory and Excel file
data_dir = '/Users/vince/Salk/PaperGeneration/data'
csv_file = "/Users/vince/Salk/PaperGeneration/notebooks/condition_revised.csv"
base_dir = "/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents"
output_file = "search_results_revised.json"

# %%
# Whoosh index directory (change this if needed)
index_dir = "uptodate_index"

from whoosh.fields import Schema, TEXT, ID, STORED, KEYWORD

# Define a sophisticated schema
schema = Schema(
    path=ID(unique=True, stored=True),           # Unique path for each chunk
    title=TEXT(stored=True),                    # Title of the chunk
    topic=TEXT(stored=True),                    # Topic from metadata
    subtopic=TEXT(stored=True),                 # Subtopic from metadata
    content=TEXT(stored=True),                               # Main text content of the chunk
    references=STORED,                          # Store references as raw data
    keywords=KEYWORD(commas=True, stored=True)  # Optional: Keywords for advanced filtering
)
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
logger = logging.getLogger(__name__)


def setup_index(index_dir, schema):
    """
    Creates a new index or clears the existing one.
    """
    if os.path.exists(index_dir):
        logger.info(f"Clearing existing index directory: {index_dir}")
        shutil.rmtree(index_dir)
    os.mkdir(index_dir)
    ix = index.create_in(index_dir, schema)
    logger.info(f"Created new index in directory: {index_dir}")
    return ix

ix = setup_index(index_dir, schema)
# Out:
# INFO: Clearing existing index directory: uptodate_index
# INFO: Created new index in directory: uptodate_index

# %%
import tqdm
import markdown
from bs4 import BeautifulSoup

# Function to extract plain text from Markdown
def extract_text_from_markdown(markdown_content):
    html = markdown.markdown(markdown_content)
    soup = BeautifulSoup(html, 'html.parser')
    return soup.get_text()

def index_json_chunks(base_dir, ix):
    """
    Indexes all JSON chunk files in the specified base directory.
    Each file is expected to be an array of chunk objects, each having a
    'content', 'references', and 'metadata' fields.
    """
    json_files = [
        os.path.join(root, file)
        for root, _, files in os.walk(base_dir)
        for file in files
        if file.lower().endswith(".json")
    ]
    
    total_files = len(json_files)
    logger.info(f"Total JSON files to index: {total_files}")

    if total_files == 0:
        logger.warning("No JSON files found to index.")
        return

    pbar = tqdm.tqdm(total=total_files, desc="Indexing JSON Files", unit="file")

    try:
        with ix.writer() as writer:
            for file_path in json_files:
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        # Each JSON file is an array of chunks
                        chunks = json.load(f)

                    # Index each chunk individually
                    for i, chunk in enumerate(chunks):
                        raw_content = chunk.get("content", "")
                        content_text = extract_text_from_markdown(raw_content)
                        metadata = chunk.get("metadata", {})
                        
                        # Extract metadata fields
                        title = metadata.get("title", "")
                        topic = metadata.get("topic", "")
                        subtopic = metadata.get("subtopic", "")
                        references = chunk.get("references", [])

                        # Optional: Generate keywords from content or metadata
                        keywords = ','.join([topic, subtopic])

                        # Unique path for each chunk
                        unique_path = f"{file_path}::chunk{i}"

                        writer.update_document(
                            path=unique_path,
                            title=title,
                            topic=topic,
                            subtopic=subtopic,
                            content=content_text,
                            references=json.dumps(references),  # Store as JSON string
                            keywords=keywords
                        )
                except Exception as e:
                    logger.error(f"Error indexing {file_path}: {e}")
                finally:
                    pbar.update(1)
    except Exception as e:
        logger.critical(f"Failed to write to index: {e}")
    finally:
        pbar.close()
        logger.info("Indexing complete.")


# Run the indexing
index_json_chunks(base_dir, ix)
# Out:
# INFO: Total JSON files to index: 42029
# Indexing JSON Files: 100%|██████████| 42029/42029 [27:31<00:00, 25.45file/s]
# INFO: Indexing complete.

# %%
print("test")
# Out:
# test

# %%
# 4. Search Function
def search_index(query, ix, top_n=100):
    with ix.searcher() as searcher:
        parser = QueryParser("content", ix.schema)
        q = parser.parse(query)
        results = searcher.search(q, limit=top_n)
        return [{"path": r["path"], "score": r.score} for r in results]


results = search_index("PTSD", ix)
results
# Out:
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk17',
#   'score': 16.644248087873407},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk15',
#   'score': 16.58394078208086},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk4',
#   'score': 16.51485215493983},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk24',
#   'score': 16.141032927018177},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk15',
#   'score': 16.071205941602102},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk24',
#   'score': 15.963948934214965},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk25',
#   'score': 15.937597223977422},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk8',
#   'score': 15.904342528062218},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk16',
#   'score': 15.880674012046851},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk9',
#   'score': 15.875359048216744},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk0',
#   'score': 15.869487751787332},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk0',
#   'score': 15.869487751787332},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk6',
#   'score': 15.863230001348784},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/bipolar-disorders/bipolar-disorder-in-adults-clinical-features.json::chunk24',
#   'score': 15.86010216291595},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk7',
#   'score': 15.856456564430237},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk27',
#   'score': 15.78387523819878},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk22',
#   'score': 15.781663941615996},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk10',
#   'score': 15.781663941615996},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk10',
#   'score': 15.781663941615996},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk2',
#   'score': 15.731271704758305},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk21',
#   'score': 15.679513284558038},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk14',
#   'score': 15.647278216272957},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk35',
#   'score': 15.640687904175628},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk7',
#   'score': 15.60349417437554},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk8',
#   'score': 15.580615988489214},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk13',
#   'score': 15.576229532382824},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk2',
#   'score': 15.545829660807705},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/hiv-infection/overview-of-the-neuropsychiatric-aspects-of-hiv-infection-and-aids.json::chunk8',
#   'score': 15.51751235725928},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/mental-and-medical-disorders/overview-of-the-neuropsychiatric-aspects-of-hiv-infection-and-aids.json::chunk8',
#   'score': 15.51751235725928},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/infectious-diseases/hiv-infection/overview-of-the-neuropsychiatric-aspects-of-hiv-infection-and-aids.json::chunk8',
#   'score': 15.51751235725928},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk9',
#   'score': 15.499848859422686},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk3',
#   'score': 15.485779871381158},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk1',
#   'score': 15.434165044161327},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk9',
#   'score': 15.404861438902909},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk9',
#   'score': 15.404861438902909},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/general-medicine/medical-care-of-the-military-veteran.json::chunk8',
#   'score': 15.391353551344986},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/general-medicine/risk-factors-comorbidities-and-consequences-of-insomnia-in-adults.json::chunk9',
#   'score': 15.391353551344986},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk0',
#   'score': 15.383997435240843},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/depressive-disorders/bereavement-and-grief-in-adults-clinical-features.json::chunk28',
#   'score': 15.327825040381784},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk9',
#   'score': 15.31445185645982},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/depressive-disorders/prolonged-grief-disorder-in-adults-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk38',
#   'score': 15.304338286140611},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk7',
#   'score': 15.252759863626881},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/general-medicine/medical-care-of-the-military-veteran.json::chunk7',
#   'score': 15.252759863626881},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk11',
#   'score': 15.252759863626881},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk11',
#   'score': 15.252759863626881},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk12',
#   'score': 15.252758024355261},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/complementary-medicine/medical-use-of-cannabis-and-cannabinoids-in-adults.json::chunk18',
#   'score': 15.238314807694342},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk36',
#   'score': 15.219785101407675},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk17',
#   'score': 15.174306100316175},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/treatment-of-co-occurring-anxiety-related-disorders-and-substance-use-disorders-in-adults.json::chunk17',
#   'score': 15.174306100316175},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk0',
#   'score': 15.154007425004277},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk0',
#   'score': 15.133901743240642},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk10',
#   'score': 15.129429355116354},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk3',
#   'score': 15.09279351417032},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk3',
#   'score': 15.09279351417032},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk11',
#   'score': 15.082633775040499},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk26',
#   'score': 15.030507428236739},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk19',
#   'score': 14.989903048207669},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk23',
#   'score': 14.98118185527729},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk9',
#   'score': 14.961256095092025},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk27',
#   'score': 14.961256095092025},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-treatment.json::chunk12',
#   'score': 14.961256095092025},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk26',
#   'score': 14.961256095092025},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-treatment.json::chunk18',
#   'score': 14.922714413138914},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk17',
#   'score': 14.922714413138914},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk12',
#   'score': 14.916951160860354},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk27',
#   'score': 14.896238945119027},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk26',
#   'score': 14.875201361439979},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk19',
#   'score': 14.858412284442341},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-trauma-focused-psychotherapy.json::chunk16',
#   'score': 14.820779417610181},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk18',
#   'score': 14.800333227225565},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk10',
#   'score': 14.783336699592907},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/mental-and-medical-disorders/pregnancy-termination-and-potential-psychiatric-outcomes.json::chunk10',
#   'score': 14.77956547315116},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/gynecologic-surgery/pregnancy-termination-and-potential-psychiatric-outcomes.json::chunk10',
#   'score': 14.77956547315116},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/general-surgery/gynecologic-surgery/pregnancy-termination-and-potential-psychiatric-outcomes.json::chunk10',
#   'score': 14.77956547315116},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk27',
#   'score': 14.779263167414266},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk12',
#   'score': 14.7726735039195},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-treatment.json::chunk15',
#   'score': 14.7726735039195},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk0',
#   'score': 14.7726735039195},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk11',
#   'score': 14.749460487632534},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/mental-and-medical-disorders/psychiatric-aspects-of-organ-transplantation.json::chunk5',
#   'score': 14.749460487632534},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk9',
#   'score': 14.688874648805907},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk5',
#   'score': 14.66878840760038},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-treatment-overview.json::chunk1',
#   'score': 14.66878840760038},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk4',
#   'score': 14.66878840760038},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk4',
#   'score': 14.66878840760038},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk16',
#   'score': 14.59561211404794},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk5',
#   'score': 14.585217914589613},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk7',
#   'score': 14.585217914589613},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/acute-stress-disorder-in-adults-treatment.json::chunk17',
#   'score': 14.519885251615609},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-epidemiology-clinical-features-assessment-and-diagnosis.json::chunk14',
#   'score': 14.519885251615609},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk14',
#   'score': 14.470919007372013},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-epidemiology-pathophysiology-clinical-features-assessment-and-diagnosis.json::chunk20',
#   'score': 14.470919007372013},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/primary-care-psychiatry/posttraumatic-stress-disorder-in-adults-psychotherapy-and-psychosocial-interventions.json::chunk26',
#   'score': 14.41743803182759},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk7',
#   'score': 14.397550909955845},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/anxiety-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk10',
#   'score': 14.389581061561893},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/substance-use-disorders/co-occurring-substance-use-disorder-and-anxiety-related-disorders-in-adults-epidemiology-pathogenesis-clinical-manifestations-course-assessment-and-diagnosis.json::chunk10',
#   'score': 14.389581061561893},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk4',
#   'score': 14.373970671150756},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/depressive-disorders/bereavement-and-grief-in-adults-clinical-features.json::chunk45',
#   'score': 14.357940804751152},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/family-medicine-and-general-practice/child-and-adolescent-mental-disorders/posttraumatic-stress-disorder-in-children-and-adolescents-treatment-overview.json::chunk10',
#   'score': 14.357940804751152}]

# %%
from whoosh.qparser import MultifieldParser

# Open the index
ix = index.open_dir(index_dir)

# Create a parser for multiple fields
parser = MultifieldParser(["content", "title", "topic", "subtopic"], schema=ix.schema)

with ix.searcher() as searcher:
    query = parser.parse("immunotherapy")
    results = searcher.search(query, limit=10)
    
    for result in results:
        print(f"Score: {result.score:.2f}")
        # print(f"Score: {result['score']}")
        print(f"Path: {result['path']}")
        print(f"Title: {result['title']}")
        print(f"Topic: {result['topic']}")
        print(f"Subtopic: {result['subtopic']}")
        print(f"References: {result['references']}")
        # print(f"Snippet: {result.highlights('content')}")
        print(f"Content: {result['content']}")
        print("-" * 40)
# Out:
# Score: 29.07
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/sublingual-immunotherapy-beyond-the-basics.json::chunk6
# Title: Patient education: Sublingual immunotherapy (Beyond the Basics)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: FREQUENTLY ASKED QUESTIONS
# What are the other ways to treat my allergies?
# Other types of immunotherapy
# Subcutaneous immunotherapy (SCIT) is a long-established, traditional form of allergen immunotherapy. In SCIT, a mixture of the allergens to which you are allergic is prepared, and injections of the extract are gradually increased (over 16 to 20 weeks) as tolerated to a maintenance regimen that is then administered at your physician's office every two to four weeks over three to five years. In contrast to SLIT-tablets, another form of allergen immunotherapy is that of sublingual drops (SLIT-drops). This method involves putting drops of a solution containing a mixture of allergens under the tongue. This approach is used in various parts of the world. However, it is not US Food and Drug Administration (FDA) approved in the United States, although it can be given "off label" (meaning that a physician can prescribe it for a condition for which it has not been officially approved). Most studies have shown that it is less effective than injection immunotherapy or SLIT tablets.
# ----------------------------------------
# Score: 29.02
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/sublingual-immunotherapy-beyond-the-basics.json::chunk3
# Title: Patient education: Sublingual immunotherapy (Beyond the Basics)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: FREQUENTLY ASKED QUESTIONS
# What are the other ways to treat my allergies?
# The other ways to treat allergies are avoidance, medications, injection immunotherapy, and immunotherapy using a sublingual liquid (drops).
# ----------------------------------------
# Score: 29.01
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/allergen-immunotherapy-for-allergic-disease-therapeutic-mechanisms.json::chunk0
# Title: Allergen immunotherapy for allergic disease: Therapeutic mechanisms
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: INTRODUCTION
# Allergen immunotherapy (AIT) is the only disease-modifying treatment available for several common allergic diseases. Subcutaneous immunotherapy (SCIT) is the best studied form of AIT and is effective for allergic rhinitis and rhinoconjunctivitis, allergic asthma, and Hymenoptera venom allergy. SCIT involves the repeated subcutaneous injection of increasing amounts of allergen beginning with very small doses of allergen and gradually increasing to higher doses. Another popular method of AIT involves sublingual administration in the form of dissolvable tablets or extracts. This topic will discuss the known immunologic changes that occur during AIT. Other topics related to AIT are found separately:
# ●(See "Subcutaneous immunotherapy (SCIT) for allergic rhinoconjunctivitis and asthma: Indications and efficacy".)
# ●(See "Sublingual immunotherapy for allergic rhinitis and conjunctivitis: SLIT-tablets".)
# ●(See "SCIT: Standard schedules, administration techniques, adverse reactions, and monitoring".)
# ●(See "SCIT: Preparation of allergen extracts for therapeutic use".)
# ●(See "Hymenoptera venom immunotherapy: Efficacy, indications, and mechanism of action".)
# ----------------------------------------
# Score: 28.96
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/subcutaneous-aeroallergen-immunotherapy-accelerated-schedules-cluster-and-rush.json::chunk3
# Title: Subcutaneous aeroallergen immunotherapy: Accelerated schedules (cluster and rush)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: TERMINOLOGY
# Rush schedules
# Rush schedules involve administering injections of increasing dose at 15- to 60-minute intervals over one to three consecutive days until a target dose (usually slightly less than the maintenance dose) is achieved. The remainder of the build-up phase proceeds using a traditional schedule until maintenance is achieved, usually in less than eight weeks.
# Ultra-rush immunotherapy is an even more rapid dosing schedule for immunotherapy, in which an effective maintenance dose is reached within one day. Ultra-rush is usually applied to Hymenoptera venom immunotherapy. Accelerated forms of venom immunotherapy are reviewed separately. (See "Rush and ultra-rush venom immunotherapy for Hymenoptera allergy".)
# ----------------------------------------
# Score: 28.92
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/sublingual-immunotherapy-beyond-the-basics.json::chunk7
# Title: Patient education: Sublingual immunotherapy (Beyond the Basics)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: FREQUENTLY ASKED QUESTIONS
# What is the goal of immunotherapy?
# Allergen immunotherapy (of any type) changes how your immune system reacts to the allergen in question, essentially teaching your immune system to ignore it. Many people are able to achieve long-lasting control of their symptoms with a course of treatment (usually four to five years). In addition, allergen immunotherapy initiated for nasal or eye allergies may prevent the development of allergic asthma, as well as prevent the onset of new allergies to other airborne allergens.
# ----------------------------------------
# Score: 28.79
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/allergen-immunotherapy-for-allergic-disease-therapeutic-mechanisms.json::chunk12
# Title: Allergen immunotherapy for allergic disease: Therapeutic mechanisms
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: ["[5] Creticos PS. Immunotherapy with allergens. JAMA 1992; 268:2834.", "[14] Creticos PS, Van Metre TE, Mardiney MR, et al. Dose response of IgE and IgG antibodies during ragweed immunotherapy. J Allergy Clin Immunol 1984; 73:94.", "[16] Jutel M, Agache I, Bonini S, et al. International Consensus on Allergen Immunotherapy II: Mechanisms, standardization, and pharmacoeconomics. J Allergy Clin Immunol 2016; 137:358."]
# Content: IMMUNOLOGIC CHANGES WITH SCIT
# Changes in allergen-specific antibodies
# IgG
# Allergen-specific serum IgG antibodies are often present at low levels in allergic patients. Immunotherapy generally results in an increase in allergen-specific IgG antibodies, which lags behind the rise in IgE antibodies by weeks to a few months. Levels may continue to rise over many months of maintenance immunotherapy, and elevated levels may persist for many years after immunotherapy is discontinued [14].
# Studies demonstrate that high levels of allergen-specific IgG as a result of SCIT correlate with the dose of allergen that has been administered but not necessarily with clinical relief of symptoms [16]. However, the failure to produce allergen-specific IgG in an individual patient receiving immunotherapy does correlate with a lack of clinical response [5].
# Although practices differ around the world, in North America, allergen-specific IgG is used mostly as a research tool and is not routinely measured by most clinicians in the clinical practice setting, based on practice guidelines. In contrast, the author measures allergen-specific IgG prior to administration of AIT in patients who have undergone AIT in the past and finds this information can be used clinically to assess the efficacy of a patient's previous immunotherapy. For example, if the patient reports that a previous course of immunotherapy did not seem to help, the finding of low allergen-specific IgG levels to the allergen given essentially confirms that the therapy was not effective.
# ----------------------------------------
# Score: 28.61
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/subcutaneous-immunotherapy-scit-for-allergic-rhinoconjunctivitis-and-asthma-indications-and-efficacy.json::chunk0
# Title: Subcutaneous immunotherapy (SCIT) for allergic rhinoconjunctivitis and asthma: Indications and efficacy
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: INTRODUCTION
# Immunotherapy for allergic disease (AIT) involves the administration of allergen to which the patient is sensitive, for the purpose of modulating the untoward immune response to that allergen and alleviating allergic symptoms. AIT represents the only therapy capable of inducing a state of immune tolerance and, through its inherent disease-modifying properties, provides the potential to affect a sustained clinical benefit with long-lasting clinical remission of the allergic condition. In addition, it offers the possibility of preventing the development of new allergen sensitivities in the allergic patient, inhibiting the progression of allergic rhinitis to asthma, and improving a patient's quality of life and medication requirements.
# Subcutaneous immunotherapy (SCIT) is the best-established form of this treatment. The indications and efficacy for SCIT with aeroallergens (ie, inhaled allergens, such as pollens, dust mites, animal danders, etc) will be reviewed here. SCIT with other allergens, such as venoms or food allergens, is reviewed separately. Oral and sublingual forms of immunotherapy, rush immunotherapy, mechanisms of action, and the preparation of allergen extracts are also discussed elsewhere.
# ●(See "Hymenoptera venom immunotherapy: Efficacy, indications, and mechanism of action".)
# ●(See "Food allergy management: Allergen-nonspecific therapies".)
# ●(See "Sublingual immunotherapy for allergic rhinitis and conjunctivitis: SLIT-tablets".)
# ●(See "Allergen immunotherapy for allergic disease: Therapeutic mechanisms".)
# ●(See "SCIT: Preparation of allergen extracts for therapeutic use".)
# ●(See "SCIT: Standard schedules, administration techniques, adverse reactions, and monitoring".)
# ●(See "Subcutaneous aeroallergen immunotherapy: Accelerated schedules (cluster and rush)".)
# ●(See "Anaphylaxis induced by subcutaneous allergen immunotherapy".)
# ----------------------------------------
# Score: 28.58
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/subcutaneous-aeroallergen-immunotherapy-accelerated-schedules-cluster-and-rush.json::chunk41
# Title: Subcutaneous aeroallergen immunotherapy: Accelerated schedules (cluster and rush)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: []
# Content: SUMMARY AND RECOMMENDATIONS
# ●Preparation of extracts – Allergen extracts for use in accelerated immunotherapy are prepared similarly to those used in conventional immunotherapy, although the number of different solutions needed should be minimized. (See 'Allergen extract preparation' above.)
# ●Example protocols:
# •Cluster – Different protocols for cluster immunotherapy have been published, and a representative schedule is shown (table 2). However, studies evaluating the tolerability of cluster immunotherapy with multiple aeroallergens are lacking. (See 'Cluster schedules' above.)
# •Rush – Various protocols for RIT also exist. One protocol has been studied for use with multiple aeroallergens and is relatively well characterized (table 3). The authors use a similar approach in their clinic (table 4). (See 'Rush schedules' above.)
# ●Adjusting after a systemic reaction – We suggest that patients who develop systemic allergic reactions during accelerated immunotherapy be converted to a conventional schedule (Grade 2C). (See 'Adjusting the protocol for adverse reactions' above.)
# ----------------------------------------
# Score: 28.49
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/subcutaneous-immunotherapy-scit-for-allergic-rhinoconjunctivitis-and-asthma-indications-and-efficacy.json::chunk32
# Title: Subcutaneous immunotherapy (SCIT) for allergic rhinoconjunctivitis and asthma: Indications and efficacy
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: ["[8] Cox L, Nelson H, Lockey R, et al. Allergen immunotherapy: a practice parameter third update. J Allergy Clin Immunol 2011; 127:S1.", "[77] Pitsios C, Demoly P, Bil\u00f2 MB, et al. Clinical contraindications to allergen immunotherapy: an EAACI position paper. Allergy 2015; 70:897."]
# Content: SPECIAL PATIENT GROUPS
# Beta-blocker and ACE-inhibitor therapy
# Patients on chronic beta-blocker treatment for cardiovascular disease are at some risk for a poor outcome if they have an anaphylactic reaction to an immunotherapy injection, since they may not respond properly to epinephrine or other vasopressor agents used to treat the reaction. Patients receiving angiotensin-converting enzyme (ACE) inhibitors are theoretically at increased risk during anaphylaxis, possibly due to the inhibition of conversion of angiotensin I to angiotensin II, resulting in poorer response to hemodynamic stress during hypotension or to accumulated bradykinin, a potent vasodilator. The data behind these conclusions are presented elsewhere. (See "Anaphylaxis induced by subcutaneous allergen immunotherapy", section on 'Beta-adrenergic blockers' and "Anaphylaxis induced by subcutaneous allergen immunotherapy", section on 'ACE inhibitors'.)
# As with any therapeutic decision, the risk must be weighed against the benefit [8]. Most clinicians avoid administering SCIT to patients on significant doses of beta-blockers. In some cases, hypertension or other cardiovascular disorders can be treated with medications that do not carry these risks. A European guideline considers beta-blocker use to be relatively contraindicated in aeroallergen SCIT, although not with venom immunotherapy in patients with clear indications for both interventions, since venom immunotherapy is considered potentially lifesaving [77]. Unlike immunotherapy for venom allergy, immunotherapy for allergic rhinitis or asthma is generally considered elective. The use of beta-blockers and ACE inhibitors in patients receiving venom immunotherapy is discussed in more detail elsewhere. (See "Hymenoptera venom immunotherapy: Efficacy, indications, and mechanism of action", section on 'Patients requiring ACE inhibitors or beta blockers'.)
# ----------------------------------------
# Score: 28.43
# Path: /Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/allergen-immunotherapy/subcutaneous-aeroallergen-immunotherapy-accelerated-schedules-cluster-and-rush.json::chunk7
# Title: Subcutaneous aeroallergen immunotherapy: Accelerated schedules (cluster and rush)
# Topic: Allergy and immunology
# Subtopic: Allergen immunotherapy
# References: ["[6] Tabar AI, Echechip\u00eda S, Garc\u00eda BE, et al. Double-blind comparative study of cluster and conventional immunotherapy schedules with Dermatophagoides pteronyssinus. J Allergy Clin Immunol 2005; 116:109.", "[7] Zhang L, Wang C, Han D, et al. Comparative study of cluster and conventional immunotherapy schedules with dermatophagoides pteronyssinus in the treatment of persistent allergic rhinitis. Int Arch Allergy Immunol 2009; 148:161.", "[8] Horst M, Hejjaoui A, Horst V, et al. Double-blind, placebo-controlled rush immunotherapy with a standardized Alternaria extract. J Allergy Clin Immunol 1990; 85:460.", "[9] Kohno Y, Minoguchi K, Oda N, et al. Effect of rush immunotherapy on airway inflammation and airway hyperresponsiveness after bronchoprovocation with allergen in asthma. J Allergy Clin Immunol 1998; 102:927."]
# Content: INDICATIONS
# The indications for SCIT (of any type) are reviewed in detail separately. (See "Subcutaneous immunotherapy (SCIT) for allergic rhinoconjunctivitis and asthma: Indications and efficacy", section on 'Indications'.)
# The indications for accelerated SCIT specifically are:
# ●A desire by the patient to increase convenience of the immunotherapy process
# ●A desire by the patient to experience clinical benefit sooner than would be possible with a conventional schedule
# Multiple studies have demonstrated that clinically significant reduction in allergic symptoms is apparent shortly after reaching maintenance in patients receiving accelerated immunotherapy [6-9].
# ----------------------------------------

# %%
import json
import pandas as pd
from whoosh.qparser import MultifieldParser

# Open the index
ix = index.open_dir(index_dir)

def search_index(query, ix, top_n=500):
    """
    Search the index for a given query.
    """
    with ix.searcher() as searcher:
        parser = MultifieldParser(["content", "title", "topic", "subtopic"], schema=ix.schema)
        q = parser.parse(query)
        results = searcher.search(q, limit=top_n)
        
        # Collect results
        result_list = []
        for result in results:
            result_list.append({
                "path": result["path"],
                "title": result["title"],
                "topic": result["topic"],
                "subtopic": result["subtopic"],
                "score": result.score,
                "content": result["content"],
                "references": result["references"]
            })
        return result_list

def remove_duplicates(results):
    """
    Remove duplicate results based on the 'content' field.
    """
    seen = set()
    unique_results = []
    for result in results:
        content_hash = hash(result["content"])  # Hashing content for faster comparison
        if content_hash not in seen:
            unique_results.append(result)
            seen.add(content_hash)
    return unique_results

# Process queries and save results
df = pd.read_csv(csv_file)
df = df[['Condition', 'Alternative Name', 'Category']].fillna("")

results_list = []
for i, row in df.iterrows():
    query = row['Condition']
    query_alt = row['Alternative Name']
    print(f"[{i+1}] Processing Query: {query}")
    
    # Main query
    results = search_index(query, ix)
    a = len(results)
    results = remove_duplicates(results)
    if len(results) < a: 
        print(f"Removed duplicates: {a - len(results)}")
    results = results[:100]
    formatted_results = {
        "query": query,
        "results": [{"path": r["path"], "title": r["title"], "topic": r["topic"], 
                     "subtopic": r["subtopic"], "score": r["score"], 
                     "content": r["content"], "references": r["references"]} for r in results]
    }
    results_list.append(formatted_results)
    
    # Alternative query
    if query_alt:
        print(f"Processing Alternative Query: {query_alt}")
        results = search_index(query_alt, ix)
        results = remove_duplicates(results)
        formatted_results = {
            "query": query_alt,
            "results": [{"path": r["path"], "title": r["title"], "topic": r["topic"], 
                         "subtopic": r["subtopic"], "score": r["score"], 
                         "content": r["content"], "references": r["references"]} for r in results]
        }
        results_list.append(formatted_results)

# Save results to JSON
with open(output_file, "w") as json_file:
    json.dump(results_list, json_file, indent=4)
print(f"Results saved to {output_file}")
# Out:
# [1] Processing Query: Food Allergy
# [2] Processing Query: Allergic Rhinitis
# Removed duplicates: 14
# Processing Alternative Query: Hay Fever
# [3] Processing Query: Drug Allergies
# Removed duplicates: 47
# [4] Processing Query: Atopic Dermatitis
# Removed duplicates: 48
# Processing Alternative Query: Eczema
# [5] Processing Query: Contact Dermatitis
# Removed duplicates: 52
# [6] Processing Query: Ankylosing Spondylitis
# Removed duplicates: 43
# [7] Processing Query: Gout
# Removed duplicates: 58
# [8] Processing Query: Guillain-Barre Syndrome
# Removed duplicates: 18
# [9] Processing Query: Multiple Sclerosis
# Removed duplicates: 38
# Processing Alternative Query: MS
# [10] Processing Query: Osteoarthritis
# Removed duplicates: 52
# [11] Processing Query: Rheumatoid Arthritis
# Removed duplicates: 25
# [12] Processing Query: Sarcoidosis
# Removed duplicates: 50
# [13] Processing Query: Scleroderma
# Removed duplicates: 80
# [14] Processing Query: Systemic Lupus Erythematosus
# Removed duplicates: 52
# Processing Alternative Query: SLE
# [15] Processing Query: Vasculitis
# Removed duplicates: 66
# [16] Processing Query: Ant Bites
# Removed duplicates: 2
# [17] Processing Query: Bedbug Bites
# Removed duplicates: 36
# [18] Processing Query: Flea Bites
# Removed duplicates: 32
# [19] Processing Query: Horsefly Bites
# [20] Processing Query: Mosquito Bites
# Removed duplicates: 51
# [21] Processing Query: Spider Bites
# Removed duplicates: 72
# [22] Processing Query: Tick Bites
# Removed duplicates: 66
# [23] Processing Query: Anemia
# Removed duplicates: 40
# [24] Processing Query: Hemophilia
# Removed duplicates: 73
# [25] Processing Query: Thrombocytopenia
# Removed duplicates: 53
# Processing Alternative Query: Low Platelet Count
# [26] Processing Query: Polycythemia Vera
# Removed duplicates: 69
# [27] Processing Query: Osteoporosis
# Removed duplicates: 68
# [28] Processing Query: Osteomalacia
# Removed duplicates: 38
# Processing Alternative Query: Soft Bone Disease
# [29] Processing Query: Osteogenesis Imperfecta
# Removed duplicates: 40
# Processing Alternative Query: Brittle Bone Disease
# [30] Processing Query: Paget's Disease of Bone
# Removed duplicates: 47
# Processing Alternative Query: Osteitis Deformans
# [31] Processing Query: Bone Fractures
# Removed duplicates: 25
# [32] Processing Query: Basal Cell Carcinoma
# Removed duplicates: 79
# [33] Processing Query: Breast Cancer
# [34] Processing Query: Cervical Cancer
# Removed duplicates: 45
# [35] Processing Query: Colorectal Cancer
# Removed duplicates: 9
# [36] Processing Query: Liver Cancer
# Removed duplicates: 11
# [37] Processing Query: Lung Cancer
# Removed duplicates: 55
# [38] Processing Query: Melanoma
# Removed duplicates: 65
# [39] Processing Query: Ovarian Cancer
# Removed duplicates: 65
# [40] Processing Query: Prostate Cancer
# Removed duplicates: 67
# [41] Processing Query: Squamous Cell Carcinoma
# Removed duplicates: 59
# [42] Processing Query: Leukemia
# Processing Alternative Query: Blood Cancer
# [43] Processing Query: Cardiac Arrhythmia
# Removed duplicates: 16
# [44] Processing Query: Coronary Artery Disease
# Removed duplicates: 28
# [45] Processing Query: Heart Failure
# Removed duplicates: 1
# [46] Processing Query: Hypertension
# Removed duplicates: 50
# Processing Alternative Query: High Blood Pressure
# [47] Processing Query: Chronic Fatigue Syndrome
# Removed duplicates: 72
# [48] Processing Query: Fibromyalgia
# Removed duplicates: 32
# [49] Processing Query: Post-COVID Syndrome
# Removed duplicates: 43
# Processing Alternative Query: Long COVID
# [50] Processing Query: Anal Fissures
# Removed duplicates: 63
# [51] Processing Query: Appendicitis
# Removed duplicates: 74
# [52] Processing Query: Barrett's Esophagus
# Removed duplicates: 38
# [53] Processing Query: Celiac Disease
# Removed duplicates: 48
# [54] Processing Query: Cholecystitis
# Removed duplicates: 67
# [55] Processing Query: Colitis
# Removed duplicates: 57
# [56] Processing Query: Constipation
# Removed duplicates: 63
# [57] Processing Query: Crohn's Disease
# Removed duplicates: 29
# Processing Alternative Query: Intestinal Inflammation
# [58] Processing Query: Diarrhea
# Removed duplicates: 68
# [59] Processing Query: Diverticulitis
# Removed duplicates: 75
# [60] Processing Query: Esophagitis
# Removed duplicates: 54
# [61] Processing Query: Functional Dyspepsia
# Removed duplicates: 66
# [62] Processing Query: Gallbladder Disease
# Removed duplicates: 15
# [63] Processing Query: Gastritis
# Removed duplicates: 36
# [64] Processing Query: Gastroenteritis
# Removed duplicates: 75
# Processing Alternative Query: Stomach Flu
# [65] Processing Query: Gastroesophageal Reflux Disease
# Removed duplicates: 55
# Processing Alternative Query: GERD
# [66] Processing Query: Gastroparesis
# Removed duplicates: 53
# [67] Processing Query: Hemorrhoids
# Removed duplicates: 68
# Processing Alternative Query: Piles
# [68] Processing Query: Inflammatory Bowel Disease
# Processing Alternative Query: IBD
# [69] Processing Query: Irritable Bowel Syndrome
# Removed duplicates: 58
# Processing Alternative Query: IBS
# [70] Processing Query: Lactose Intolerance
# Removed duplicates: 73
# [71] Processing Query: Pancreatitis
# Removed duplicates: 84
# [72] Processing Query: Peptic Ulcer Disease
# Removed duplicates: 17
# Processing Alternative Query: PUD
# [73] Processing Query: Small Intestinal Bacterial Overgrowth
# Removed duplicates: 26
# Processing Alternative Query: SIBO
# [74] Processing Query: Zollinger-Ellison Syndrome
# Removed duplicates: 86
# [75] Processing Query: Otitis Externa
# Removed duplicates: 48
# Processing Alternative Query: Swimmer's Ear
# [76] Processing Query: Tonsillitis
# Removed duplicates: 60
# [77] Processing Query: Eustachian Tube Dysfunction
# Removed duplicates: 26
# Processing Alternative Query: Eustachian Tube Disorder
# [78] Processing Query: Laryngitis
# Removed duplicates: 58
# [79] Processing Query: Tympanic Membrane (Eardrum) Perforation
# Removed duplicates: 1
# [80] Processing Query: Eustachian Tube Dysfunction
# Removed duplicates: 26
# Processing Alternative Query: ETD
# [81] Processing Query: Hashimoto's Thyroiditis
# Removed duplicates: 66
# Processing Alternative Query: Autoimmune Thyroiditis
# [82] Processing Query: Hyperthyroidism
# Removed duplicates: 81
# [83] Processing Query: Hypothyroidism
# Removed duplicates: 57
# [84] Processing Query: Type 1 Diabetes
# [85] Processing Query: Type 2 Diabetes
# [86] Processing Query: Age-related Macular Degeneration
# Removed duplicates: 61
# Processing Alternative Query: AMD
# [87] Processing Query: Amblyopia
# Removed duplicates: 22
# [88] Processing Query: Astigmatism
# Removed duplicates: 34
# [89] Processing Query: Blepharitis
# Removed duplicates: 48
# [90] Processing Query: Cataracts
# Removed duplicates: 47
# [91] Processing Query: Conjunctivitis
# Removed duplicates: 83
# [92] Processing Query: Corneal Abrasion
# Removed duplicates: 62
# [93] Processing Query: Diabetic Retinopathy
# Removed duplicates: 58
# [94] Processing Query: Dry Eye Syndrome
# Removed duplicates: 32
# Processing Alternative Query: Dry Eye
# [95] Processing Query: Eye Floaters
# Removed duplicates: 38
# [96] Processing Query: Glaucoma
# Removed duplicates: 39
# [97] Processing Query: Hyperopia
# Removed duplicates: 26
# Processing Alternative Query: Farsightedness
# [98] Processing Query: Keratitis
# Removed duplicates: 39
# [99] Processing Query: Keratoconus
# Removed duplicates: 29
# [100] Processing Query: Macular Hole
# Removed duplicates: 4
# [101] Processing Query: Myopia
# Removed duplicates: 47
# Processing Alternative Query: Nearsightedness
# [102] Processing Query: Photophobia
# Removed duplicates: 61
# [103] Processing Query: Presbyopia
# Removed duplicates: 30
# [104] Processing Query: Retinal Detachment
# Removed duplicates: 47
# [105] Processing Query: Retinitis Pigmentosa
# Removed duplicates: 16
# [106] Processing Query: Strabismus
# Removed duplicates: 25
# [107] Processing Query: Uveitis
# Removed duplicates: 49
# [108] Processing Query: Cystic Fibrosis
# Removed duplicates: 58
# [109] Processing Query: Huntington's Disease
# Removed duplicates: 47
# [110] Processing Query: Sickle Cell Disease
# Removed duplicates: 40
# [111] Processing Query: Marfan Syndrome
# Removed duplicates: 73
# [112] Processing Query: Yeast Infection
# Removed duplicates: 54
# Processing Alternative Query: Candidiasis
# [113] Processing Query: Chickenpox and Shingles
# Removed duplicates: 65
# Processing Alternative Query: Varicella-Zoster Virus Infection
# [114] Processing Query: Clostridioides difficile (C. diff) Infection
# Removed duplicates: 1
# [115] Processing Query: Common Cold
# Removed duplicates: 21
# [116] Processing Query: HIV/AIDS
# Removed duplicates: 48
# [117] Processing Query: Hepatitis B
# Removed duplicates: 50
# Processing Alternative Query: HBV
# [118] Processing Query: Hepatitis C
# Removed duplicates: 50
# Processing Alternative Query: HCV
# [119] Processing Query: Herpes Simplex Virus Infection
# Removed duplicates: 62
# Processing Alternative Query: HSV
# [120] Processing Query: Human Papillomavirus (HPV) Infection
# Removed duplicates: 64
# [121] Processing Query: Influenza
# Removed duplicates: 68
# Processing Alternative Query: Flu
# [122] Processing Query: Lyme Disease
# Removed duplicates: 58
# [123] Processing Query: Meningitis
# Removed duplicates: 70
# [124] Processing Query: Mononucleosis
# Removed duplicates: 70
# Processing Alternative Query: Mono
# [125] Processing Query: Osteomyelitis
# Removed duplicates: 62
# Processing Alternative Query: Bone Infection
# [126] Processing Query: Sepsis
# Removed duplicates: 74
# [127] Processing Query: Streptococcal Pharyngitis
# Removed duplicates: 68
# Processing Alternative Query: Strep throat
# [128] Processing Query: Tuberculosis
# Removed duplicates: 54
# [129] Processing Query: Chronic Kidney Disease
# Removed duplicates: 17
# Processing Alternative Query: CKD
# [130] Processing Query: Cirrhosis
# [131] Processing Query: Hepatitis
# Removed duplicates: 50
# [132] Processing Query: Metabolic-Associated Steatohepatitis
# Removed duplicates: 62
# [133] Processing Query: Metabolic-Associated Steatotic Liver Disease
# Removed duplicates: 53
# [134] Processing Query: Attention-Deficit/Hyperactivity Disorder
# Removed duplicates: 49
# Processing Alternative Query: ADHD
# [135] Processing Query: Anxiety Disorder
# Removed duplicates: 1
# [136] Processing Query: Asperger's Syndrome
# Removed duplicates: 1
# [137] Processing Query: Autism Spectrum Disorder
# Removed duplicates: 42
# [138] Processing Query: Bipolar Disorder
# Removed duplicates: 1
# [139] Processing Query: Depression
# Removed duplicates: 43
# [140] Processing Query: Loneliness
# Removed duplicates: 23
# [141] Processing Query: Post-traumatic Stress Disorder
# Removed duplicates: 53
# Processing Alternative Query: PTSD
# [142] Processing Query: Panic Disorder
# Removed duplicates: 4
# [143] Processing Query: Postpartum Depression
# Removed duplicates: 3
# [144] Processing Query: Seasonal Affective Disorder
# Removed duplicates: 11
# [145] Processing Query: Childhood Obesity
# Removed duplicates: 67
# [146] Processing Query: Dyslipidemia
# Removed duplicates: 56
# [147] Processing Query: Metabolic Syndrome
# Removed duplicates: 83
# [148] Processing Query: Obesity
# [149] Processing Query: Prediabetes
# Removed duplicates: 68
# [150] Processing Query: Achilles Tendinitis
# Removed duplicates: 79
# Processing Alternative Query: Achilles Tendinopathy
# [151] Processing Query: Acute fractures
# Removed duplicates: 87
# [152] Processing Query: Ankle Sprain
# Removed duplicates: 64
# [153] Processing Query: Anterior Cruciate Ligament Tear
# Removed duplicates: 60
# Processing Alternative Query: ACL Tear
# [154] Processing Query: Bruises
# Removed duplicates: 70
# Processing Alternative Query: Contusion
# [155] Processing Query: Burns
# Removed duplicates: 74
# [156] Processing Query: Bursitis
# Removed duplicates: 61
# [157] Processing Query: Frostbite
# Removed duplicates: 29
# [158] Processing Query: Medial Epicondylitis
# Removed duplicates: 30
# Processing Alternative Query: Golfer's Elbow
# [159] Processing Query: Growth Plate Fracture
# Removed duplicates: 67
# [160] Processing Query: Hamstring Injury
# Removed duplicates: 66
# [161] Processing Query: Herniated Disc
# Removed duplicates: 69
# [162] Processing Query: Iliotibial Band Syndrome
# Removed duplicates: 62
# [163] Processing Query: Glenoid Labrum Tear
# Removed duplicates: 26
# [164] Processing Query: Little League Elbow
# Removed duplicates: 44
# [165] Processing Query: Little League Shoulder
# Removed duplicates: 22
# [166] Processing Query: Medial Collateral Ligament Injury
# Removed duplicates: 58
# [167] Processing Query: Muscle Cramp
# Removed duplicates: 12
# [168] Processing Query: Osgood-Schlatter Disease
# Removed duplicates: 79
# [169] Processing Query: Osteochondritis Dissecans
# Removed duplicates: 77
# [170] Processing Query: Overtraining Syndrome
# Removed duplicates: 10
# [171] Processing Query: Repetitive Strain Injury
# Removed duplicates: 51
# [172] Processing Query: Patellar Tendinitis
# Removed duplicates: 43
# [173] Processing Query: Patellofemoral Pain Syndrome
# Removed duplicates: 67
# Processing Alternative Query: PFPS
# [174] Processing Query: Sacroiliac Joint Dysfunction
# Removed duplicates: 27
# Processing Alternative Query: Pelvic Pain
# [175] Processing Query: Plantar Fasciitis
# Removed duplicates: 75
# [176] Processing Query: Rotator Cuff Tear
# Removed duplicates: 54
# [177] Processing Query: Scoliosis
# Removed duplicates: 68
# [178] Processing Query: Sever's Disease
# Removed duplicates: 77
# Processing Alternative Query: Calcaneal Apophysitis
# [179] Processing Query: Medial Tibial Stress Syndrome
# Removed duplicates: 73
# Processing Alternative Query: Shin Splints
# [180] Processing Query: Shoulder Dislocation
# Removed duplicates: 79
# [181] Processing Query: Spinal Stenosis
# Removed duplicates: 28
# [182] Processing Query: Spondylolisthesis
# Removed duplicates: 67
# [183] Processing Query: Sprains and Strains
# Removed duplicates: 57
# [184] Processing Query: Stress Fracture
# Removed duplicates: 75
# [185] Processing Query: Lateral Epicondylitis
# Removed duplicates: 46
# Processing Alternative Query: Tennis Elbow
# [186] Processing Query: Meniscus Tear
# Removed duplicates: 65
# [187] Processing Query: Alzheimer's Disease
# Removed duplicates: 22
# [188] Processing Query: Carpal Tunnel Syndrome
# Removed duplicates: 76
# [189] Processing Query: Cervical Radiculopathy
# Removed duplicates: 24
# [190] Processing Query: Cluster Headache
# Removed duplicates: 42
# [191] Processing Query: Concussions
# Removed duplicates: 64
# [192] Processing Query: ICU Delirium
# Removed duplicates: 72
# [193] Processing Query: Lumbar Radiculopathy
# Removed duplicates: 62
# [194] Processing Query: Migraine Headache
# Removed duplicates: 27
# [195] Processing Query: Postural Orthostatic Tachycardia Syndrome
# Removed duplicates: 58
# Processing Alternative Query: POTS
# [196] Processing Query: Parkinson's Disease
# Removed duplicates: 48
# [197] Processing Query: Peripheral Neuropathy
# Removed duplicates: 41
# [198] Processing Query: Postherpetic Neuralgia
# Removed duplicates: 55
# Processing Alternative Query: Shingles Pain
# [199] Processing Query: Sciatica
# Removed duplicates: 60
# [200] Processing Query: Stroke
# Removed duplicates: 49
# [201] Processing Query: Tension Headache
# Removed duplicates: 37
# [202] Processing Query: Trigeminal Neuralgia
# Removed duplicates: 32
# [203] Processing Query: Vertigo
# Removed duplicates: 66
# [204] Processing Query: Visual Migraine
# Removed duplicates: 43
# Processing Alternative Query: Ocular Migraine
# [205] Processing Query: Halitosis
# Removed duplicates: 41
# Processing Alternative Query: Bad Breath
# [206] Processing Query: Cavities
# Removed duplicates: 50
# Processing Alternative Query: Tooth Decay
# [207] Processing Query: Dental Abscess
# Removed duplicates: 64
# [208] Processing Query: Dry Mouth
# Removed duplicates: 24
# Processing Alternative Query: Xerostomia
# [209] Processing Query: Gingivitis
# Removed duplicates: 57
# [210] Processing Query: Mouth Ulcers
# Removed duplicates: 61
# Processing Alternative Query: Canker Sores
# [211] Processing Query: Orthodontic Relapse
# [212] Processing Query: Periodontitis
# Removed duplicates: 57
# [213] Processing Query: Dentin Hypersensitivity
# Processing Alternative Query: Tooth Sensitivity
# [214] Processing Query: Wisdom Teeth Impaction
# [215] Processing Query: Malaria
# Removed duplicates: 51
# [216] Processing Query: Toxoplasmosis
# Removed duplicates: 62
# [217] Processing Query: Giardiasis
# Removed duplicates: 81
# [218] Processing Query: Trichinosis
# Removed duplicates: 18
# [219] Processing Query: Lice Infestation
# Removed duplicates: 75
# Processing Alternative Query: Pediculosis
# [220] Processing Query: Scabies
# Removed duplicates: 83
# [221] Processing Query: Endometriosis
# Removed duplicates: 57
# [222] Processing Query: Infertility
# Removed duplicates: 64
# [223] Processing Query: Menopause
# Removed duplicates: 68
# Processing Alternative Query: Menopausal Symptoms
# [224] Processing Query: Menstrual Disorders
# Removed duplicates: 65
# [225] Processing Query: Polycystic Ovary Syndrome (PCOS) Related Hair Loss
# Removed duplicates: 5
# [226] Processing Query: Polycystic Ovary Syndrome
# Removed duplicates: 72
# Processing Alternative Query: PCOS
# [227] Processing Query: Premenstrual Dysphoric Disorder
# Removed duplicates: 83
# [228] Processing Query: Premenstrual Syndrome
# Removed duplicates: 81
# [229] Processing Query: Acute Respiratory Distress Syndrome
# Removed duplicates: 66
# Processing Alternative Query: ARDS
# [230] Processing Query: Asthma
# [231] Processing Query: Bronchitis
# Removed duplicates: 66
# [232] Processing Query: Chronic Cough
# Removed duplicates: 36
# [233] Processing Query: Chronic Obstructive Pulmonary Disease
# Removed duplicates: 34
# Processing Alternative Query: COPD
# [234] Processing Query: Lung Abscess
# Removed duplicates: 57
# [235] Processing Query: Occupational Lung Disease
# Removed duplicates: 39
# [236] Processing Query: Pneumoconiosis
# Removed duplicates: 11
# [237] Processing Query: Pneumonia
# Removed duplicates: 68
# [238] Processing Query: Pulmonary Embolism
# Removed duplicates: 47
# [239] Processing Query: Pulmonary Fibrosis
# Removed duplicates: 22
# [240] Processing Query: Pulmonary Hypertension
# Removed duplicates: 37
# [241] Processing Query: Sinusitis
# Removed duplicates: 36
# Processing Alternative Query: Sinus Infection
# [242] Processing Query: Bacterial Vaginosis
# Removed duplicates: 55
# Processing Alternative Query: BV
# [243] Processing Query: Chlamydia Infection
# Removed duplicates: 49
# [244] Processing Query: Gonorrhea
# Removed duplicates: 37
# [245] Processing Query: Syphilis
# Removed duplicates: 65
# [246] Processing Query: Trichomoniasis
# Removed duplicates: 31
# [247] Processing Query: Acne Vulgaris
# Removed duplicates: 45
# Processing Alternative Query: Acne Vulgaris
# [248] Processing Query: Actinic Keratosis
# Removed duplicates: 65
# [249] Processing Query: Albinism
# Removed duplicates: 58
# [250] Processing Query: Alopecia Areata
# Removed duplicates: 79
# [251] Processing Query: Athlete's Foot
# Removed duplicates: 67
# Processing Alternative Query: Tinea Pedis
# [252] Processing Query: Boils
# Removed duplicates: 24
# Processing Alternative Query: Furuncle
# [253] Processing Query: Cellulitis
# Removed duplicates: 82
# [254] Processing Query: Contact Dermatitis
# Removed duplicates: 52
# [255] Processing Query: Cystic Acne
# Removed duplicates: 37
# [256] Processing Query: Eczema
# Removed duplicates: 58
# Processing Alternative Query: Atopic Dermatitis
# [257] Processing Query: Folliculitis
# Removed duplicates: 56
# [258] Processing Query: Alopecia
# Removed duplicates: 65
# Processing Alternative Query: Hair Loss
# [259] Processing Query: Urticaria
# Removed duplicates: 66
# Processing Alternative Query: Hives
# [260] Processing Query: Hyperhidrosis
# Removed duplicates: 66
# [261] Processing Query: Tinea Cruris
# Removed duplicates: 87
# Processing Alternative Query: Jock Itch
# [262] Processing Query: Keloid
# Removed duplicates: 70
# [263] Processing Query: Keratosis Pilaris
# Removed duplicates: 60
# [264] Processing Query: Melasma
# Removed duplicates: 74
# [265] Processing Query: Postpartum Hair Loss
# Removed duplicates: 13
# [266] Processing Query: Psoriasis
# Removed duplicates: 52
# [267] Processing Query: Ringworm
# Removed duplicates: 36
# Processing Alternative Query: Tinea
# [268] Processing Query: Rosacea
# Removed duplicates: 50
# [269] Processing Query: Seborrheic Dermatitis
# Removed duplicates: 51
# [270] Processing Query: Skin Tag
# Removed duplicates: 40
# Processing Alternative Query: Acrochordon
# [271] Processing Query: Sunburn
# Removed duplicates: 74
# [272] Processing Query: Vitiligo
# Removed duplicates: 48
# [273] Processing Query: Wart
# Removed duplicates: 72
# [274] Processing Query: Central Sleep Apnea
# Removed duplicates: 92
# Processing Alternative Query: CSA
# [275] Processing Query: Delayed Sleep Phase Syndrome
# Removed duplicates: 3
# [276] Processing Query: Familial Advanced Sleep Phase Syndrome
# [277] Processing Query: Idiopathic Hypersomnia
# Removed duplicates: 1
# [278] Processing Query: Insomnia
# Removed duplicates: 14
# [279] Processing Query: Narcolepsy
# Removed duplicates: 20
# [280] Processing Query: Night Terrors
# Removed duplicates: 11
# [281] Processing Query: Non-24-Hour Sleep-Wake Disorder
# [282] Processing Query: Periodic Limb Movement Disorder
# Removed duplicates: 13
# Processing Alternative Query: PLMD
# [283] Processing Query: REM Sleep Behavior Disorder
# Removed duplicates: 43
# [284] Processing Query: Restless Legs Syndrome
# Removed duplicates: 11
# [285] Processing Query: Shift Work Sleep Disorder
# Removed duplicates: 4
# [286] Processing Query: Sleep Apnea
# Removed duplicates: 99
# [287] Processing Query: Sleep Bruxism
# Removed duplicates: 7
# Processing Alternative Query: Teeth Grinding
# [288] Processing Query: Sleepwalking
# Removed duplicates: 38
# [289] Processing Query: Interstitial Cystitis
# Removed duplicates: 61
# [290] Processing Query: Urinary Tract Infection
# Removed duplicates: 74
# Processing Alternative Query: UTI
# [291] Processing Query: Nephrolithiasis
# Removed duplicates: 64
# Processing Alternative Query: Kidney Stones
# [292] Processing Query: Urinary Incontinence
# Removed duplicates: 70
# [293] Processing Query: Prostatitis
# Removed duplicates: 66
# Results saved to search_results_revised.json

# %%
# 5. Process Queries and Save Results
df = pd.read_csv(csv_file)
df = df[['Condition', 'Alternative Name', 'Category']].fillna("")

results_list = []
for i, row in df.iterrows():
    query = row['Condition']
    query_alt = row['Alternative Name']
    print(f"Processing Query: {query}")
    results = search_index(query, ix)
    formatted_results = {
        "query": query,
        "results": [{"path": result['path'], "score": result['score']} for result in results]
    }
    results_list.append(formatted_results)

    if query_alt:
        print(f"Processing Alternative Query: {query_alt}")
        results = search_index(query_alt, ix)
        formatted_results = {
            "query": query_alt,
            "results": [{"path": result['path'], "score": result['score']} for result in results]
        }
        results_list.append(formatted_results)

with open(output_file, "w") as json_file:
    json.dump(results_list, json_file, indent=4)
print(f"Results saved to {output_file}")
# Out:
# Processing Query: Food Allergy
# Processing Query: Allergic Rhinitis
# Processing Alternative Query: Hay Fever
# Processing Query: Drug Allergies
# Processing Query: Atopic Dermatitis
# Processing Alternative Query: Eczema
# Processing Query: Contact Dermatitis
# Processing Query: Ankylosing Spondylitis
# Processing Query: Gout
# Processing Query: Guillain-Barre Syndrome
# Processing Query: Multiple Sclerosis
# Processing Alternative Query: MS
# Processing Query: Osteoarthritis
# Processing Query: Rheumatoid Arthritis
# Processing Query: Sarcoidosis
# Processing Query: Scleroderma
# Processing Query: Systemic Lupus Erythematosus
# Processing Alternative Query: SLE
# Processing Query: Vasculitis
# Processing Query: Ant Bites
# Processing Query: Bedbug Bites
# Processing Query: Flea Bites
# Processing Query: Horsefly Bites
# Processing Query: Mosquito Bites
# Processing Query: Spider Bites
# Processing Query: Tick Bites
# Processing Query: Anemia
# Processing Query: Hemophilia
# Processing Query: Thrombocytopenia
# Processing Alternative Query: Low Platelet Count
# Processing Query: Polycythemia Vera
# Processing Query: Osteoporosis
# Processing Query: Osteomalacia
# Processing Alternative Query: Soft Bone Disease
# Processing Query: Osteogenesis Imperfecta
# Processing Alternative Query: Brittle Bone Disease
# Processing Query: Paget's Disease of Bone
# Processing Alternative Query: Osteitis Deformans
# Processing Query: Bone Fractures
# Processing Query: Basal Cell Carcinoma
# Processing Query: Breast Cancer
# Processing Query: Cervical Cancer
# Processing Query: Colorectal Cancer
# Processing Query: Liver Cancer
# Processing Query: Lung Cancer
# Processing Query: Melanoma
# Processing Query: Ovarian Cancer
# Processing Query: Prostate Cancer
# Processing Query: Squamous Cell Carcinoma
# Processing Query: Leukemia
# Processing Alternative Query: Blood Cancer
# Processing Query: Cardiac Arrhythmia
# Processing Query: Coronary Artery Disease
# Processing Query: Heart Failure
# Processing Query: Hypertension
# Processing Alternative Query: High Blood Pressure
# Processing Query: Chronic Fatigue Syndrome
# Processing Query: Fibromyalgia
# Processing Query: Post-COVID Syndrome
# Processing Alternative Query: Long COVID
# Processing Query: Anal Fissures
# Processing Query: Appendicitis
# Processing Query: Barrett's Esophagus
# Processing Query: Celiac Disease
# Processing Query: Cholecystitis
# Processing Query: Colitis
# Processing Query: Constipation
# Processing Query: Crohn's Disease
# Processing Alternative Query: Intestinal Inflammation
# Processing Query: Diarrhea
# Processing Query: Diverticulitis
# Processing Query: Esophagitis
# Processing Query: Functional Dyspepsia
# Processing Query: Gallbladder Disease
# Processing Query: Gastritis
# Processing Query: Gastroenteritis
# Processing Alternative Query: Stomach Flu
# Processing Query: Gastroesophageal Reflux Disease
# Processing Alternative Query: GERD
# Processing Query: Gastroparesis
# Processing Query: Hemorrhoids
# Processing Alternative Query: Piles
# Processing Query: Inflammatory Bowel Disease
# Processing Alternative Query: IBD
# Processing Query: Irritable Bowel Syndrome
# Processing Alternative Query: IBS
# Processing Query: Lactose Intolerance
# Processing Query: Pancreatitis
# Processing Query: Peptic Ulcer Disease
# Processing Alternative Query: PUD
# Processing Query: Small Intestinal Bacterial Overgrowth
# Processing Alternative Query: SIBO
# Processing Query: Zollinger-Ellison Syndrome
# Processing Query: Otitis Externa
# Processing Alternative Query: Swimmer's Ear
# Processing Query: Tonsillitis
# Processing Query: Eustachian Tube Dysfunction
# Processing Alternative Query: Eustachian Tube Disorder
# Processing Query: Laryngitis
# Processing Query: Tympanic Membrane (Eardrum) Perforation
# Processing Query: Eustachian Tube Dysfunction
# Processing Alternative Query: ETD
# Processing Query: Hashimoto's Thyroiditis
# Processing Alternative Query: Autoimmune Thyroiditis
# Processing Query: Hyperthyroidism
# Processing Query: Hypothyroidism
# Processing Query: Type 1 Diabetes
# Processing Query: Type 2 Diabetes
# Processing Query: Age-related Macular Degeneration
# Processing Alternative Query: AMD
# Processing Query: Amblyopia
# Processing Query: Astigmatism
# Processing Query: Blepharitis
# Processing Query: Cataracts
# Processing Query: Conjunctivitis
# Processing Query: Conjunctivitis
# Processing Query: Corneal Abrasion
# Processing Query: Diabetic Retinopathy
# Processing Query: Dry Eye Syndrome
# Processing Alternative Query: Dry Eye
# Processing Query: Eye Floaters
# Processing Query: Glaucoma
# Processing Query: Hyperopia
# Processing Alternative Query: Farsightedness
# Processing Query: Keratitis
# Processing Query: Keratoconus
# Processing Query: Macular Hole
# Processing Query: Myopia
# Processing Alternative Query: Nearsightedness
# Processing Query: Photophobia
# Processing Query: Presbyopia
# Processing Query: Retinal Detachment
# Processing Query: Retinitis Pigmentosa
# Processing Query: Strabismus
# Processing Query: Uveitis
# Processing Query: Cystic Fibrosis
# Processing Query: Huntington's Disease
# Processing Query: Sickle Cell Disease
# Processing Query: Marfan Syndrome
# Processing Query: Yeast Infection
# Processing Alternative Query: Candidiasis
# Processing Query: Chickenpox and Shingles
# Processing Alternative Query: Varicella-Zoster Virus Infection
# Processing Query: Clostridioides difficile (C. diff) Infection
# Processing Query: Common Cold
# Processing Query: HIV/AIDS
# Processing Query: Hepatitis B
# Processing Alternative Query: HBV
# Processing Query: Hepatitis C
# Processing Alternative Query: HCV
# Processing Query: Herpes Simplex Virus Infection
# Processing Alternative Query: HSV
# Processing Query: Human Papillomavirus (HPV) Infection
# Processing Query: Influenza
# Processing Alternative Query: Flu
# Processing Query: Lyme Disease
# Processing Query: Meningitis
# Processing Query: Mononucleosis
# Processing Alternative Query: Mono
# Processing Query: Osteomyelitis
# Processing Alternative Query: Bone Infection
# Processing Query: Sepsis
# Processing Query: Streptococcal Pharyngitis
# Processing Alternative Query: Strep throat
# Processing Query: Tuberculosis
# Processing Query: Chronic Kidney Disease
# Processing Alternative Query: CKD
# Processing Query: Cirrhosis
# Processing Query: Hepatitis
# Processing Query: Metabolic-Associated Steatohepatitis
# Processing Query: Metabolic-Associated Steatotic Liver Disease
# Processing Query: Attention-Deficit/Hyperactivity Disorder
# Processing Alternative Query: ADHD
# Processing Query: Anxiety Disorder
# Processing Query: Asperger's Syndrome
# Processing Query: Autism Spectrum Disorder
# Processing Query: Bipolar Disorder
# Processing Query: Depression
# Processing Query: Loneliness
# Processing Query: Post-traumatic Stress Disorder
# Processing Alternative Query: PTSD
# Processing Query: Panic Disorder
# Processing Query: Postpartum Depression
# Processing Query: Seasonal Affective Disorder
# Processing Query: Childhood Obesity
# Processing Query: Dyslipidemia
# Processing Query: Metabolic Syndrome
# Processing Query: Obesity
# Processing Query: Prediabetes
# Processing Query: Achilles Tendinitis
# Processing Alternative Query: Achilles Tendinopathy
# Processing Query: Acute fractures
# Processing Query: Ankle Sprain
# Processing Query: Anterior Cruciate Ligament Tear
# Processing Alternative Query: ACL Tear
# Processing Query: Bruises
# Processing Alternative Query: Contusion
# Processing Query: Burns
# Processing Query: Bursitis
# Processing Query: Frostbite
# Processing Query: Medial Epicondylitis
# Processing Alternative Query: Golfer's Elbow
# Processing Query: Growth Plate Fracture
# Processing Query: Hamstring Injury
# Processing Query: Herniated Disc
# Processing Query: Iliotibial Band Syndrome
# Processing Query: Glenoid Labrum Tear
# Processing Query: Little League Elbow
# Processing Query: Little League Shoulder
# Processing Query: Medial Collateral Ligament Injury
# Processing Query: Muscle Cramp
# Processing Query: Osgood-Schlatter Disease
# Processing Query: Osteochondritis Dissecans
# Processing Query: Overtraining Syndrome
# Processing Query: Repetitive Strain Injury
# Processing Query: Patellar Tendinitis
# Processing Query: Patellofemoral Pain Syndrome
# Processing Alternative Query: PFPS
# Processing Query: Sacroiliac Joint Dysfunction
# Processing Alternative Query: Pelvic Pain
# Processing Query: Plantar Fasciitis
# Processing Query: Rotator Cuff Tear
# Processing Query: Scoliosis
# Processing Query: Sever's Disease
# Processing Alternative Query: Calcaneal Apophysitis
# Processing Query: Medial Tibial Stress Syndrome
# Processing Alternative Query: Shin Splints
# Processing Query: Shoulder Dislocation
# Processing Query: Spinal Stenosis
# Processing Query: Spondylolisthesis
# Processing Query: Sprains and Strains
# Processing Query: Stress Fracture
# Processing Query: Lateral Epicondylitis
# Processing Alternative Query: Tennis Elbow
# Processing Query: Meniscus Tear
# Processing Query: Alzheimer's Disease
# Processing Query: Carpal Tunnel Syndrome
# Processing Query: Cervical Radiculopathy
# Processing Query: Cluster Headache
# Processing Query: Concussions
# Processing Query: ICU Delirium
# Processing Query: Lumbar Radiculopathy
# Processing Query: Migraine Headache
# Processing Query: Postural Orthostatic Tachycardia Syndrome
# Processing Alternative Query: POTS
# Processing Query: Parkinson's Disease
# Processing Query: Peripheral Neuropathy
# Processing Query: Postherpetic Neuralgia
# Processing Alternative Query: Shingles Pain
# Processing Query: Sciatica
# Processing Query: Stroke
# Processing Query: Tension Headache
# Processing Query: Trigeminal Neuralgia
# Processing Query: Vertigo
# Processing Query: Visual Migraine
# Processing Alternative Query: Ocular Migraine
# Processing Query: Halitosis
# Processing Alternative Query: Bad Breath
# Processing Query: Cavities
# Processing Alternative Query: Tooth Decay
# Processing Query: Dental Abscess
# Processing Query: Dry Mouth
# Processing Alternative Query: Xerostomia
# Processing Query: Gingivitis
# Processing Query: Mouth Ulcers
# Processing Alternative Query: Canker Sores
# Processing Query: Orthodontic Relapse
# Processing Query: Periodontitis
# Processing Query: Dentin Hypersensitivity
# Processing Alternative Query: Tooth Sensitivity
# Processing Query: Wisdom Teeth Impaction
# Processing Query: Malaria
# Processing Query: Toxoplasmosis
# Processing Query: Giardiasis
# Processing Query: Trichinosis
# Processing Query: Lice Infestation
# Processing Alternative Query: Pediculosis
# Processing Query: Scabies
# Processing Query: Endometriosis
# Processing Query: Infertility
# Processing Query: Menopause
# Processing Alternative Query: Menopausal Symptoms
# Processing Query: Menstrual Disorders
# Processing Query: Polycystic Ovary Syndrome (PCOS) Related Hair Loss
# Processing Query: Polycystic Ovary Syndrome
# Processing Alternative Query: PCOS
# Processing Query: Premenstrual Dysphoric Disorder
# Processing Query: Premenstrual Syndrome
# Processing Query: Acute Respiratory Distress Syndrome
# Processing Alternative Query: ARDS
# Processing Query: Asthma
# Processing Query: Bronchitis
# Processing Query: Chronic Cough
# Processing Query: Chronic Obstructive Pulmonary Disease
# Processing Alternative Query: COPD
# Processing Query: Lung Abscess
# Processing Query: Occupational Lung Disease
# Processing Query: Pneumoconiosis
# Processing Query: Pneumonia
# Processing Query: Pulmonary Embolism
# Processing Query: Pulmonary Fibrosis
# Processing Query: Pulmonary Hypertension
# Processing Query: Sinusitis
# Processing Alternative Query: Sinus Infection
# Processing Query: Bacterial Vaginosis
# Processing Alternative Query: BV
# Processing Query: Chlamydia Infection
# Processing Query: Gonorrhea
# Processing Query: Syphilis
# Processing Query: Trichomoniasis
# Processing Query: Acne Vulgaris
# Processing Alternative Query: Acne Vulgaris
# Processing Query: Actinic Keratosis
# Processing Query: Albinism
# Processing Query: Alopecia Areata
# Processing Query: Athlete's Foot
# Processing Alternative Query: Tinea Pedis
# Processing Query: Boils
# Processing Alternative Query: Furuncle
# Processing Query: Cellulitis
# Processing Query: Contact Dermatitis
# Processing Query: Cystic Acne
# Processing Query: Eczema
# Processing Alternative Query: Atopic Dermatitis
# Processing Query: Folliculitis
# Processing Query: Alopecia
# Processing Alternative Query: Hair Loss
# Processing Query: Urticaria
# Processing Alternative Query: Hives
# Processing Query: Hyperhidrosis
# Processing Query: Tinea Cruris
# Processing Alternative Query: Jock Itch
# Processing Query: Keloid
# Processing Query: Keratosis Pilaris
# Processing Query: Melasma
# Processing Query: Postpartum Hair Loss
# Processing Query: Psoriasis
# Processing Query: Ringworm
# Processing Alternative Query: Tinea
# Processing Query: Rosacea
# Processing Query: Seborrheic Dermatitis
# Processing Query: Skin Tag
# Processing Alternative Query: Acrochordon
# Processing Query: Sunburn
# Processing Query: Vitiligo
# Processing Query: Wart
# Processing Query: Central Sleep Apnea
# Processing Alternative Query: CSA
# Processing Query: Delayed Sleep Phase Syndrome
# Processing Query: Familial Advanced Sleep Phase Syndrome
# Processing Query: Idiopathic Hypersomnia
# Processing Query: Insomnia
# Processing Query: Narcolepsy
# Processing Query: Night Terrors
# Processing Query: Non-24-Hour Sleep-Wake Disorder
# Processing Query: Periodic Limb Movement Disorder
# Processing Alternative Query: PLMD
# Processing Query: REM Sleep Behavior Disorder
# Processing Query: Restless Legs Syndrome
# Processing Query: Shift Work Sleep Disorder
# Processing Query: Sleep Apnea
# Processing Query: Sleep Bruxism
# Processing Alternative Query: Teeth Grinding
# Processing Query: Sleepwalking
# Processing Query: Interstitial Cystitis
# Processing Query: Urinary Tract Infection
# Processing Alternative Query: UTI
# Processing Query: Nephrolithiasis
# Processing Alternative Query: Kidney Stones
# Processing Query: Urinary Incontinence
# Processing Query: Prostatitis
# Results saved to search_results_revised.json

# %%
with open("/Users/vince/Salk/PaperGeneration/data/search_results_revised.json", 'r', encoding='utf-8') as file:
    search_results = json.load(file)
    print(search_results[0])
# Out:
# {'query': 'Food Allergy', 'results': [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/food-allergy-and-food-intolerance/pathogenesis-of-food-allergy.json::chunk43', 'title': 'Pathogenesis of food allergy', 'topic': 'Allergy and immunology', 'subtopic': 'Food allergy and food intolerance', 'score': 54.42908898520413, 'content': 'FACTORS INFLUENCING SENSITIZATION OR TOLERANCE\nGenetics\nGenetic susceptibility plays a role in the development of food allergy. This has been demonstrated in mouse models by the strain-dependent variability in induction of oral tolerance or hypersensitivity [173,174].\nAn atopic predisposition is associated with an increased risk for food allergy. There is a significant familial aggregation of food allergy and food allergen sensitization [175]. The association is strongest among siblings: A child is over two-and-a-half times more likely to develop a food allergy if a sibling has a food allergy. Regarding inheritance of allergy to specific foods, peanut allergy is the only specific food allergy definitively associated with familial inheritance, but other foods have not been extensively studied [176-179].', 'references': '["[173] Li X, Huang CK, Schofield BH, et al. Strain-dependent induction of allergic sensitization caused by peanut allergen DNA immunization in mice. J Immunol 1999; 162:3045.", "[174] Morafo V, Srivastava K, Huang CK, et al. Genetic susceptibility to food allergy is linked to differential TH2-TH1 responses in C3H/HeJ and BALB/c mice. J Allergy Clin Immunol 2003; 111:1122.", "[175] Tsai HJ, Kumar R, Pongracic J, et al. Familial aggregation of food allergy and sensitization to food allergens: a family-based study. Clin Exp Allergy 2009; 39:101.", "[176] Howell WM, Turner SJ, Hourihane JO, et al. HLA class II DRB1, DQB1 and DPB1 genotypic associations with peanut allergy: evidence from a family-based and case-control study. Clin Exp Allergy 1998; 28:156.", "[177] Amoli MM, Hand S, Hajeer AH, et al. Polymorphism in the STAT6 gene encodes risk for nut allergy. Genes Immun 2002; 3:220.", "[178] Hourihane JO, Dean TP, Warner JO. Peanut allergy in relation to heredity, maternal diet, and other atopic diseases: results of a questionnaire survey, skin prick testing, and food challenges. BMJ 1996; 313:518.", "[179] Sicherer SH, Furlong TJ, Maes HH, et al. Genetics of peanut allergy: a twin study. J Allergy Clin Immunol 2000; 106:53."]'}, {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate_markdownify/table-of-contents/allergy-and-immunology/food-allergy-and-food-intolerance/pathogenesis-of-food-allergy.json::chunk0', 'title': 'Pathogenesis of food allergy', 'topic': 'Allergy and immunology', 'subtopic': 'Food allergy and food intolerance', 'score': 54.351739350405495, 'content': 'INTRODUCTION\nTolerance is the normal immune response to the food an individual eats over a lifetime [1]. Food allergy is an abnormal immune reaction consisting of hypersensitivity to food components, most commonly proteins [2,3].\nThis topic will focus on food allergy due to primary sensitization through the gut and will review organization of the gut immune system and factors that influence oral tolerance induction. Theories addressing the increasing prevalence of food allergy are briefly mentioned. The pathogenesis of pollen-food allergy syndrome, seen more frequently in adolescents and adults, is discussed separately. (See "Pathogenesis of oral allergy syndrome (pollen-food allergy syndrome)".)', 'references': '["[1] Vickery BP, Scurlock AM, Jones SM, Burks AW. Mechanisms of immune tolerance relevant to food allergy. J Allergy Clin Immunol 2011; 127:576.", "[2] Chehade M, Mayer L. Oral tolerance and its relation to food hypersensitivities. J Allergy Clin Immunol 2005; 115:3.", "[3] Burks AW, Laubach S, Jones SM. Oral tolerance, food allergy, and immunotherapy: implications for future treatment. J Allergy Clin Immunol 2008; 121:1344."]'}, {'path': '/Use ...

# %%
json.loads(search_results[0].get('results')[0].get('references'))
# Out:
# ['[173] Li X, Huang CK, Schofield BH, et al. Strain-dependent induction of allergic sensitization caused by peanut allergen DNA immunization in mice. J Immunol 1999; 162:3045.',
#  '[174] Morafo V, Srivastava K, Huang CK, et al. Genetic susceptibility to food allergy is linked to differential TH2-TH1 responses in C3H/HeJ and BALB/c mice. J Allergy Clin Immunol 2003; 111:1122.',
#  '[175] Tsai HJ, Kumar R, Pongracic J, et al. Familial aggregation of food allergy and sensitization to food allergens: a family-based study. Clin Exp Allergy 2009; 39:101.',
#  '[176] Howell WM, Turner SJ, Hourihane JO, et al. HLA class II DRB1, DQB1 and DPB1 genotypic associations with peanut allergy: evidence from a family-based and case-control study. Clin Exp Allergy 1998; 28:156.',
#  '[177] Amoli MM, Hand S, Hajeer AH, et al. Polymorphism in the STAT6 gene encodes risk for nut allergy. Genes Immun 2002; 3:220.',
#  '[178] Hourihane JO, Dean TP, Warner JO. Peanut allergy in relation to heredity, maternal diet, and other atopic diseases: results of a questionnaire survey, skin prick testing, and food challenges. BMJ 1996; 313:518.',
#  '[179] Sicherer SH, Furlong TJ, Maes HH, et al. Genetics of peanut allergy: a twin study. J Allergy Clin Immunol 2000; 106:53.']

# %%
conditions_df = pd.read_csv("/Users/vince/Salk/PaperGeneration/notebooks/condition_revised.csv")
for idx, row in conditions_df.head(3).iterrows():
    print(row)
# Out:
# Condition           Food Allergy
# Alternative Name             NaN
# Category               Allergies
# Name: 0, dtype: object
# Condition           Allergic Rhinitis
# Alternative Name            Hay Fever
# Category                    Allergies
# Name: 1, dtype: object
# Condition           Drug Allergies
# Alternative Name               NaN
# Category                 Allergies
# Name: 2, dtype: object

# %%
from rich import print as rprint
import pprint as pp

def extract_top_unique_files(results, top_n=5):
    """
    Extracts the top N unique markdown file paths from the results.

    Args:
        results (List[Dict]): List of result dictionaries with 'path' and 'score' keys.
        top_n (int): Number of top unique files to return.

    Returns:
        List[str]: List of top N unique file paths.
    """
    seen = set()
    unique_files = []

    for item in results:
        path = item.get("path")
        score = item.get("score")
        if path and score is not None:
            file_name = os.path.basename(path)
            key = (file_name, score)
            if key not in seen:
                seen.add(key)
                unique_files.append(item)
                if len(unique_files) == top_n:
                    break

    return unique_files


print(len(results_list))
for result in results_list[:10]:
    # rprint(result)
    print(result['query'])
    pp.pprint(extract_top_unique_files(result['results'], 10))
# Out:
# 371
# Food Allergy
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/history-and-physical-examination-in-the-patient-with-possible-food-allergy.md',
#   'score': 11.593656134767937},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pediatrics/pediatric-allergy/history-and-physical-examination-in-the-patient-with-possible-food-allergy.md',
#   'score': 11.593480239683114},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/management-of-ige-mediated-food-allergy-an-overview.md',
#   'score': 11.592376503805076},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/diagnostic-evaluation-of-ige-mediated-food-allergy.md',
#   'score': 11.588274052453869},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pediatrics/pediatric-allergy/diagnostic-evaluation-of-ige-mediated-food-allergy.md',
#   'score': 11.588070276037094},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/food-allergy-and-food-intolerance/food-intolerance-and-food-allergy-in-adults-an-overview.md',
#   'score': 11.58242954298413},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/society-guidelines-in-allergy-and-immunology/society-guideline-links-food-allergy.md',
#   'score': 11.581320440313931},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pediatrics/pediatric-allergy/food-allergy-in-children-prevalence-natural-history-and-monitoring-for-resolution.md',
#   'score': 11.579138604149964},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/food-allergy-in-children-prevalence-natural-history-and-monitoring-for-resolution.md',
#   'score': 11.578853516143523},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/respiratory-manifestations-of-food-allergy.md',
#   'score': 11.578630448759634}]
# Allergic Rhinitis
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/allergic-rhinitis-clinical-manifestations-epidemiology-and-diagnosis.md',
#   'score': 16.89519530665197},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/relationships-between-rhinosinusitis-and-asthma.md',
#   'score': 16.852734466547656},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/chronic-nonallergic-rhinitis.md',
#   'score': 16.85014698499475},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/an-overview-of-rhinitis.md',
#   'score': 16.826220911374424},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/emergency-medicine-adult-and-pediatric/adult-medical-emergencies/pharmacotherapy-of-allergic-rhinitis.md',
#   'score': 16.80702929415648},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pediatrics/pediatric-allergy/pharmacotherapy-of-allergic-rhinitis.md',
#   'score': 16.80050366806164},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/rhinitis-and-sinusitis/complementary-and-alternative-therapies-for-allergic-rhinitis-and-conjunctivitis.md',
#   'score': 16.784155549105893},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/pathogenesis-of-allergic-rhinitis-rhinosinusitis.md',
#   'score': 16.77026184618181},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/society-guidelines-in-allergy-and-immunology/society-guideline-links-rhinitis.md',
#   'score': 16.712526266098845},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/subcutaneous-immunotherapy-scit-for-allergic-rhinoconjunctivitis-and-asthma-indications-and-efficacy.md',
#   'score': 16.69063460468847}]
# Hay Fever
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/subcutaneous-immunotherapy-scit-for-allergic-rhinoconjunctivitis-and-asthma-indications-and-efficacy.md',
#   'score': 12.941003174901612},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/pets-in-the-home-impact-on-allergic-disease.md',
#   'score': 12.175499254130303},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pulmonary-and-critical-care-medicine/asthma/epidemiology-of-asthma.md',
#   'score': 12.081090353068053},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/ear-nose-and-throat/environmental-allergies-in-adults-the-basics.md',
#   'score': 11.269393645698463},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/general-surgery/alimentary-tract-anorectal/prevention-and-management-of-perineal-complications-following-an-abdominal-perineal-resection.md',
#   'score': 11.028896588497924},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/ear-nose-and-throat/environmental-allergies-in-children-the-basics.md',
#   'score': 11.023865755261866},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pediatrics/pediatric-infectious-disease/fever-in-infants-and-children-pathophysiology-and-management.md',
#   'score': 10.929796713079494},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/primary-care-adult/primary-care-ent/nasal-obstruction-diagnosis-and-management.md',
#   'score': 10.917645385810433},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/hospital-medicine/hospital-pulmonary-critical-care-and-sleep-medicine/weaning-from-mechanical-ventilation-readiness-testing.md',
#   'score': 10.89596401008792},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/genodermatoses/netherton-syndrome.md',
#   'score': 10.864431523319901}]
# Drug Allergies
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/allergen-immunotherapy/sublingual-immunotherapy-beyond-the-basics.md',
#   'score': 11.512933815812236},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/drug-allergy/choice-of-antibiotics-in-penicillin-allergic-hospitalized-patients.md',
#   'score': 11.344530282007648},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/overview-of-skin-testing-for-ige-mediated-allergic-disease.md',
#   'score': 11.325697061559922},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/allergies-and-asthma/allergy-skin-testing-the-basics.md',
#   'score': 11.051559457433182},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/penicillin-allergy-immediate-reactions.md',
#   'score': 10.998505952096886},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/general-surgery/breast-disease/breast-cellulitis-and-other-skin-disorders-of-the-breast.md',
#   'score': 10.996615519248232},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/food-allergy-management-allergen-nonspecific-therapies.md',
#   'score': 10.974614919224082},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/senior-health/drug-allergy-the-basics.md',
#   'score': 10.933977454341104},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/drug-allergy/sulfonamide-allergy-in-hiv-uninfected-patients.md',
#   'score': 10.914965024151233},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/allergies-and-asthma/contrast-allergy-the-basics.md',
#   'score': 10.841592450992238}]
# Atopic Dermatitis
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/society-guidelines-in-allergy-and-immunology/society-guideline-links-atopic-dermatitis.md',
#   'score': 17.1380350120057},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/atopic-dermatitis-eczema-pathogenesis-clinical-manifestations-and-diagnosis.md',
#   'score': 17.134814216434812},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/evaluation-and-management-of-severe-refractory-atopic-dermatitis-eczema-in-adults.md',
#   'score': 17.128165193867627},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/role-of-allergy-in-atopic-dermatitis-eczema.md',
#   'score': 17.099015824652692},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/atopic-dermatitis-comorbidities-and-associated-diseases.md',
#   'score': 17.087990796937394},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/other-topics-in-allergy/management-of-severe-refractory-atopic-dermatitis-eczema-in-children.md',
#   'score': 17.04763255111853},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/primary-care-adult/primary-care-dermatology/treatment-of-atopic-dermatitis-eczema.md',
#   'score': 17.037808295912864},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/other-topics-in-allergy/treatment-of-atopic-dermatitis-eczema.md',
#   'score': 17.031176206546103},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/overview-of-dermatitis-eczematous-dermatoses.md',
#   'score': 17.022274205337887},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/nummular-eczema.md',
#   'score': 17.01613555272746}]
# Eczema
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/chronic-hand-eczema.md',
#   'score': 9.80511122547399},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/acute-palmoplantar-eczema-dyshidrotic-eczema.md',
#   'score': 9.803410112202668},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/nummular-eczema.md',
#   'score': 9.782268517592257},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/overview-of-dermatitis-eczematous-dermatoses.md',
#   'score': 9.762488373695197},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/skin-hair-and-nails/eczema-atopic-dermatitis-the-basics.md',
#   'score': 9.757390486203768},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/eczema-herpeticum.md',
#   'score': 9.668769131449832},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/other-topics-in-allergy/prebiotics-and-probiotics-for-prevention-of-allergic-disease.md',
#   'score': 9.649495383239445},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/atopic-dermatitis-eczema-pathogenesis-clinical-manifestations-and-diagnosis.md',
#   'score': 9.646074534838661},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/society-guidelines-in-allergy-and-immunology/society-guideline-links-atopic-dermatitis.md',
#   'score': 9.614025763187689},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/evaluation-and-management-of-severe-refractory-atopic-dermatitis-eczema-in-adults.md',
#   'score': 9.606825397823897}]
# Contact Dermatitis
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/clinical-features-and-diagnosis-of-allergic-contact-dermatitis.md',
#   'score': 13.887111761882238},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/allergic-contact-dermatitis-in-children.md',
#   'score': 13.886471421033601},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/common-allergens-in-allergic-contact-dermatitis.md',
#   'score': 13.872487815656132},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/eyelid-dermatitis.md',
#   'score': 13.858287314139279},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/irritant-contact-dermatitis-in-adults.md',
#   'score': 13.857204703348032},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatologic-diagnosis/patch-testing.md',
#   'score': 13.844801066853227},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/allergy-and-immunology/pediatric-allergy/overview-of-dermatitis-eczematous-dermatoses.md',
#   'score': 13.83475795223287},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/family-medicine-and-general-practice/dermatitis/management-of-allergic-contact-dermatitis-in-adults.md',
#   'score': 13.831571380653159},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/obstetrics-gynecology-and-womens-health/office-gynecology/vulvar-dermatitis.md',
#   'score': 13.809879223588432},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/emergency-medicine-adult-and-pediatric/adult-environmental-emergencies/poison-ivy-toxicodendron-dermatitis.md',
#   'score': 13.77264704552442}]
# Ankylosing Spondylitis
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/spinal-disease-and-back-pain/clinical-manifestations-of-axial-spondyloarthritis-ankylosing-spondylitis-and-nonradiographic-axial-spondyloarthritis-in-adults.md',
#   'score': 22.77100484441162},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/spinal-disease-and-back-pain/treatment-of-axial-spondyloarthritis-ankylosing-spondylitis-and-nonradiographic-axial-spondyloarthritis-in-adults.md',
#   'score': 22.73164070636564},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/bones-joints-and-muscles/ankylosing-spondylitis-the-basics.md',
#   'score': 22.708822814781332},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/spinal-disease-and-back-pain/pathogenesis-of-spondyloarthritis.md',
#   'score': 22.61085278951034},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/spondyloarthropathies/overview-of-the-clinical-manifestations-and-classification-of-spondyloarthritis.md',
#   'score': 22.292644340345895},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pulmonary-and-critical-care-medicine/interstitial-lung-disease/chest-wall-diseases-and-restrictive-physiology.md',
#   'score': 22.01281010150881},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/rheumatoid-arthritis/spondyloarthritis-in-children.md',
#   'score': 21.909876272978398},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/osteoarthritis/diffuse-idiopathic-skeletal-hyperostosis-dish.md',
#   'score': 21.82120401805891},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/spondyloarthropathies/diagnosis-and-differential-diagnosis-of-axial-spondyloarthritis-ankylosing-spondylitis-and-nonradiographic-axial-spondyloarthritis-in-adults.md',
#   'score': 21.811430179428307},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/spondyloarthropathies/treatment-of-psoriatic-arthritis.md',
#   'score': 21.759742086057905}]
# Gout
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/crystal-diseases/gout-nonpharmacologic-strategies-for-prevention-and-treatment.md',
#   'score': 10.916101600302238},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/hospital-medicine/hospital-rheumatology/gout-clinical-manifestations-and-diagnosis.md',
#   'score': 10.915523326852012},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/nephrology-and-hypertension/kidney-transplant/hyperuricemia-and-gout-in-kidney-transplant-recipients.md',
#   'score': 10.889876170892457},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/bones-joints-and-muscles/gout-the-basics.md',
#   'score': 10.864383506672826},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/crystal-diseases/pathophysiology-of-gout.md',
#   'score': 10.861578746877777},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/crystal-diseases/pharmacologic-urate-lowering-therapy-and-treatment-of-tophi-in-patients-with-gout.md',
#   'score': 10.853059888749897},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/emergency-medicine-adult-and-pediatric/adult-medical-emergencies/gout-treatment-of-flares.md',
#   'score': 10.840630208830245},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/crystal-diseases/asymptomatic-hyperuricemia.md',
#   'score': 10.821205800291164},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/nephrology-and-hypertension/fluid-and-electrolytes/diuretic-induced-hyperuricemia-and-gout.md',
#   'score': 10.80477011844008},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/rheumatology/society-guidelines-in-rheumatology/society-guideline-links-gout-and-other-crystal-disorders.md',
#   'score': 10.751186335292713}]
# Guillain-Barre Syndrome
# [{'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/pediatric-neurology/guillain-barre-syndrome-in-children-epidemiology-clinical-features-and-diagnosis.md',
#   'score': 26.458532590914782},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/pulmonary-and-critical-care-medicine/critical-care-neurology/guillain-barre-syndrome-in-adults-treatment-and-prognosis.md',
#   'score': 26.449337109714886},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/neuromuscular-disease/guillain-barre-syndrome-in-adults-treatment-and-prognosis.md',
#   'score': 26.365807871881373},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/neuromuscular-disease/guillain-barre-syndrome-in-adults-pathogenesis-clinical-features-and-diagnosis.md',
#   'score': 26.01946029078649},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/pediatric-neurology/guillain-barre-syndrome-in-children-treatment-and-prognosis.md',
#   'score': 24.584910751716798},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/digestive-system/campylobacter-infection-the-basics.md',
#   'score': 23.321249784130416},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/pediatric-neurology/overview-of-acquired-peripheral-neuropathies-in-children.md',
#   'score': 23.021113839297612},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/neurology/neuropathies/immune-mediated-neuropathies.md',
#   'score': 22.507427597673228},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/gastroenterology-and-hepatology/gastrointestinal-infections/campylobacter-infection-clinical-manifestations-diagnosis-and-treatment.md',
#   'score': 21.88180502344828},
#  {'path': '/Users/vince/Salk/NeuroCircadia/data/uptodate/table-of-contents/patient-education/senior-health/weakness-the-basics.md',
#   'score': 21.594949001045222}]
