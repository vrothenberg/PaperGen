# %%
import os 
import pandas as pd

# %%
df = pd.read_excel("/Users/vince/Salk/PaperGeneration/data/Conditions.xlsx")
df
# Out:
#     Circadian                          Condition Disease type Priority  \
# 0         NaN                     Mosquito Bites        Bites      NaN
# 1         NaN                         Tick Bites        Bites      NaN
# 2         NaN                       Spider Bites        Bites      NaN
# 3         NaN                       Bedbug Bites        Bites      NaN
# 4         NaN                         Flea Bites        Bites      NaN
# ..        ...                                ...          ...      ...
# 266       NaN                         Strabismus       Vision      NaN
# 267       NaN                          Amblyopia       Vision      NaN
# 268       NaN  Visual Migraine (Ocular Migraine)       Vision      NaN
# 269       NaN                        Photophobia       Vision      NaN
# 270       NaN                           Floaters       Vision      NaN
#
#      References
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 266         NaN
# 267         NaN
# 268         NaN
# 269         NaN
# 270         NaN
#
# [271 rows x 5 columns]

# %%
from datetime import datetime
import logging 
import json


logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

output_dir = "/Users/vince/Salk/PaperGeneration/data/output"
filtered_dir = "/Users/vince/Salk/PaperGeneration/data/filtered_json"
os.makedirs(filtered_dir, exist_ok=True)

for i, row in df.iterrows():
    category = row['Disease type']
    condition = row['Condition']
    logger(f"[{i}] {condition} - {category}")

    # Create the directory path
    dir_path = os.path.join(output_dir, category.str.replace(' ', '_'))
    # Check if the directory exists
    if not os.path.exists(dir_path):
        # If it doesn't exist, skip 
        logger(f"Skipping. Does not exist: {dir_path}")
        continue

    # If directory exists, find most recent JSON files

    final_jsons = [f for f in os.listdir(dir_path) if "_final_" in f and f.endswith(".json")]
    uptodate_jsons = [f for f in os.listdir(dir_path) if "_uptodate_" in f and f.endswith(".json")]

    # Find the latest final JSON
    latest_final_json = None
    latest_final_time = None

    for f in final_jsons:
        try:
            dt = datetime.strptime(f.split('_')[-2] + ' ' + f.split('_')[-1].split('.json')[0], '%Y%m%d %H%M%S')
            if latest_final_time is None or dt > latest_final_time:
                latest_final_time = dt
                latest_final_json = f
        except ValueError as e:
            logger(f"Error parsing filename {f}: {e}")
            continue

        # Find the latest papers JSON
    latest_uptodate_json = None
    latest_uptodate_time = None

    for f in uptodate_jsons:
        try:
            dt = datetime.strptime(f.split('_')[-2] + ' ' + f.split('_')[-1].split('.json')[0], '%Y%m%d %H%M%S')
            if latest_uptodate_time is None or dt > latest_uptodate_time:
                latest_uptodate_time = dt
                latest_uptodate_json = f
        except ValueError as e:
            logger.error(f"Error parsing filename {f}: {e}")
            continue

    # Check if latest_final_json is valid, if so store in filtered_dir
    try:
        with open(latest_final_json, 'r') as f:
            final_data = json.load(f)
        final_data["category"] = category
        # Output to filtered_dir
        with open(os.path.join(filtered_dir, latest_final_json), 'w') as f:
            json.dump(final_data, f)
    except Exception as e:
        logger.error(f"Error on {latest_final_json}")
        logger.error(e)
        continue

    # Check if latest_uptodate_json is valid, if so store in filtered_dir
# Out:
# 0 Mosquito Bites Bites
# 1 Tick Bites Bites
# 2 Spider Bites Bites
# 3 Bedbug Bites Bites
# 4 Flea Bites Bites
# 5 Horsefly Bites Bites
# 6 Ant Bites Bites
# 7 Anemia Blood
# 8 Stroke Brain
# 9 Anxiety Brain Health
# 10 Bipolar syndrome Brain Health
# 11 PTSD Brain Health
# 12 Postpartum depression Brain Health
# 13 Autism Brain Health
# 14 Autism Spectrum Disorder Brain Health
# 15 Asperger's Syndrome Brain Health
# 16 ADHD Brain Health
# 17 Seasonal Affective Disorders Brain Health
# 18 ICU delirium Brain Health
# 19 Panic disorder Brain Health
# 20 Loneliness Brain Health
# 21 Lung cancer Cancer
# 22 Prostate cancer Cancer
# 23 Colorectal cancer Cancer
# 24 Liver cancer Cancer
# 25 Breast cancer Cancer
# 26 Cervical Cancer Cancer
# 27 Ovarian Cancer Cancer
# 28 Melanoma Cancer
# 29 Squamous Cell Carcinoma Cancer
# 30 Basal Cell Carcinoma Cancer
# 31 Pneumonia Cold
# 32 Bronchitis Cold
# 33 Influenza Cold
# 34 Sinus Infections Cold
# 35 Common Cold Cold
# 36 Cavities (Tooth Decay) Dental
# 37 Gingivitis Dental
# 38 Periodontitis Dental
# 39 Wisdom Teeth Issues Dental
# 40 Tooth Sensitivity Dental
# 41 Bad Breath (Halitosis) Dental
# 42 Dry Mouth (Xerostomia) Dental
# 43 Mouth Ulcers (Canker Sores) Dental
# 44 Dental Abscess Dental
# 45 Orthodontic Problems (Post-Braces) Dental
# 46 Gastroesophageal Reflux Disease (GERD) Digestive
# 47 Gallbladder Disease Digestive
# 48 Colitis Digestive
# 49 Irritable Bowel Syndrome (IBS) Digestive
# 50 Inflammatory Bowel Disease (IBD) Digestive
# 51 Celiac Disease Digestive
# 52 Gallbladder Disease Digestive
# 53 Pancreatitis Digestive
# 54 Crohn’s disease (intestinal inflammation) Digestive
# 55 Diverticulitis Digestive
# 56 Peptic Ulcers Digestive
# 57 Esophagitis Digestive
# 58 Barrett’s Esophagus Digestive
# 59 Gastritis Digestive
# 60 Small Intestinal Bacterial Overgrowth (SIBO) Digestive
# 61 Constipation Digestive
# 62 Diarrhea Digestive
# 63 Hemorrhoids Digestive
# 64 Anal Fissures Digestive
# 65 Gastroparesis Digestive
# 66 Functional Dyspepsia Digestive
# 67 Gastroenteritis Digestive
# 68 Clostridioides difficile (C. diff) Infection Digestive
# 69 Lactose Intolerance Digestive
# 70 Zollinger-Ellison Syndrome Digestive
# 71 Food Allergies Digestive
# 72 Hypothyroidism Endocrine
# 73 Hyperthyroidism Endocrine
# 74 Fibromyalgia Fatigue
# 75 Chronic fatigue syndrome Fatigue
# 76 Post-Covid syndrome Fatigue
# 77 Post-Covid syndrome Fatigue
# 78 POTS Fatigue
# 79 Mononucleosis Fatigue
# 80 Premenstrual Syndrome (PMS) Female
# 81 Premenstrual Dysphoric Disorder (PMDD) Female
# 82 Menopause-Related Conditions Female
# 83 Infertility Female
# 84 Menstrual Disorders Female
# 85 Endometriosis Female
# 86 Polycystic Ovary Syndrome (PCOS) Female
# 87 Urinary Tract Infections (UTIs) Female
# 88 Cystic Fibrosis Genetic
# 89 Alopecia Areata Hair
# 90 Postpartum Hair Loss Hair
# 91 PCOS-Related Hair Loss Hair
# 92 Hair Loss (Alopecia) Hair
# 93 Cardiac arrhythmia Heart
# 94 Heart failure Heart
# 95 Coronary artery disease Heart
# 96 Osteoarthritis Immune system
# 97 Rheumatoid arthritis Immune system
# 98 Osteopororsis Immune system
# 99 Systemic Lupus Erythematosus (SLE) Immune system
# 100 Gout Immune system
# 101 Sarcoidosis Immune system
# 102 Multiple Sclerosis Immune system
# 103 Guillain-Barré syndrome Immune system
# 104 Ankylosing spondylitis Immune system
# 105 Autoimmune thyroiditis (Hashimoto's) Immune system
# 106 Vasculitis Immune system
# 107 Appendicitis Immune system
# 108 Meningitis Immune system
# 109 Sepsis Immune system
# 110 Strep throat Immune system
# 111 Tonsillitis Immune system
# 112 HIV/AIDS Infectious diseases
# 113 Human Papillomavirus (HPV) Infection Infectious diseases
# 114 Lyme disease Infectious diseases
# 115 Tuberculosis Infectious diseases
# 116 Osteomyelitis (bone infection) Infectious diseases
# 117 Hepatitis B (HBV) Infectious diseases
# 118 Herpes Simplex Virus (HSV) Infectious diseases
# 119 Hepatitis C (HCV) Infectious diseases
# 120 Candidiasis (Yeast Infection) Infectious diseases
# 121 Chickenpox and Shingles Infectious diseases
# 122 Swimmer’s Ear (Otitis Externa) Infectious diseases
# 123 Conjuctivitis Infectious diseases
# 124 Cholecystitis Inflammation
# 125 Plantar Fasciitis Injuries
# 126 Bursitis Injuries
# 127 Hamstring Injuries Injuries
# 128 IT Band Syndrome Injuries
# 129 Shin Splints Injuries
# 130 Herniated Discs Injuries
# 131 Concussions Injuries
# 132 Tennis elbow (lateral epicondylitis) Injuries
# 133 Golfer's elbow (medial epicondylitis) Injuries
# 134 Spinal stenosis Injuries
# 135 Achilles Tendinitis or Rupture Injuries
# 136 Stress Fractures Injuries
# 137 Acute fractures Injuries
# 138 Rotator Cuff Tears Injuries
# 139 Labral Tears Injuries
# 140 Patellar Tendinitis Injuries
# 141 Medial Collateral Ligament (MCL) Injuries Injuries
# 142 Anterior Cruciate Ligament (ACL) Tears Injuries
# 143 Sprains and Strains Injuries
# 144 Frostbite Injuries
# 145 Burns Injuries
# 146 Ankle Sprains Injuries
# 147 Shoulder Dislocations Injuries
# 148 Overtraining Syndrome Injuries
# 149 Growth plate fracture Injuries
# 150 Sever’s disease Injuries
# 151 Overuse Injuries Injuries
# 152 Little League elbow Injuries
# 153 Little League shoulder Injuries
# 154 Osgood-Schlatter Disease Injuries
# 155 Osteochondritis Dissecans  Injuries
# 156 Spondylolysis and Spondylolisthesis Injuries
# 157 Torn Meniscus Injuries
# 158 Bruises Injuries
# 159 Patellofemoral pain Injuries
# 160 Overweight and Obesity Metabolic
# 161 Childhood overweight and obesity Metabolic
# 162 Prediabetes Metabolic
# 163 Type 2 diabetes Metabolic
# 164 Type 1 Diabetes Metabolic
# 165 Hypertension Metabolic
# 166 Metabolic syndrome Metabolic
# 167 Dyslipidemia Metabolic
# 168 Depression Metabolic
# 169 MASLD Metabolic
# 170 MASH Metabolic
# 171 Hepatitis Metabolic
# 172 Pulmonary Hypertension Metabolic
# 173 Chronic Kidney Disease (CKD) Metabolic
# 174 Alzheimer’s disease Neurodegenerative
# 175 Parkinson's Disease Neurodegenerative
# 176 Interstitial Cystitis Pain
# 177 Migraine Pain
# 178 Tension headache Pain
# 179 Cluster Headache Pain
# 180 Trigeminal neuralgia Pain
# 181 Peripheral neuropathy (e.g., diabetic neuropathy) Pain
# 182 Postherpetic neuralgia (shingles pain) Pain
# 183 Sciatica (nerve root compression) Pain
# 184 Cervical radiculopathy (nerve pain in the neck) Pain
# 185 Lumbar radiculopathy (nerve pain in the lower back) Pain
# 186 Pelvic pain (e.g., sacroiliac joint dysfunction) Pain
# 187 Muscle cramps Pain
# 188 Carpal tunnel syndrome Pain
# 189 Scoliosis Pain
# 190 Vertigo Pain
# 191 Trichomoniasis Parasitic
# 192 Scabies Parasitic
# 193 Lice Infestation Parasitic
# 194 Chronic Obstructive Pulmonary Disease (COPD) Respiratory
# 195 Pulmonary Fibrosis Respiratory
# 196 Pneumoconiosis Respiratory
# 197 Pulmonary Embolism Respiratory
# 198 Occupational Lung Diseases Respiratory
# 199 Acute Respiratory Distress Syndrome (ARDS) Respiratory
# 200 Lung Abscess Respiratory
# 201 Chronic Cough Respiratory
# 202 Asthma Respiratory
# 203 Psoriasis Skin
# 204 Eczema (Atopic Dermatitis) Skin
# 205 Contact Dermatitis Skin
# 206 Seborrheic Dermatitis Skin
# 207 Hives (Urticaria) Skin
# 208 Rosacea Skin
# 209 Cellulitis Skin
# 210 Boils Skin
# 211 Warts Skin
# 212 Ringworm (Tinea) Skin
# 213 Athlete’s Foot (Tinea Pedis) Skin
# 214 Jock Itch (Tinea Cruris) Skin
# 215 Vitiligo Skin
# 216 Melasma Skin
# 217 Albinism Skin
# 218 Sun burn Skin
# 219 Acne Vulgaris Skin
# 220 Cystic Acne Skin
# 221 Folliculitis Skin
# 222 Scleroderma Skin
# 223 Actinic Keratosis Skin
# 224 Hyperhidrosis Skin
# 225 Keloids Skin
# 226 Skin Tags Skin
# 227 Keratosis Pilaris Skin
# 228 Ringworm (Tinea) Skin
# 229 Insomnia Sleep
# 230 Sleep Apnea Sleep
# 231 Non-24h sleep disorders Sleep
# 232 Familial advanced sleep phase syndrome Sleep
# 233 Delayed sleep phase syndrome Sleep
# 234 Central Sleep Apnea (CSA) Sleep
# 235 Shift Work Disorder: Sleep
# 236 Narcolepsy Sleep
# 237 Idiopathic Hypersomnia Sleep
# 238 Restless Legs Syndrome Sleep
# 239 Periodic Limb Movement Disorder (PLMD) Sleep
# 240 Sleep Bruxism Sleep
# 241 Sleepwalking Sleep
# 242 REM Sleep Behavior Disorder (RBD) Sleep
# 243 Night Terrors Sleep
# 244 Chlamydia STD
# 245 Gonorrhea STD
# 246 Syphilis STD
# 247 Bacterial Vaginosis (BV) STD
# 248 Myopia (Nearsightedness) Vision
# 249 Hyperopia (Farsightedness) Vision
# 250 Astigmatism Vision
# 251 Presbyopia Vision
# 252 Cataracts Vision
# 253 Age-Related Macular Degeneration (AMD) Vision
# 254 Glaucoma Vision
# 255 Dry Eye Syndrome Vision
# 256 Diabetic Retinopathy Vision
# 257 Retinal Detachment Vision
# 258 Retinitis Pigmentosa Vision
# 259 Macular Hole Vision
# 260 Conjunctivitis Vision
# 261 Keratitis Vision
# 262 Uveitis Vision
# 263 Blepharitis Vision
# 264 Corneal Abrasion Vision
# 265 Keratoconus Vision
# 266 Strabismus Vision
# 267 Amblyopia Vision
# 268 Visual Migraine (Ocular Migraine) Vision
# 269 Photophobia Vision
# 270 Floaters Vision
