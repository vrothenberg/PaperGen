# %%
import os 
import pandas as pd

# %%
df = pd.read_excel("/Users/vince/Salk/PaperGeneration/data/Conditions.xlsx")
df
# Out:
#     Circadian                          Condition Disease type Priority  \
# 0         NaN                     Mosquito Bites        Bites      NaN
# 1         NaN                         Tick Bites        Bites      NaN
# 2         NaN                       Spider Bites        Bites      NaN
# 3         NaN                       Bedbug Bites        Bites      NaN
# 4         NaN                         Flea Bites        Bites      NaN
# ..        ...                                ...          ...      ...
# 266       NaN                         Strabismus       Vision      NaN
# 267       NaN                          Amblyopia       Vision      NaN
# 268       NaN  Visual Migraine (Ocular Migraine)       Vision      NaN
# 269       NaN                        Photophobia       Vision      NaN
# 270       NaN                           Floaters       Vision      NaN
#
#      References
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 266         NaN
# 267         NaN
# 268         NaN
# 269         NaN
# 270         NaN
#
# [271 rows x 5 columns]

# %%
import os
from datetime import datetime
import logging 
import json
import shutil
import string

def sanitize_filename(filename):
  valid_chars = "-_.() %s%s" % (string.ascii_letters, string.digits)
  return ''.join(c for c in filename if c in valid_chars)

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

output_dir = "/Users/vince/Salk/PaperGeneration/data/output"
filtered_dir = "/Users/vince/Salk/PaperGeneration/data/filtered_json"
os.makedirs(filtered_dir, exist_ok=True)

command_dir = "/home/vrothenberg_salk_edu/wagtail/data/filtered_json"

# This will store the commands
commands = []

for i, row in df.iterrows():
    category = row['Disease type']
    condition = row['Condition']
    logger.info(f"[{i}] {condition} - {category}")

    # Create the directory path
    dir_path = os.path.join(output_dir, condition.replace(' ', '_'))
    # Check if the directory exists
    if not os.path.exists(dir_path):
        # If it doesn't exist, skip 
        logger.info(f"Skipping. Does not exist: {dir_path}")
        continue

    # If directory exists, find most recent JSON files
    final_jsons = [f for f in os.listdir(dir_path) if "_final_" in f and f.endswith(".json")]
    uptodate_jsons = [f for f in os.listdir(dir_path) if "_uptodate_" in f and f.endswith(".json")]

    # Find the latest final JSON
    latest_final_json = None
    latest_final_time = None

    for f in final_jsons:
        try:
            dt = datetime.strptime(f.split('_')[-2] + ' ' + f.split('_')[-1].split('.json')[0], '%Y%m%d %H%M%S')
            if latest_final_time is None or dt > latest_final_time:
                latest_final_time = dt
                latest_final_json = f
        except ValueError as e:
            logger.error(f"Error parsing filename {f}: {e}")
            continue

    # Find the latest papers JSON
    latest_uptodate_json = None
    latest_uptodate_time = None

    for f in uptodate_jsons:
        try:
            dt = datetime.strptime(f.split('_')[-2] + ' ' + f.split('_')[-1].split('.json')[0], '%Y%m%d %H%M%S')
            if latest_uptodate_time is None or dt > latest_uptodate_time:
                latest_uptodate_time = dt
                latest_uptodate_json = f
        except ValueError as e:
            logger.error(f"Error parsing filename {f}: {e}")
            continue

    # Check if latest_final_json is valid, if so store in filtered_dir
    if latest_final_json:
        try:
            source_path = os.path.join(dir_path, latest_final_json)
            
            # Validate JSON by loading it
            with open(source_path, 'r') as f:
                json.load(f)  # This will raise an exception if the JSON is invalid

            # Sanitize the filename
            safe_filename = sanitize_filename(latest_final_json)
            destination_path = os.path.join(filtered_dir, safe_filename) 
            shutil.copy(source_path, destination_path)

            command_path = os.path.join(command_dir, safe_filename) 

            # Add the command for this file
            command = f"python manage.py import_articles --category-name \"{category}\" --json-path \"{command_path}\""
            commands.append(command)

        except json.JSONDecodeError as e:
            logger.error(f"Invalid JSON format in {latest_final_json}: {e}")
        except Exception as e:
            logger.error(f"Error on {latest_final_json}")
            logger.error(e)
            continue

    # Check if latest_uptodate_json is valid, if so store in filtered_dir
    elif latest_uptodate_json:
        try:
            source_path = os.path.join(dir_path, latest_uptodate_json)
            
            # Validate JSON by loading it
            with open(source_path, 'r') as f:
                json.load(f)  # This will raise an exception if the JSON is invalid

            # Sanitize the filename
            safe_filename = sanitize_filename(latest_uptodate_json)
            destination_path = os.path.join(filtered_dir, safe_filename)
            shutil.copy(source_path, destination_path)

            command_path = os.path.join(command_dir, safe_filename)

            # Add the command for this file (if you want to upload these files too)
            command = f"python manage.py import_articles --category-name \"{category}\" --json-path \"{command_path}\""
            commands.append(command) 

        except json.JSONDecodeError as e:
            logger.error(f"Invalid JSON format in {latest_uptodate_json}: {e}")
        except Exception as e:
            logger.error(f"Error on {latest_uptodate_json}")
            logger.error(e)
            continue

    else:
        print(f"No valid JSON found for {condition}")
        continue

# Print or save the commands
for command in commands:
    print(command)

# You can save the commands to a file if you want to execute them later
with open('import_commands.sh', 'w') as f:
    for command in commands:
        f.write(command + '\n')
# Out:
# 2024-12-18 15:14:48,717 - INFO - [0] Mosquito Bites - Bites
# 2024-12-18 15:14:48,733 - INFO - [1] Tick Bites - Bites
# 2024-12-18 15:14:48,734 - INFO - [2] Spider Bites - Bites
# 2024-12-18 15:14:48,735 - INFO - [3] Bedbug Bites - Bites
# 2024-12-18 15:14:48,736 - INFO - [4] Flea Bites - Bites
# 2024-12-18 15:14:48,738 - INFO - [5] Horsefly Bites - Bites
# 2024-12-18 15:14:48,739 - INFO - [6] Ant Bites - Bites
# 2024-12-18 15:14:48,741 - INFO - [7] Anemia - Blood
# 2024-12-18 15:14:48,742 - INFO - [8] Stroke - Brain
# 2024-12-18 15:14:48,743 - INFO - [9] Anxiety - Brain Health
# 2024-12-18 15:14:48,744 - INFO - [10] Bipolar syndrome - Brain Health
# 2024-12-18 15:14:48,746 - INFO - [11] PTSD - Brain Health
# 2024-12-18 15:14:48,746 - ERROR - Invalid JSON format in PTSD_final_20241218_112817.json: Expecting value: line 1 column 1 (char 0)
# 2024-12-18 15:14:48,747 - INFO - [12] Postpartum depression - Brain Health
# 2024-12-18 15:14:48,748 - INFO - [13] Autism - Brain Health
# 2024-12-18 15:14:48,749 - ERROR - Invalid JSON format in Autism_final_20241218_113326.json: Expecting value: line 1 column 1 (char 0)
# 2024-12-18 15:14:48,749 - INFO - [14] Autism Spectrum Disorder - Brain Health
# 2024-12-18 15:14:48,751 - INFO - [15] Asperger's Syndrome - Brain Health
# 2024-12-18 15:14:48,751 - ERROR - Invalid JSON format in Asperger's_Syndrome_final_20241218_113044.json: Expecting value: line 1 column 1 (char 0)
# 2024-12-18 15:14:48,752 - INFO - [16] ADHD - Brain Health
# 2024-12-18 15:14:48,753 - INFO - [17] Seasonal Affective Disorders - Brain Health
# 2024-12-18 15:14:48,754 - INFO - [18] ICU delirium - Brain Health
# 2024-12-18 15:14:48,756 - INFO - [19] Panic disorder - Brain Health
# 2024-12-18 15:14:48,757 - INFO - [20] Loneliness - Brain Health
# 2024-12-18 15:14:48,758 - INFO - [21] Lung cancer - Cancer
# 2024-12-18 15:14:48,759 - INFO - [22] Prostate cancer - Cancer
# 2024-12-18 15:14:48,760 - INFO - [23] Colorectal cancer - Cancer
# 2024-12-18 15:14:48,760 - ERROR - Invalid JSON format in Colorectal_cancer_final_20241218_113509.json: Expecting value: line 1 column 1 (char 0)
# 2024-12-18 15:14:48
json"
# python manage.py import_articles --category-name "Digestive" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Lactose_Intolerance_final_20241218_120816.json"
# python manage.py import_articles --category-name "Digestive" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Zollinger-Ellison_Syndrome_final_20241218_121128.json"
# python manage.py import_articles --category-name "Digestive" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Food_Allergies_final_20241218_120839.json"
# python manage.py import_articles --category-name "Endocrine" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Hyperthyroidism_final_20241218_120821.json"
# python manage.py import_articles --category-name "Fatigue" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Fibromyalgia_final_20241218_120955.json"
# python manage.py import_articles --category-name "Fatigue" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Chronic_fatigue_syndrome_final_20241218_121217.json"
# python manage.py import_articles --category-name "Fatigue" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/POTS_final_20241218_121649.json"
# python manage.py import_articles --category-name "Fatigue" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Mononucleosis_final_20241218_122102.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Premenstrual_Syndrome_(PMS)_final_20241218_121444.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Premenstrual_Dysphoric_Disorder_(PMDD)_final_20241218_121521.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Menopause-Related_Conditions_final_20241218_121650.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Menstrual_Disorders_final_20241218_122131.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Endometriosis_final_20241218_122236.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Polycystic_Ovary_Syndrome_(PCOS)_final_20241218_122928.json"
# python manage.py import_articles --category-name "Female" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Urinary_Tract_Infections_(UTIs)_final_20241218_122024.json"
# python manage.py import_articles --category-name "Genetic" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Cystic_Fibrosis_final_20241218_122414.json"
# python manage.py import_articles --category-name "Hair" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Postpartum_Hair_Loss_final_20241218_122236.json"
# python manage.py import_articles --category-name "Hair" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/PCOS-Related_Hair_Loss_final_20241218_122728.json"
# python manage.py import_articles --category-name "Hair" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Hair_Loss_(Alopecia)_final_20241218_122924.json"
# python manage.py import_articles --category-name "Heart" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Cardiac_arrhythmia_final_20241218_122813.json"
# python manage.py import_articles --category-name "Heart" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Heart_failure_final_20241218_122923.json"
# python manage.py import_articles --category-name "Heart" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Coronary_artery_disease_final_20241218_122755.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Osteoarthritis_final_20241218_122841.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Rheumatoid_arthritis_final_20241218_123312.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Osteopororsis_final_20241218_123334.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Systemic_Lupus_Erythematosus_(SLE)_final_20241218_123252.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Sarcoidosis_final_20241218_123457.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Multiple_Sclerosis_final_20241218_123739.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Guillain-Barr_syndrome_final_20241218_123947.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Ankylosing_spondylitis_final_20241218_123815.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Autoimmune_thyroiditis_(Hashimotos)_final_20241218_123712.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Vasculitis_final_20241218_123604.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Appendicitis_final_20241218_123904.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Meningitis_final_20241218_124149.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Sepsis_final_20241218_124054.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Strep_throat_final_20241218_123940.json"
# python manage.py import_articles --category-name "Immune system" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Tonsillitis_final_20241218_124205.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Human_Papillomavirus_(HPV)_Infection_final_20241218_124255.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Lyme_disease_final_20241218_124305.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Tuberculosis_final_20241218_124249.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Osteomyelitis_(bone_infection)_final_20241218_124525.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Hepatitis_B_(HBV)_final_20241218_124442.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Herpes_Simplex_Virus_(HSV)_final_20241218_124520.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Hepatitis_C_(HCV)_final_20241218_125448.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Chickenpox_and_Shingles_final_20241218_124658.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Swimmers_Ear_(Otitis_Externa)_final_20241218_124657.json"
# python manage.py import_articles --category-name "Infectious diseases" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Conjuctivitis_final_20241218_124948.json"
# python manage.py import_articles --category-name "Inflammation" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Cholecystitis_final_20241218_125019.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Plantar_Fasciitis_final_20241218_125238.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Bursitis_final_20241218_125345.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Hamstring_Injuries_final_20241218_125206.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/IT_Band_Syndrome_final_20241218_125236.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/Shin_Splints_final_20241218_125421.json"
# python manage.py import_articles --category-name "Injuries" --json-path "/home/vrothenberg_salk_edu/wagtail/data/filtered_json/