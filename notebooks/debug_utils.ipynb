# %%
import sys
import os
import json


# Load the autoreload extension
# %load_ext autoreload

# Set autoreload mode to reload all modules before executing each cell
# %autoreload 2

# Get the absolute path to the parent directory
parent_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the parent directory to sys.path
if parent_path not in sys.path:
    sys.path.append(parent_path)

from src.utils import (
    save_results,
    sanitize_filename,
    remove_duplicates,
    extract_citations,
    parse_reference,
    identify_bad_references,
    remove_references,
    remove_inline_citations,
    create_remap_dictionary,
    update_reference_numbers,
    update_inline_citations,
    check_for_duplicate_references,
    find_orphan_references
)

from src.models import Article
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# File path to your JSON data
json_file_path = "/Users/vince/Salk/PaperGeneration/data/output/gemini-2.0-flash-exp/Liver_Cancer/Liver_Cancer_sourced_remapped_20250117_082937.json"

with open(json_file_path, 'r') as f:
    article_data = json.load(f)

# %%
from rich import print as rprint
article = Article.model_validate(article_data)  # Create an Article instance
article
# Out:
# Article(title='Systemic Lupus Erythematosus', subtitle='A chronic autoimmune disease causing widespread inflammation and tissue damage.', overview=OverviewSection(heading='Overview', content="Systemic Lupus Erythematosus (SLE), often referred to as lupus, is a complex autoimmune disease where the body's immune system mistakenly attacks its own tissues and organs. This can lead to inflammation and damage in various parts of the body. It is a chronic condition with periods of flare-ups and remissions. SLE affects women more often than men, and while it can occur at any age, it is most commonly diagnosed in individuals between the ages of 15 and 45. It’s estimated that around 1.5 million Americans have some form of lupus. The severity of the disease can vary widely, from mild to life-threatening, depending on the organs involved.  The prevalence of SLE is highest in North America, with estimates of 241 per 100,000 people [46]. Atherosclerosis also occurs prematurely in patients with SLE, independent of traditional cardiovascular risk factors [47]."), key_facts=KeyFactsSection(heading='Key Facts', content=['SLE is an autoimmune disease where the immune system attacks healthy tissues.', 'It can affect many different parts of the body including joints, skin, kidneys, blood cells, brain, heart and lungs.', 'Women are more likely to be diagnosed with lupus than men.', 'The exact cause of SLE is not fully understood.', 'SLE is a chronic disease with periods of flare-ups and remissions.', 'There is no cure for lupus but treatments can manage symptoms and reduce damage.', 'The development of autoimmune diseases involves a genetic predisposition and environmental factors that trigger immune pathways [48].']), symptoms=SymptomsSection(heading='Symptoms', content=['Fatigue', 'Joint pain and swelling', 'Skin rashes, often a butterfly-shaped rash across the cheeks and nose', 'Fever', 'Sensitivity to sunlight', 'Hair loss', 'Mouth ulcers', 'Chest pain', 'Shortness of breath', 'Swollen lymph nodes', 'Weight loss or weight gain', 'Systemic lupus erythematosus can manifest with a range of symptoms, including lymphoid hyperplasia, autoantibodies, and immune complex glomerulonephritis [49].']), types=TypesSection(heading='Types', content="While the term 'lupus' often refers to systemic lupus erythematosus (SLE), there are a few other related forms of lupus:\n\n### Systemic Lupus Erythematosus (SLE)\nThe most common and severe form of lupus, affecting multiple organs and systems.\n\n### Cutaneous Lupus Erythematosus\nPrimarily affects the skin. It can manifest in several forms including:\n\n#### Discoid Lupus\nCharacterized by disk-shaped lesions that can lead to scarring.\n\n#### Subacute Cutaneous Lupus\nCauses non-scarring skin lesions that are often sensitive to sunlight.\n\n### Drug-Induced Lupus\nA lupus-like condition triggered by certain medications. Symptoms usually resolve when the medication is stopped. Some medications like procainamide and hydralazine can induce autoreactivity and a lupus like disease [50].\n\n### Neonatal Lupus\nA rare condition affecting newborns of mothers with lupus, due to maternal antibodies. Usually resolves within six months.  Neonatal lupus is associated with maternal U1RNP antibodies [51]."), causes=CausesSection(heading='Causes', content='The exact cause of SLE is not fully understood; however, it is believed to be a combination of genetic, environmental, and hormonal factors. It is not a contagious condition. In individuals with SLE, the immune system produces autoantibodies that attack healthy tissues, causing inflammation and damage. This immune system dysfunction is likely triggered by a complex interplay of: \n\n* **Genetic Predisposition:** A family history of lupus or other autoimmune disorders increases the risk. Certain genes are known to be associated with SLE.  Specifically, HLA-DR2 and DQw1 genotypes have been associated with lower production of tumor necrosis factor (TNF)-alpha and increased susc ...

# %%
bad_references = identify_bad_references(article_data)
bad_references
# Out:
# set()

# %%
orphan_references = find_orphan_references(article_data)
rprint(orphan_references)
# Out:
# {
#     'title': 'Liver Cancer',
#     'subtitle': 'A malignant tumor arising from the liver cells.',
#     'overview': {
#         'heading': 'Overview',
#         'content': 'Liver cancer, also known as hepatic cancer, is a malignancy that originates in the liver. It is
# a significant health concern worldwide and is often diagnosed at advanced stages. Primary liver cancer arises from
# the liver cells themselves, while secondary liver cancer occurs when cancer from other parts of the body spreads to
# the liver. The prognosis and treatment options vary greatly depending on the type and stage at diagnosis. Globally,
# it is among the leading causes of cancer-related deaths [1,2]. In 2022, there were approximately 20 million new
# cancer cases worldwide, with liver cancer accounting for 7.8% of cancer-related deaths [3]. '
#     },
#     'key_facts': {
#         'heading': 'Key Facts',
#         'content': [
#             'Liver cancer is the most common type of cancer worldwide.',
#             'Hepatocellular carcinoma (HCC) is the most common type of primary liver cancer.',
#             'Chronic hepatitis B and C infections are major risk factors for developing liver cancer [4].',
#             'Liver cancer often presents with non-specific symptoms, which makes early detection difficult.',
#             'Survival rates for liver cancer vary greatly depending on the stage of diagnosis.',
#             'Surgical resection offers the greatest chance of cure for liver-isolated colorectal cancer [3].'
#         ]
#     },
#     'symptoms': {
#         'heading': 'Symptoms',
#         'content': [
#             'Abdominal pain or discomfort, particularly in the upper right quadrant',
#             'Unexplained weight loss',
#             'Loss of appetite or feeling full quickly',
#             'Nausea and vomiting',
#             'Jaundice (yellowing of the skin and eyes)',
#             'Swelling or fluid build-up in the abdomen (ascites)',
#             'Enlarged liver or spleen',
#             'Fatigue and weakness'
#         ]
#     },
#     'types': {
#         'heading': 'Types',
#         'content': 'Liver cancer can be broadly classified into primary and secondary types.\n\n### Primary Liver
# Cancer\n\nPrimary liver cancer originates in the liver itself.\n\n#### Hepatocellular Carcinoma (HCC)\nHCC is the
# most common type of primary liver cancer, arising from the hepatocytes, the main liver cells [5].\n\n####
# Cholangiocarcinoma (Intrahepatic)\nIntrahepatic cholangiocarcinoma arises from the bile ducts within the liver. The
# incidence of intrahepatic cholangiocarcinoma has been rising in the US [6].\n\n#### Hepatoblastoma\nHepatoblastoma
# is a rare type of liver cancer that primarily affects children [7].\n\n### Secondary Liver Cancer\n\nSecondary
# liver cancer occurs when cancer from another part of the body spreads to the liver (metastasis). Common sources
# include colon, lung and breast cancer. Liver metastases from colon cancer are associated with increased expression
# of vascular endothelial growth factor (VEGF) [8].'
#     },
#     'causes': {
#         'heading': 'Causes',
#         'content': 'The exact causes of liver cancer are complex and often involve multiple factors. However,
# several major causes and associations have been identified:\n\n*   **Chronic Viral Hepatitis:** Chronic infections
# with hepatitis B and C viruses are significant risk factors for HCC [9]. Hepatitis B is responsible for 33% of
# liver cancer deaths worldwide [9].\n*   **Cirrhosis:** Long-term damage to the liver, often due to alcohol abuse or
# chronic hepatitis, leads to cirrhosis, which can increase cancer risk [10].\n*   **Non-Alcoholic Fatty Liver
# Disease (NAFLD):** This condition, often linked to obesity and diabetes, can cause inflammation and damage to the
# liver, increasing the risk of liver cancer [11].\n*   **Aflatoxins:** Exposure to aflatoxins, which are toxins
# produced by certain molds that can contaminate food, can increase the risk [12].\n*   **Genetic Conditions:**
# Certain genetic disorders, such as hemochromatosis, can also predispose individuals to liver cancer [13].'
#     },
#     'risk_factors': {
#         'heading': 'Risk Factors',
#         'content': [
#             'Chronic hepatitis B or C infection',
#             'Cirrhosis of the liver',
#             'Excessive alcohol consumption',
#             'Non-alcoholic fatty liver disease (NAFLD)',
#             'Exposure to aflatoxins',
#             'Family history of liver cancer',
#             "Certain inherited liver diseases such as hemochromatosis or Wilson's disease",
#             'Obesity and type 2 diabetes',
#             'Age (risk increases with age)'
#         ]
#     },
#     'diagnosis': {
#         'heading': 'Diagnosis',
#         'content': 'The diagnosis of liver cancer typically involves a combination of methods:\n\n### Physical
# Examination\n*   The doctor will perform a physical exam, feeling for an enlarged liver or any other
# abnormalities.\n\n### Blood Tests\n*   Liver function tests (LFTs) measure enzymes and other substances to assess
# liver health.\n*   Alpha-fetoprotein (AFP) test is a tumor marker that can be elevated in some cases of liver
# cancer [14].\n*   Viral hepatitis tests are performed to identify hepatitis B or C.\n\n### Imaging Tests\n*
# **Ultrasound:** An initial imaging method to visualize the liver.\n*   **CT Scan:** Provides detailed
# cross-sectional images of the liver.\n*   **MRI:** Offers another detailed view of the liver, often used for
# further characterization of lesions. MRI is often preferred over CT scans for liver imaging because of its
# sensitivity in detecting additional lesions [16].\n\n### Liver Biopsy\n*   A small sample of liver tissue is taken
# for microscopic examination to confirm the presence of cancer cells. Liver stiffness measurement using transient
# elastography is a noninvasive method that can detect significant fibrosis or cirrhosis, which can inform the
# decision to biopsy [15].\n\n### Staging\n* Once diagnosed, staging is performed to determine the extent of the
# cancer and guide treatment decisions.'
#     },
#     'prevention': {
#         'heading': 'Prevention',
#         'content': [
#             'Vaccination against hepatitis B [17]',
#             'Screening and treatment for chronic hepatitis B and C infections',
#             'Limiting alcohol consumption',
#             'Maintaining a healthy weight and managing diabetes',
#             'Avoiding exposure to aflatoxins by ensuring proper food storage',
#             'Regular check-ups and screenings, especially for high-risk individuals'
#         ]
#     },
#     'specialist_to_visit': {
#         'heading': 'Specialist to Visit',
#         'content': 'Several specialists may be involved in the diagnosis and treatment of liver cancer:\n\n*
# **Hepatologist:** A doctor specializing in liver diseases.\n*   **Oncologist:** A doctor specializing in cancer
# treatment, including medical oncology, radiation oncology, and surgical oncology.\n*   **Interventional
# Radiologist:** A doctor who uses imaging techniques to perform procedures such as biopsies and tumor ablations.\n*
# **Surgeon:** Specializes in performing liver surgery, which may include tumor removal or liver transplantation.'
#     },
#     'treatment': {
#         'heading': 'Treatment',
#         'content': "Treatment for liver cancer depends on the stage, size, location, and type of cancer, as well as
# the patient's overall health. Common treatments include:\n\n*   **Surgery:** Resection involves removing the
# cancerous part of the liver. Liver transplant is an option in select cases. \n*   **Ablation Therapies:**  These
# include radiofrequency ablation (RFA), microwave ablation, and cryoablation that use heat, microwaves or freezing
# to destroy cancer cells. For RFA, tumors less than 3 cm and margins greater than 5 mm are associated with better
# outcomes [18].\n*   **Radiation Therapy:** High-energy rays are used to target and kill cancer cells.\n*
# **Chemotherapy:** Medications are used to kill cancer cells or slow their growth.\n*   **Targeted Therapy:** Drugs
# that target specific molecules involved in cancer cell growth.\n*  **Immunotherapy:** Stimulates the body’s immune
# system to fight cancer cells. Immunotherapies may be less effective in patients with liver metastases [19].\n*
# **Transarterial Chemoembolization (TACE):** A procedure that blocks the blood supply to tumors and delivers
# chemotherapy directly to the liver. This is used in cases where surgery is not an option. Superselective
# conventional TACE is recommended as a first choice for suitable patients [20].\n\nFor patients with colorectal
# cancer that has spread to the liver, surgical removal of the liver metastases is an option. When the metastases
# cannot be removed surgically, other treatments include ablation and chemotherapy [1,2]."
#     },
#     'home_care': {
#         'heading': 'Home-Care',
#         'content': [
#             'Follow the treatment plan prescribed by the healthcare team',
#             'Maintain a balanced and nutritious diet to support liver function',
#             'Stay hydrated and avoid alcohol consumption',
#             'Manage pain and other symptoms with medications as directed',
#             'Get adequate rest and avoid strenuous activities',
#             'Engage in light physical activity as tolerated',
#             'Seek emotional support and consider counseling'
#         ]
#     },
#     'living_with': {
#         'heading': 'Living With',
#         'content': 'Living with liver cancer can be challenging. It is important to manage the condition with a
# holistic approach:\n\n*   **Medical Management:** Follow up regularly with doctors and adhere to prescribed
# treatment plans.\n*   **Lifestyle Adjustments:** Maintain a healthy diet, avoid alcohol, manage stress, and engage
# in regular low-impact physical activity as tolerated.\n*   **Emotional Well-being:** Seek support from family,
# friends, support groups, or mental health professionals to cope with the emotional burden.\n*   **Financial
# Planning:** Cancer treatment can be costly so exploring financial assistance programs might be necessary.\n*
# **Palliative Care:** When cancer is advanced, palliative care can provide relief from symptoms and improve quality
# of life.'
#     },
#     'complications': {
#         'heading': 'Complications',
#         'content': "Untreated or poorly managed liver cancer can lead to various complications:\n\n*   **Liver
# Failure:** The liver's inability to function properly, leading to jaundice, ascites, and other severe symptoms
# [21].\n*   **Metastasis:** Spread of cancer to other parts of the body, such as lungs, bones, or brain [22].\n*
# **Pain:** Can be severe and difficult to manage.\n*   **Bleeding:**  Liver dysfunction can affect blood clotting
# leading to bleeding complications.\n*   **Ascites:** Accumulation of fluid in the abdominal cavity, causing
# discomfort and difficulty breathing [23].\n*   **Encephalopathy:**  Liver dysfunction can result in build-up of
# toxins in the brain leading to cognitive impairment [23].\n*   **Weight loss and malnutrition**"
#     },
#     'alternative_therapies': {
#         'heading': 'Alternative Therapies',
#         'content': "Some patients explore alternative or complementary therapies to complement conventional
# treatment. It's vital to discuss these options with a healthcare provider as some may interact with conventional
# treatments, or may not have robust scientific evidence to support their use. Some commonly explored options include
# herbal medicine, acupuncture, meditation, and nutritional therapies. MRI-guided focused ultrasound (MRgFUS) is a
# non-invasive thermal ablation method that is being explored for liver cancer treatment [24]. Always consult with
# your oncologist before undertaking any alternative therapies."
#     },
#     'faqs': {
#         'heading': 'FAQs',
#         'content': [
#             {
#                 'question': 'What is the most common type of liver cancer?',
#                 'answer': 'The most common type of primary liver cancer is hepatocellular carcinoma (HCC).'
#             },
#             {
#                 'question': 'What are the main risk factors for developing liver cancer?',
#                 'answer': 'Main risk factors include chronic hepatitis B and C infections, liver cirrhosis,
# excessive alcohol consumption, and non-alcoholic fatty liver disease.'
#             },
#             {
#                 'question': 'Can liver cancer be cured?',
#                 'answer': 'Liver cancer can be cured if detected at an early stage and surgically removed or
# transplanted. However, advanced stages may be managed but not cured. Early detection is key.'
#             },
#             {
#                 'question': 'What is the survival rate for liver cancer?',
#                 'answer': 'Survival rates vary widely depending on the stage at diagnosis. Resection offers the
# greatest likelihood of cure for patients with liver-isolated colorectal cancer. Five-year survival rates after
# resection range from 24 to 58 percent, averaging 40 percent [3,4,5,6].'
#             },
#             {
#                 'question': 'What is a liver biopsy?',
#                 'answer': 'A liver biopsy involves taking a small sample of liver tissue for microscopic
# examination to confirm the presence of cancer cells. It is performed if imaging tests suggests cancer.'
#             },
#             {
#                 'question': 'Can liver cancer spread?',
#                 'answer': 'Yes, liver cancer can spread (metastasize) to other parts of the body, such as the
# lungs, bones, and brain.'
#             },
#             {
#                 'question': 'What is the role of chemotherapy in treating liver cancer?',
#                 'answer': "Chemotherapy is used to kill cancer cells or slow their growth. It can be used before
# surgery to shrink tumors or after surgery to eliminate remaining cancer cells. In some cases, it's the primary
# treatment if surgery is not an option."
#             },
#             {
#                 'question': 'When is liver transplantation considered?',
#                 'answer': "Liver transplantation is an option for some patients with early-stage liver cancer who
# meet specific criteria, including the absence of spread outside the liver. It's often considered if the cancer is
# unresectable."
#             },
#             {
#                 'question': 'Can a liver abscess be related to liver cancer?',
#                 'answer': 'Studies have indicated an association between pyogenic liver abscess and colorectal
# cancer [7,8,9,10,11,12,13,14,15].'
#             }
#         ]
#     },
#     'references': {
#         'heading': 'References',
#         'content': [
#             {
#                 'reference_number': 3,
#                 'authors': 'Fong Y, Fortner J, Sun RL, et al',
#                 'year': 1999,
#                 'title': 'Clinical score for predicting recurrence after hepatic resection for metastatic
# colorectal cancer: analysis of 1001 consecutive cases.',
#                 'journal_source': 'Ann Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 4,
#                 'authors': 'Nordlinger B, Guiguet M, Vaillant JC, et al',
#                 'year': 1996,
#                 'title': 'Surgical resection of colorectal carcinoma metastases to the liver. A prognostic scoring
# system to improve case selection, based on 1568 patients. Association Française de Chirurgie.',
#                 'journal_source': 'Cancer',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 5,
#                 'authors': 'Fernandez FG, Drebin JA, Linehan DC, et al',
#                 'year': 2004,
#                 'title': 'Five-year survival after resection of hepatic metastases from colorectal cancer in
# patients screened by positron emission tomography with F-18 fluorodeoxyglucose (FDG-PET).',
#                 'journal_source': 'Ann Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 6,
#                 'authors': 'Simmonds PC, Primrose JN, Colquitt JL, et al',
#                 'year': 2006,
#                 'title': 'Surgical resection of hepatic metastases from colorectal cancer: a systematic review of
# published studies.',
#                 'journal_source': 'Br J Cancer',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 1,
#                 'authors': 'Garden OJ, Rees M, Poston GJ, et al',
#                 'year': 2006,
#                 'title': 'Guidelines for resection of colorectal cancer liver metastases.',
#                 'journal_source': 'Gut',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 2,
#                 'authors': 'Petrelli NJ',
#                 'year': 2007,
#                 'title': 'Plenary program discussion.',
#                 'journal_source': '43rd Annual Meeting of the American Society of Clinical Oncology, Chicago, IL',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 7,
#                 'authors': 'Kao WY, Hwang CY, Chang YT, et al',
#                 'year': 2012,
#                 'title': 'Cancer risk in patients with pyogenic liver abscess: a nationwide cohort study.',
#                 'journal_source': 'Aliment Pharmacol Ther',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 8,
#                 'authors': 'Koo HC, Kim YS, Kim SG, et al',
#                 'year': 2013,
#                 'title': 'Should colonoscopy be performed in patients with cryptogenic liver abscess?',
#                 'journal_source': 'Clin Res Hepatol Gastroenterol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 9,
#                 'authors': 'Jeong SW, Jang JY, Lee TH, et al',
#                 'year': 2012,
#                 'title': 'Cryptogenic pyogenic liver abscess as the herald of colon cancer.',
#                 'journal_source': 'J Gastroenterol Hepatol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 10,
#                 'authors': 'Qu K, Liu C, Wang ZX, et al',
#                 'year': 2012,
#                 'title': 'Pyogenic liver abscesses associated with nonmetastatic colorectal cancers: an increasing
# problem in Eastern Asia.',
#                 'journal_source': 'World J Gastroenterol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 11,
#                 'authors': 'Huang WK, Chang JW, See LC, et al',
#                 'year': 2012,
#                 'title': 'Higher rate of colorectal cancer among patients with pyogenic liver abscess with
# Klebsiella pneumoniae than those without: an 11-year follow-up study.',
#                 'journal_source': 'Colorectal Dis',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 12,
#                 'authors': 'Lai HC, Lin CC, Cheng KS, et al',
#                 'year': 2014,
#                 'title': 'Increased incidence of gastrointestinal cancers among patients with pyogenic liver
# abscess: a population-based cohort study.',
#                 'journal_source': 'Gastroenterology',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 13,
#                 'authors': 'Mohan BP, Meyyur Aravamudan V, Khan SR, et al',
#                 'year': 2019,
#                 'title': 'Prevalence of colorectal cancer in cryptogenic pyogenic liver abscess patients. Do they
# need screening colonoscopy? A systematic review and meta-analysis.',
#                 'journal_source': 'Dig Liver Dis',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 14,
#                 'authors': 'Mezhir JJ, Fong Y, Jacks LM, et al',
#                 'year': 2010,
#                 'title': 'Current management of pyogenic liver abscess: surgery is now second-line treatment.',
#                 'journal_source': 'J Am Coll Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 15,
#                 'authors': 'Suzuki H, Kidder I, Tanaka T, Goto M',
#                 'year': 2023,
#                 'title': 'Incidence of Colorectal Cancer in Patients Diagnosed With Pyogenic Liver Abscess.',
#                 'journal_source': 'JAMA Netw Open',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 16,
#                 'authors': 'Adam R, Wicherts DA, de Haas RJ, et al',
#                 'year': 2008,
#                 'title': 'Complete pathologic response after preoperative chemotherapy for colorectal liver
# metastases: myth or reality?',
#                 'journal_source': 'J Clin Oncol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 17,
#                 'authors': 'Mei-Hwei Chang, Chien-Jen Chen, M. Lai',
#                 'year': 1997,
#                 'title': 'Universal hepatitis B vaccination in Taiwan and the incidence of hepatocellular carcinoma
# in children. Taiwan Childhood Hepatoma Study Group.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.nejm.org/doi/pdf/10.1056/NEJM199706263362602?articleTools=true'
#             },
#             {
#                 'reference_number': 18,
#                 'authors': 'Waleed Shady, E. Petre, M. Gonen',
#                 'year': 2016,
#                 'title': 'Percutaneous Radiofrequency Ablation of Colorectal Cancer Liver Metastases: Factors
# Affecting Outcomes--A 10-year Experience at a Single Center.',
#                 'journal_source': 'Radiology',
#                 'url_doi': 'https://europepmc.org/articles/pmc4734163?pdf=render'
#             },
#             {
#                 'reference_number': 19,
#                 'authors': 'James C. Lee, Sadaf Mehdizadeh, Jennifer Smith',
#                 'year': 2020,
#                 'title': 'Regulatory T cell control of systemic immunity and immunotherapy response in liver
# metastasis',
#                 'journal_source': 'Science immunology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/d437e62cf94487ebc1bfc9ff6f2b0f6287616d07'
#             },
#             {
#                 'reference_number': 20,
#                 'authors': 'M. Kudo, K. Han, S. Ye',
#                 'year': 2020,
#                 'title': 'A Changing Paradigm for the Treatment of Intermediate-Stage Hepatocellular Carcinoma:
# Asia-Pacific Primary Liver Cancer Expert Consensus Statements',
#                 'journal_source': 'Liver Cancer',
#                 'url_doi': 'https://www.karger.com/Article/Pdf/507370'
#             },
#             {
#                 'reference_number': 21,
#                 'authors': 'M. Kudo, O. Matsui, N. Izumi',
#                 'year': 2014,
#                 'title': 'JSH Consensus-Based Clinical Practice Guidelines for the Management of Hepatocellular
# Carcinoma: 2014 Update by the Liver Cancer Study Group of Japan',
#                 'journal_source': 'Liver Cancer',
#                 'url_doi': 'https://www.karger.com/Article/Pdf/343875'
#             },
#             {
#                 'reference_number': 22,
#                 'authors': 'A. Studebaker, G. Storci, J. Werbeck',
#                 'year': 2008,
#                 'title': 'Fibroblasts isolated from common sites of breast cancer metastasis enhance cancer cell
# growth rates and invasiveness in an interleukin-6-dependent manner.',
#                 'journal_source': 'Cancer Research',
#                 'url_doi':
# 'https://figshare.com/articles/journal_contribution/Supplementary_Figure_1_from_Fibroblasts_Isolated_from_Common_Si
# tes_of_Breast_Cancer_Metastasis_Enhance_Cancer_Cell_Growth_Rates_and_Invasiveness_in_an_Interleukin-6_Dependent_Man
# ner/22374389/1/files/39819623.pdf'
#             },
#             {
#                 'reference_number': 23,
#                 'authors': 'A. Sanyal, M. V. Van Natta, J. Clark',
#                 'year': 2021,
#                 'title': 'Prospective Study of Outcomes in Adults with Nonalcoholic Fatty Liver Disease.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.nejm.org/doi/pdf/10.1056/NEJMoa2029349?articleTools=true'
#             },
#             {
#                 'reference_number': 24,
#                 'authors': 'F. Jolesz',
#                 'year': 2007,
#                 'title': 'MRI-guided focused ultrasound surgery.',
#                 'journal_source': 'Annual Review of Medicine',
#                 'url_doi': 'https://europepmc.org/articles/pmc4005559?pdf=render'
#             },
#             {
#                 'reference_number': 25,
#                 'authors': 'H. Sung, J. Ferlay, R. Siegel',
#                 'year': 2021,
#                 'title': 'Global Cancer Statistics 2020: GLOBOCAN Estimates of Incidence and Mortality Worldwide
# for 36 Cancers in 185 Countries',
#                 'journal_source': 'Ca',
#                 'url_doi': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21660'
#             },
#             {
#                 'reference_number': 26,
#                 'authors': 'H. El‐Serag, K. Rudolph',
#                 'year': 2007,
#                 'title': 'Hepatocellular carcinoma: epidemiology and molecular carcinogenesis.',
#                 'journal_source': 'Gastroenterology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/02c5864e3ba848b7b4db6a0f4a2c2fe73e92a3b1'
#             },
#             {
#                 'reference_number': 27,
#                 'authors': 'P. Cacoub, C. Comarmond, F. Domont',
#                 'year': 2016,
#                 'title': 'Extrahepatic manifestations of chronic hepatitis C virus infection',
#                 'journal_source': 'Therapeutic Advances in Infectious Disease',
#                 'url_doi': 'https://europepmc.org/articles/pmc4735500?pdf=render'
#             },
#             {
#                 'reference_number': 28,
#                 'authors': 'J. Bruix, M. Reig, M. Sherman',
#                 'year': 2016,
#                 'title': 'Evidence-Based Diagnosis, Staging, and Treatment of Patients With Hepatocellular
# Carcinoma.',
#                 'journal_source': 'Gastroenterology',
#                 'url_doi': 'http://www.gastrojournal.org/article/S001650851600007X/pdf'
#             },
#             {
#                 'reference_number': 29,
#                 'authors': 'Y. Kurebayashi, H. Ojima, Hanako Tsujikawa',
#                 'year': 2018,
#                 'title': 'Landscape of immune microenvironment in hepatocellular carcinoma and its additional
# impact on histological and molecular classification',
#                 'journal_source': 'Hepatology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/d150e6d703abf10615ad1761db9b2f0d7bf1230e'
#             },
#             {
#                 'reference_number': 30,
#                 'authors': 'Supriya K. Saha, A. Zhu, C. Fuchs',
#                 'year': 2016,
#                 'title': 'Forty-Year Trends in Cholangiocarcinoma Incidence in the U.S.: Intrahepatic Disease on
# the Rise',
#                 'journal_source': 'The Oncologist',
#                 'url_doi':
# 'https://theoncologist.onlinelibrary.wiley.com/doi/pdfdirect/10.1634/theoncologist.2015-0446'
#             },
#             {
#                 'reference_number': 31,
#                 'authors': 'R. Warren, Hui Yuan, M. Matli',
#                 'year': 1995,
#                 'title': 'Regulation by vascular endothelial growth factor of human colon cancer tumorigenesis in a
# mouse model of experimental liver metastasis.',
#                 'journal_source': 'Journal of Clinical Investigation',
#                 'url_doi': 'http://www.jci.org/articles/view/117857/files/pdf'
#             },
#             {
#                 'reference_number': 32,
#                 'authors': 'T. Akinyemiju, S. Abera, M. Ahmed',
#                 'year': 2017,
#                 'title': 'The Burden of Primary Liver Cancer and Underlying Etiologies From 1990 to 2015 at the
# Global, Regional, and National Level',
#                 'journal_source': 'JAMA Oncology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/5478179195a3a583ddcda3d5d61bb0ccec7b5df6'
#             },
#             {
#                 'reference_number': 33,
#                 'authors': 'S. Eriksson, J. Carlson, R. Velez',
#                 'year': 1986,
#                 'title': 'Risk of cirrhosis and primary liver cancer in alpha 1-antitrypsin deficiency.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.semanticscholar.org/paper/e0d8c9d65550489e68445b6a46884ebef2be3012'
#             },
#             {
#                 'reference_number': 34,
#                 'authors': 'A. Marengo, C. Rosso, E. Bugianesi',
#                 'year': 2016,
#                 'title': 'Liver Cancer: Connections with Obesity, Fatty Liver, and Cirrhosis.',
#                 'journal_source': 'Annual Review of Medicine',
#                 'url_doi': 'https://www.annualreviews.org/doi/pdf/10.1146/annurev-med-090514-013832'
#             },
#             {
#                 'reference_number': 35,
#                 'authors': 'Jonathan H. Williams, T. Phillips, P. Jolly',
#                 'year': 2004,
#                 'title': 'Human aflatoxicosis in developing countries: a review of toxicology, exposure, potential
# health consequences, and interventions.',
#                 'journal_source': 'American Journal of Clinical Nutrition',
#                 'url_doi': 'https://academic.oup.com/ajcn/article-pdf/80/5/1106/23714952/1106.pdf'
#             },
#             {
#                 'reference_number': 36,
#                 'authors': 'C. Niederau, R. Fischer, A. Sonnenberg',
#                 'year': 1985,
#                 'title': 'Survival and causes of death in cirrhotic and in noncirrhotic patients with primary
# hemochromatosis.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.semanticscholar.org/paper/ecbe20c4efc68b1db3174444018484c44b06aae6'
#             },
#             {
#                 'reference_number': 37,
#                 'authors': 'G. Omenn, G. Goodman, M. Thornquist',
#                 'year': 1996,
#                 'title': 'Risk factors for lung cancer and for intervention effects in CARET, the Beta-Carotene and
# Retinol Efficacy Trial.',
#                 'journal_source': 'Journal of the National Cancer Institute',
#                 'url_doi': 'https://escholarship.org/content/qt8qk8w9zw/qt8qk8w9zw.pdf?t=ol280z'
#             },
#             {
#                 'reference_number': 38,
#                 'authors': 'F. Kanwal, J. Kramer, Srikar R. Mapakshi',
#                 'year': 2018,
#                 'title': 'Risk of Hepatocellular Cancer in Patients With Non-Alcoholic Fatty Liver Disease.',
#                 'journal_source': 'Gastroenterology',
#                 'url_doi': 'http://www.gastrojournal.org/article/S0016508518348893/pdf'
#             },
#             {
#                 'reference_number': 39,
#                 'authors': 'Q. Lai, A. Avolio, I. Graziadei',
#                 'year': 2013,
#                 'title': 'Alpha‐fetoprotein and modified response evaluation criteria in Solid Tumors progression
# after locoregional therapy as predictors of hepatocellular cancer recurrence and death after transplantation',
#                 'journal_source': 'Liver transplantation',
#                 'url_doi': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/lt.23706'
#             },
#             {
#                 'reference_number': 40,
#                 'authors': 'C. Tempany, K. Zou, S. Silverman',
#                 'year': 2000,
#                 'title': 'Staging of advanced ovarian cancer: comparison of imaging modalities--report from the
# Radiological Diagnostic Oncology Group.',
#                 'journal_source': 'Radiology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/0917be444c58e44d36bc91ad3d40ed933ae98914'
#             },
#             {
#                 'reference_number': 41,
#                 'authors': 'M. Ziol, A. Handra-Luca, A. Kettaneh',
#                 'year': 2005,
#                 'title': 'Noninvasive assessment of liver fibrosis by measurement of stiffness in patients with
# chronic hepatitis C',
#                 'journal_source': 'Hepatology',
#                 'url_doi': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/hep.20506'
#             },
#             {
#                 'reference_number': 42,
#                 'authors': 'F. Bray, M. Laversanne, Hyuna Sung',
#                 'year': 2024,
#                 'title': 'Global cancer statistics 2022: GLOBOCAN estimates of incidence and mortality worldwide
# for 36 cancers in 185 countries',
#                 'journal_source': 'Ca',
#                 'url_doi': 'https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21834'
#             }
#         ]
#     }
# }

# %%
from rich import print as rprint
article_data = remove_references(article_data, bad_references)
rprint(article_data)
# Out:
# {
#     'title': 'Post-COVID Syndrome',
#     'subtitle': 'A complex condition characterized by persistent symptoms following a COVID-19 infection.',
#     'overview': {
#         'heading': 'Overview',
#         'content': "Post-COVID Syndrome, also known as Long COVID, refers to a wide range of health problems that
# can persist for weeks, months, or even years after an initial infection with the SARS-CoV-2 virus. It is a complex
# and multifaceted condition, and while research is ongoing, it is recognized as a significant public health concern.
# The symptoms of Post-COVID Syndrome can be quite varied, impacting nearly every organ system, making diagnosis and
# management challenging. It's important to note that the severity of the initial COVID infection does not
# necessarily correlate with the likelihood of developing Post-COVID Syndrome. While estimates vary, studies suggest
# that a substantial percentage of individuals who contract COVID-19 experience some form of Long COVID. Some studies
# suggest that 6 to 15 percent of patients may experience prolonged symptoms following acute infection [106, 108]."
#     },
#     'key_facts': {
#         'heading': 'Key Facts',
#         'content': [
#             'Post-COVID Syndrome can affect people of all ages, including children.',
#             'Symptoms can fluctuate in severity and may appear and disappear over time.',
#             'The syndrome is not solely related to the severity of the initial COVID-19 infection; even mild cases
# can lead to Long COVID.',
#             'Ongoing research is crucial for better understanding and treatment strategies.',
#             "Fatigue, cognitive dysfunction ('brain fog'), and shortness of breath are commonly reported symptoms."
#         ]
#     },
#     'symptoms': {
#         'heading': 'Symptoms',
#         'content': [
#             'Fatigue that interferes with daily life',
#             'Shortness of breath or difficulty breathing',
#             'Cognitive dysfunction (brain fog, difficulty concentrating)',
#             'Headache',
#             'Dizziness',
#             'Heart palpitations',
#             'Chest pain',
#             'Joint and muscle pain',
#             'Sleep disturbances',
#             'Changes in taste or smell',
#             'Anxiety and depression',
#             'Gastrointestinal issues',
#             'Skin rashes'
#         ]
#     },
#     'types': {
#         'heading': 'Types',
#         'content': 'Post-COVID Syndrome does not have clearly defined types, but symptoms can be grouped by
# affected systems, often overlapping.  \n\n### Systemic\nThese types involve multiple body systems:\n*   **Fatigue
# Dominant**: Primarily characterized by persistent and severe fatigue.\n*   **Neurocognitive**: Predominantly
# manifests as cognitive issues and neurological symptoms.\n\n### Organ-Specific\nSymptoms can also be classified
# based on the affected organ or system:\n*   **Pulmonary**: Primarily impacting the respiratory system.\n*
# **Cardiovascular**: Mainly involves symptoms affecting the heart and blood vessels.\n*   **Gastrointestinal**:
# Primarily affecting the digestive system.\n\nThis classification is not definitive, and individuals may experience
# a combination of these types.'
#     },
#     'causes': {
#         'heading': 'Causes',
#         'content': "The exact causes of Post-COVID Syndrome are still under investigation, but several potential
# mechanisms have been proposed. These include: \n*   **Persistent Viral Reservoir:** The virus may remain in the
# body, triggering an ongoing immune response.\n*   **Immune Dysregulation:**  An overactive or misdirected immune
# response after the initial infection could be responsible.\n*   **Endothelial Dysfunction:** Damage to the lining
# of blood vessels may contribute to symptoms [49].\n*   **Autoimmunity:** The body's immune system might start
# attacking its own tissues.\n*   **Organ Damage:** Lingering damage to organs due to the initial infection can lead
# to persistent issues. It's likely a combination of these factors that contributes to Post-COVID Syndrome. Other
# potential mechanisms include cellular injury, select gene expression profiles, reduction in peripheral serotonin
# levels, microbiota dysbiosis, complement dysregulation and neurologic signaling dysfunction [47, 48, 50, 51, 52,
# 53, 54, 57]."
#     },
#     'risk_factors': {
#         'heading': 'Risk Factors',
#         'content': [
#             'Severity of initial COVID-19 infection, although mild cases can still develop Long COVID.',
#             'Pre-existing conditions, such as diabetes, autoimmune disorders or respiratory issues.',
#             'Age, with older adults and those with comorbidities at higher risk.',
#             'Gender, with some studies suggesting women are slightly more susceptible.',
#             'Having a history of Epstein-Barr virus infection or other pre-existing conditions.',
#             'Lack of vaccination against COVID-19 may increase risk.'
#         ]
#     },
#     'diagnosis': {
#         'heading': 'Diagnosis',
#         'content': 'Diagnosing Post-COVID Syndrome can be challenging as there is no single diagnostic test.
# Diagnosis often involves a combination of factors:\n### Clinical Evaluation\nA thorough medical history, including
# the details of the initial COVID-19 infection, a physical exam, and assessment of reported symptoms.\n### Symptom
# Tracking\nMonitoring symptom patterns and severity over time through patient diaries or questionnaires can provide
# insights.\n### Exclusion of other conditions\nRule out other potential health issues that may be causing similar
# symptoms.\n### Diagnostic tests\nVarious laboratory tests and imaging such as chest X-rays, blood tests, and tests
# to evaluate organ function may be employed to assess the extent of the damage. There is no specific blood test that
# identifies long covid. The process is typically one of exclusion. Diagnosis is often based on the persistent
# symptoms after a period of time since initial infection, with no other clear cause. For patients with persistent
# symptoms recovering from moderate or severe illness, a complete blood count, blood chemistries, and liver function
# studies may be useful [140].'
#     },
#     'prevention': {
#         'heading': 'Prevention',
#         'content': [
#             'Vaccination against COVID-19 can reduce the risk of initial infection and may decrease the likelihood
# of developing Long COVID [126].',
#             'Following public health guidelines, such as wearing masks and practicing social distancing.',
#             'Prompt treatment of acute COVID-19 infection under medical guidance may help reduce the chances of
# Long COVID.',
#             'Maintaining a healthy lifestyle, including a balanced diet and regular exercise to support the immune
# system.',
#             'Reducing exposure to potential infection by taking precautions.'
#         ]
#     },
#     'specialist_to_visit': {
#         'heading': 'Specialist to Visit',
#         'content': 'Given the varied symptoms of Post-COVID Syndrome, several specialists may be involved in the
# diagnosis and management:\n*   **Primary Care Physician:** Initial evaluation and coordination of care.\n*
# **Pulmonologist:** For respiratory issues such as shortness of breath and lung problems.\n*   **Cardiologist:** For
# heart-related symptoms like chest pain and palpitations.\n*   **Neurologist:** For neurological issues, cognitive
# dysfunction, and headaches.\n*   **Psychiatrist/Psychologist:** To address mental health symptoms like anxiety and
# depression.\n*   **Physiotherapist/Occupational Therapist:**  To help with physical rehabilitation and daily
# functioning.\n*   **Infectious Disease Specialist:** To understand the underlying infection-related process.\nA
# multidisciplinary approach is often needed to address the wide array of symptoms associated with Post-COVID
# Syndrome.'
#     },
#     'treatment': {
#         'heading': 'Treatment',
#         'content': "Currently, there is no single cure for Post-COVID Syndrome, and treatment is largely focused on
# symptom management and rehabilitation. This often involves:\n*   **Medications:** Over-the-counter or prescription
# drugs to manage specific symptoms (e.g., pain relievers, anti-inflammatories, sleep aids).\n*   **Physical
# Therapy:** Exercises to improve strength, endurance, and respiratory function.\n*   **Cognitive Rehabilitation:**
# Strategies and therapies to address memory and attention problems ('brain fog').\n*   **Psychological Support:**
# Counseling or therapy to manage anxiety, depression, and other mental health challenges.\n*   **Multidisciplinary
# Approach:** Coordination of care among various specialists based on the individual's needs. Treatments are highly
# individualized based on the patient's unique symptoms and circumstances. More research is needed to identify
# effective treatments."
#     },
#     'home_care': {
#         'heading': 'Home-Care',
#         'content': [
#             'Pacing activities and avoiding overexertion, taking frequent breaks.',
#             'Maintaining a regular sleep schedule and creating a calming sleep environment.',
#             'Practicing relaxation techniques, such as deep breathing exercises or meditation.',
#             'Eating a nutritious diet and ensuring adequate hydration.',
#             'Monitoring symptoms and keeping a symptom diary to identify patterns.',
#             'Seeking emotional support from friends, family, or support groups.',
#             'Engaging in gentle exercise or movement as tolerated to promote recovery.'
#         ]
#     },
#     'living_with': {
#         'heading': 'Living With',
#         'content': 'Living with Post-COVID Syndrome can be challenging and requires a multifaceted approach. It
# involves:\n*   **Acceptance and Self-Compassion:** Recognizing that the condition is real and adjusting
# expectations accordingly.\n*   **Support Networks:** Joining support groups and connecting with others who
# understand the condition.\n*   **Advocating for Oneself:** Actively communicating with healthcare providers and
# seeking appropriate care.\n*   **Lifestyle Adjustments:** Making necessary modifications to daily routines to
# accommodate symptoms.\n*   **Mental Health Support:** Prioritizing mental well-being through therapy or counseling
# if needed. A holistic approach, focusing on physical, emotional, and social well-being is crucial to managing Long
# COVID.'
#     },
#     'complications': {
#         'heading': 'Complications',
#         'content': 'Post-COVID Syndrome can lead to several complications if not managed effectively. These
# include: \n*   **Reduced Quality of Life:** Chronic symptoms can impact daily functioning, employment, and social
# interactions. Post-exertional malaise, triggered by physical, cognitive, or psychological exertion, can also limit
# daily activities [110, 111].\n*  **Mental Health Issues:** Anxiety, depression, and post-traumatic stress disorder
# are common and can worsen the overall condition.\n*   **Organ Damage:** Lingering issues with organs (e.g., heart,
# lungs) can result in long-term health problems.\n*   **Cardiovascular Problems:** An increased risk of conditions
# like blood clots, myocarditis, and other heart-related issues can occur.\n*  **Respiratory Issues:** Chronic
# shortness of breath, ongoing lung inflammation, or fibrosis can cause long-term pulmonary issues.\n*   **Cognitive
# Dysfunction:**  Persistent difficulties with memory, attention, and concentration may impact the ability to work or
# engage in regular daily activities.\n*   **Increased Healthcare Utilization:** Frequent visits to specialists and
# hospitalizations may be necessary, creating a strain on healthcare resources. Monitoring and addressing these
# issues early is important.'
#     },
#     'alternative_therapies': {
#         'heading': 'Alternative Therapies',
#         'content': "Some individuals with Post-COVID Syndrome explore alternative therapies to alleviate symptoms.
# While more research is needed to evaluate their effectiveness, they may include: \n*   **Acupuncture**: May be used
# to manage pain, fatigue, and improve energy flow.\n*   **Mindfulness and Meditation**: Used to reduce stress,
# improve focus, and manage mental health.\n*   **Yoga and Tai Chi**: Gentle forms of exercise to improve
# flexibility, strength and reduce stress.\n*   **Herbal Remedies:** Some people use herbal supplements or
# traditional medicines; however, it's important to consult with a healthcare professional before trying these
# therapies.\n*   **Nutritional Supplements:** Some supplements like vitamins may be helpful but it is essential to
# verify with your doctor that it is safe.\nIt is essential to use caution and discuss alternative therapies with a
# healthcare provider to ensure safety and avoid interactions with conventional treatments. It is also vital to
# ensure any practitioner is qualified."
#     },
#     'faqs': {
#         'heading': 'FAQs',
#         'content': [
#             {
#                 'question': 'How long does Post-COVID Syndrome last?',
#                 'answer': 'The duration of Post-COVID Syndrome varies widely. Some people recover within a few
# months, while others may experience symptoms for a year or longer. The long-term course is still being
# investigated.'
#             },
#             {
#                 'question': 'Can you get Long COVID from a mild COVID infection?',
#                 'answer': 'Yes, even mild cases of COVID-19 can lead to Long COVID. The severity of the initial
# infection does not necessarily predict the likelihood of developing Post-COVID Syndrome.'
#             },
#             {
#                 'question': 'Is there a cure for Post-COVID Syndrome?',
#                 'answer': 'Currently, there is no specific cure for Post-COVID Syndrome. Treatment focuses on
# managing symptoms and providing rehabilitation, as well as monitoring the progress of recovery.'
#             },
#             {
#                 'question': 'What is the link between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome?',
#                 'answer': 'There is an overlap between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome (ME/CFS), with many Long COVID patients meeting the diagnostic criteria for ME/CFS [133, 134, 135].'
#             },
#             {
#                 'question': 'What is the impact of vaccination on Long COVID?',
#                 'answer': 'Vaccination against COVID-19 may reduce the incidence of long COVID [126]. Some studies
# also indicate that vaccination after infection can decrease the likelihood of persistent symptoms.'
#             },
#             {
#                 'question': 'What should I do if I think I have Long COVID?',
#                 'answer': 'If you suspect you have Long COVID, consult your primary care physician. They can
# evaluate your symptoms, perform necessary tests, and refer you to specialists if needed.'
#             },
#             {
#                 'question': 'Is there any support available for people with Long COVID?',
#                 'answer': 'Yes, various support groups and organizations are available to help individuals with
# Long COVID. These groups can provide information, peer support, and advocacy.'
#             },
#             {
#                 'question': 'Can Long COVID be considered a disability?',
#                 'answer': 'Yes, Long COVID can be considered a disability under the Americans with Disabilities Act
# if it substantially limits one or more major life activities [112].'
#             },
#             {
#                 'question': 'Are there any treatments being investigated for Long COVID?',
#                 'answer': 'Yes, several therapies are under investigation, including low-dose naltrexone, Paxlovid,
# and some gut microbiome modulators [145, 146, 147, 149].'
#             }
#         ]
#     },
#     'references': {
#         'heading': 'References',
#         'content': [
#             {
#                 'reference_number': 47,
#                 'authors': 'Siripanthong B, Asatryan B, Hanff TC, et al.',
#                 'year': '2022',
#                 'title': 'The Pathogenesis and Long-Term Consequences of COVID-19 Cardiac Injury.',
#                 'journal_source': 'JACC Basic Transl Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 48,
#                 'authors': 'Peluso MJ, Deeks SG.',
#                 'year': '2022',
#                 'title': 'Early clues regarding the pathogenesis of long-COVID.',
#                 'journal_source': 'Trends Immunol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 49,
#                 'authors': 'Fogarty H, Townsend L, Morrin H, et al.',
#                 'year': '2021',
#                 'title': 'Persistent endotheliopathy in the pathogenesis of long COVID syndrome.',
#                 'journal_source': 'J Thromb Haemost',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 50,
#                 'authors': 'Clark IA.',
#                 'year': '2022',
#                 'title': 'Chronic cerebral aspects of long COVID, post-stroke syndromes and similar states share
# their pathogenesis and perispinal etanercept treatment logic.',
#                 'journal_source': 'Pharmacol Res Perspect',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 51,
#                 'authors': 'Thompson RC, Simons NW, Wilkins L, et al.',
#                 'year': '2023',
#                 'title': 'Molecular states during acute COVID-19 reveal distinct etiologies of long-term
# sequelae.',
#                 'journal_source': 'Nat Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 52,
#                 'authors': 'Davis HE, McCorkell L, Vogel JM, Topol EJ.',
#                 'year': '2023',
#                 'title': 'Long COVID: major findings, mechanisms and recommendations.',
#                 'journal_source': 'Nat Rev Microbiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 53,
#                 'authors': 'Yao Q, Doyle ME, Liu QR, et al.',
#                 'year': '2023',
#                 'title': 'Long-Term Dysfunction of Taste Papillae in SARS-CoV-2.',
#                 'journal_source': 'NEJM Evid',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 54,
#                 'authors': 'Wong AC, Devason AS, Umana IC, et al.',
#                 'year': '2023',
#                 'title': 'Serotonin reduction in post-acute sequelae of viral infection.',
#                 'journal_source': 'Cell',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 57,
#                 'authors': 'Cervia-Hasler C, Br\\u00fcningk SC, Hoch T, et al.',
#                 'year': '2024',
#                 'title': 'Persistent complement dysregulation with signs of thromboinflammation in active Long
# Covid.',
#                 'journal_source': 'Science',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 106,
#                 'authors': 'Global Burden of Disease Long COVID Collaborators, Wulf Hanson S, Abbafati C, et al.',
#                 'year': '2022',
#                 'title': 'Estimated Global Proportions of Individuals With Persistent Fatigue, Cognitive, and
# Respiratory Symptom Clusters Following Symptomatic COVID-19 in 2020 and 2021.',
#                 'journal_source': 'JAMA',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 108,
#                 'authors': 'Sedgley R, Winer-Jones J, Bonafede M.',
#                 'year': '2023',
#                 'title': 'Long COVID Incidence in a Large US Ambulatory Electronic Health Record System.',
#                 'journal_source': 'Am J Epidemiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 110,
#                 'authors': 'Cohen J, Rodgers YVM.',
#                 'year': '2024',
#                 'title': 'Long COVID Prevalence, Disability, and Accommodations: Analysis Across Demographic
# Groups.',
#                 'journal_source': 'J Occup Rehabil',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 111,
#                 'authors': 'Davis HE, Assaf GS, McCorkell L, et al.',
#                 'year': '2021',
#                 'title': 'Characterizing long COVID in an international cohort: 7 months of symptoms and their
# impact.',
#                 'journal_source': 'EClinicalMedicine',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 126,
#                 'authors': 'Byambasuren O, Stehlik P, Clark J, et al.',
#                 'year': '2023',
#                 'title': 'Effect of covid-19 vaccination on long covid: systematic review.',
#                 'journal_source': 'BMJ Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 133,
#                 'authors': 'Tate WP, Walker MOM, Peppercorn K, et al.',
#                 'year': '2023',
#                 'title': 'Towards a Better Understanding of the Complexities of Myalgic Encephalomyelitis/Chronic
# Fatigue Syndrome and Long COVID.',
#                 'journal_source': 'Int J Mol Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 134,
#                 'authors': 'Renz-Polster H, Scheibenbogen C.',
#                 'year': '2022',
#                 'title': '[Post-COVID syndrome with fatigue and exercise intolerance: myalgic
# encephalomyelitis/chronic fatigue syndrome].',
#                 'journal_source': 'Inn Med (Heidelb)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 135,
#                 'authors': 'Wong TL, Weitzer DJ.',
#                 'year': '2021',
#                 'title': 'Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue Syndrome (ME/CFS)-A Systemic
# Review and Comparison of Clinical Presentation and Symptomatology.',
#                 'journal_source': 'Medicina (Kaunas)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 140,
#                 'authors': 'Arnold DT, Hamilton FW, Milne A, et al.',
#                 'year': '2021',
#                 'title': 'Patient outcomes after hospitalisation with COVID-19 and implications for follow-up:
# results from a prospective UK cohort.',
#                 'journal_source': 'Thorax',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 145,
#                 'authors': 'Cohen AK, Jaudon TW, Schurman EM, et al.',
#                 'year': '2023',
#                 'title': 'Impact of extended-course oral nirmatrelvir/ritonavir (Paxlovid) in established Long
# COVID: Case series and research considerations.',
#                 'journal_source': 'Res Sq',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 146,
#                 'authors': "O'Kelly B, Vidal L, McHugh T, et al.",
#                 'year': '2022',
#                 'title': 'Safety and efficacy of low dose naltrexone in a long covid cohort; an interventional
# pre-post study.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 147,
#                 'authors': 'Isman A, Nyquist A, Strecker B, et al.',
#                 'year': '2024',
#                 'title': 'Low-dose naltrexone and NAD+ for the treatment of patients with persistent fatigue
# symptoms after COVID-19.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 149,
#                 'authors': 'Zhang L, Xu Z, Mak JWY, et al.',
#                 'year': '2022',
#                 'title': 'Gut microbiota-derived synbiotic formula (SIM01) as a novel adjuvant therapy for
# COVID-19: An open-label pilot study.',
#                 'journal_source': 'J Gastroenterol Hepatol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 150,
#                 'authors': 'Lau RI, Su Q, Lau ISF, et al.',
#                 'year': '2024',
#                 'title': 'A synbiotic preparation (SIM01) for post-acute COVID-19 syndrome in Hong Kong (RECOVERY):
# a randomised, double-blind, placebo-controlled trial.',
#                 'journal_source': 'Lancet Infect Dis',
#                 'url_doi': None
#             }
#         ]
#     }
# }

# %%
article_data = remove_inline_citations(article_data, bad_references)
rprint(article_data)
# Out:
# {
#     'title': 'Post-COVID Syndrome',
#     'subtitle': 'A complex condition characterized by persistent symptoms following a COVID-19 infection.',
#     'overview': {
#         'heading': 'Overview',
#         'content': "Post-COVID Syndrome, also known as Long COVID, refers to a wide range of health problems that
# can persist for weeks, months, or even years after an initial infection with the SARS-CoV-2 virus. It is a complex
# and multifaceted condition, and while research is ongoing, it is recognized as a significant public health concern.
# The symptoms of Post-COVID Syndrome can be quite varied, impacting nearly every organ system, making diagnosis and
# management challenging. It's important to note that the severity of the initial COVID infection does not
# necessarily correlate with the likelihood of developing Post-COVID Syndrome. While estimates vary, studies suggest
# that a substantial percentage of individuals who contract COVID-19 experience some form of Long COVID. Some studies
# suggest that 6 to 15 percent of patients may experience prolonged symptoms following acute infection [106,108]."
#     },
#     'key_facts': {
#         'heading': 'Key Facts',
#         'content': [
#             'Post-COVID Syndrome can affect people of all ages, including children.',
#             'Symptoms can fluctuate in severity and may appear and disappear over time.',
#             'The syndrome is not solely related to the severity of the initial COVID-19 infection; even mild cases
# can lead to Long COVID.',
#             'Ongoing research is crucial for better understanding and treatment strategies.',
#             "Fatigue, cognitive dysfunction ('brain fog'), and shortness of breath are commonly reported symptoms."
#         ]
#     },
#     'symptoms': {
#         'heading': 'Symptoms',
#         'content': [
#             'Fatigue that interferes with daily life',
#             'Shortness of breath or difficulty breathing',
#             'Cognitive dysfunction (brain fog, difficulty concentrating)',
#             'Headache',
#             'Dizziness',
#             'Heart palpitations',
#             'Chest pain',
#             'Joint and muscle pain',
#             'Sleep disturbances',
#             'Changes in taste or smell',
#             'Anxiety and depression',
#             'Gastrointestinal issues',
#             'Skin rashes'
#         ]
#     },
#     'types': {
#         'heading': 'Types',
#         'content': 'Post-COVID Syndrome does not have clearly defined types, but symptoms can be grouped by
# affected systems, often overlapping.  \n\n### Systemic\nThese types involve multiple body systems:\n*   **Fatigue
# Dominant**: Primarily characterized by persistent and severe fatigue.\n*   **Neurocognitive**: Predominantly
# manifests as cognitive issues and neurological symptoms.\n\n### Organ-Specific\nSymptoms can also be classified
# based on the affected organ or system:\n*   **Pulmonary**: Primarily impacting the respiratory system.\n*
# **Cardiovascular**: Mainly involves symptoms affecting the heart and blood vessels.\n*   **Gastrointestinal**:
# Primarily affecting the digestive system.\n\nThis classification is not definitive, and individuals may experience
# a combination of these types.'
#     },
#     'causes': {
#         'heading': 'Causes',
#         'content': "The exact causes of Post-COVID Syndrome are still under investigation, but several potential
# mechanisms have been proposed. These include: \n*   **Persistent Viral Reservoir:** The virus may remain in the
# body, triggering an ongoing immune response.\n*   **Immune Dysregulation:**  An overactive or misdirected immune
# response after the initial infection could be responsible.\n*   **Endothelial Dysfunction:** Damage to the lining
# of blood vessels may contribute to symptoms [49].\n*   **Autoimmunity:** The body's immune system might start
# attacking its own tissues.\n*   **Organ Damage:** Lingering damage to organs due to the initial infection can lead
# to persistent issues. It's likely a combination of these factors that contributes to Post-COVID Syndrome. Other
# potential mechanisms include cellular injury, select gene expression profiles, reduction in peripheral serotonin
# levels, microbiota dysbiosis, complement dysregulation and neurologic signaling dysfunction
# [47,48,50,51,52,53,54,57]."
#     },
#     'risk_factors': {
#         'heading': 'Risk Factors',
#         'content': [
#             'Severity of initial COVID-19 infection, although mild cases can still develop Long COVID.',
#             'Pre-existing conditions, such as diabetes, autoimmune disorders or respiratory issues.',
#             'Age, with older adults and those with comorbidities at higher risk.',
#             'Gender, with some studies suggesting women are slightly more susceptible.',
#             'Having a history of Epstein-Barr virus infection or other pre-existing conditions.',
#             'Lack of vaccination against COVID-19 may increase risk.'
#         ]
#     },
#     'diagnosis': {
#         'heading': 'Diagnosis',
#         'content': 'Diagnosing Post-COVID Syndrome can be challenging as there is no single diagnostic test.
# Diagnosis often involves a combination of factors:\n### Clinical Evaluation\nA thorough medical history, including
# the details of the initial COVID-19 infection, a physical exam, and assessment of reported symptoms.\n### Symptom
# Tracking\nMonitoring symptom patterns and severity over time through patient diaries or questionnaires can provide
# insights.\n### Exclusion of other conditions\nRule out other potential health issues that may be causing similar
# symptoms.\n### Diagnostic tests\nVarious laboratory tests and imaging such as chest X-rays, blood tests, and tests
# to evaluate organ function may be employed to assess the extent of the damage. There is no specific blood test that
# identifies long covid. The process is typically one of exclusion. Diagnosis is often based on the persistent
# symptoms after a period of time since initial infection, with no other clear cause. For patients with persistent
# symptoms recovering from moderate or severe illness, a complete blood count, blood chemistries, and liver function
# studies may be useful [140].'
#     },
#     'prevention': {
#         'heading': 'Prevention',
#         'content': [
#             'Vaccination against COVID-19 can reduce the risk of initial infection and may decrease the likelihood
# of developing Long COVID [126].',
#             'Following public health guidelines, such as wearing masks and practicing social distancing.',
#             'Prompt treatment of acute COVID-19 infection under medical guidance may help reduce the chances of
# Long COVID.',
#             'Maintaining a healthy lifestyle, including a balanced diet and regular exercise to support the immune
# system.',
#             'Reducing exposure to potential infection by taking precautions.'
#         ]
#     },
#     'specialist_to_visit': {
#         'heading': 'Specialist to Visit',
#         'content': 'Given the varied symptoms of Post-COVID Syndrome, several specialists may be involved in the
# diagnosis and management:\n*   **Primary Care Physician:** Initial evaluation and coordination of care.\n*
# **Pulmonologist:** For respiratory issues such as shortness of breath and lung problems.\n*   **Cardiologist:** For
# heart-related symptoms like chest pain and palpitations.\n*   **Neurologist:** For neurological issues, cognitive
# dysfunction, and headaches.\n*   **Psychiatrist/Psychologist:** To address mental health symptoms like anxiety and
# depression.\n*   **Physiotherapist/Occupational Therapist:**  To help with physical rehabilitation and daily
# functioning.\n*   **Infectious Disease Specialist:** To understand the underlying infection-related process.\nA
# multidisciplinary approach is often needed to address the wide array of symptoms associated with Post-COVID
# Syndrome.'
#     },
#     'treatment': {
#         'heading': 'Treatment',
#         'content': "Currently, there is no single cure for Post-COVID Syndrome, and treatment is largely focused on
# symptom management and rehabilitation. This often involves:\n*   **Medications:** Over-the-counter or prescription
# drugs to manage specific symptoms (e.g., pain relievers, anti-inflammatories, sleep aids).\n*   **Physical
# Therapy:** Exercises to improve strength, endurance, and respiratory function.\n*   **Cognitive Rehabilitation:**
# Strategies and therapies to address memory and attention problems ('brain fog').\n*   **Psychological Support:**
# Counseling or therapy to manage anxiety, depression, and other mental health challenges.\n*   **Multidisciplinary
# Approach:** Coordination of care among various specialists based on the individual's needs. Treatments are highly
# individualized based on the patient's unique symptoms and circumstances. More research is needed to identify
# effective treatments."
#     },
#     'home_care': {
#         'heading': 'Home-Care',
#         'content': [
#             'Pacing activities and avoiding overexertion, taking frequent breaks.',
#             'Maintaining a regular sleep schedule and creating a calming sleep environment.',
#             'Practicing relaxation techniques, such as deep breathing exercises or meditation.',
#             'Eating a nutritious diet and ensuring adequate hydration.',
#             'Monitoring symptoms and keeping a symptom diary to identify patterns.',
#             'Seeking emotional support from friends, family, or support groups.',
#             'Engaging in gentle exercise or movement as tolerated to promote recovery.'
#         ]
#     },
#     'living_with': {
#         'heading': 'Living With',
#         'content': 'Living with Post-COVID Syndrome can be challenging and requires a multifaceted approach. It
# involves:\n*   **Acceptance and Self-Compassion:** Recognizing that the condition is real and adjusting
# expectations accordingly.\n*   **Support Networks:** Joining support groups and connecting with others who
# understand the condition.\n*   **Advocating for Oneself:** Actively communicating with healthcare providers and
# seeking appropriate care.\n*   **Lifestyle Adjustments:** Making necessary modifications to daily routines to
# accommodate symptoms.\n*   **Mental Health Support:** Prioritizing mental well-being through therapy or counseling
# if needed. A holistic approach, focusing on physical, emotional, and social well-being is crucial to managing Long
# COVID.'
#     },
#     'complications': {
#         'heading': 'Complications',
#         'content': 'Post-COVID Syndrome can lead to several complications if not managed effectively. These
# include: \n*   **Reduced Quality of Life:** Chronic symptoms can impact daily functioning, employment, and social
# interactions. Post-exertional malaise, triggered by physical, cognitive, or psychological exertion, can also limit
# daily activities [110,111].\n*  **Mental Health Issues:** Anxiety, depression, and post-traumatic stress disorder
# are common and can worsen the overall condition.\n*   **Organ Damage:** Lingering issues with organs (e.g., heart,
# lungs) can result in long-term health problems.\n*   **Cardiovascular Problems:** An increased risk of conditions
# like blood clots, myocarditis, and other heart-related issues can occur.\n*  **Respiratory Issues:** Chronic
# shortness of breath, ongoing lung inflammation, or fibrosis can cause long-term pulmonary issues.\n*   **Cognitive
# Dysfunction:**  Persistent difficulties with memory, attention, and concentration may impact the ability to work or
# engage in regular daily activities.\n*   **Increased Healthcare Utilization:** Frequent visits to specialists and
# hospitalizations may be necessary, creating a strain on healthcare resources. Monitoring and addressing these
# issues early is important.'
#     },
#     'alternative_therapies': {
#         'heading': 'Alternative Therapies',
#         'content': "Some individuals with Post-COVID Syndrome explore alternative therapies to alleviate symptoms.
# While more research is needed to evaluate their effectiveness, they may include: \n*   **Acupuncture**: May be used
# to manage pain, fatigue, and improve energy flow.\n*   **Mindfulness and Meditation**: Used to reduce stress,
# improve focus, and manage mental health.\n*   **Yoga and Tai Chi**: Gentle forms of exercise to improve
# flexibility, strength and reduce stress.\n*   **Herbal Remedies:** Some people use herbal supplements or
# traditional medicines; however, it's important to consult with a healthcare professional before trying these
# therapies.\n*   **Nutritional Supplements:** Some supplements like vitamins may be helpful but it is essential to
# verify with your doctor that it is safe.\nIt is essential to use caution and discuss alternative therapies with a
# healthcare provider to ensure safety and avoid interactions with conventional treatments. It is also vital to
# ensure any practitioner is qualified."
#     },
#     'faqs': {
#         'heading': 'FAQs',
#         'content': [
#             {
#                 'question': 'How long does Post-COVID Syndrome last?',
#                 'answer': 'The duration of Post-COVID Syndrome varies widely. Some people recover within a few
# months, while others may experience symptoms for a year or longer. The long-term course is still being
# investigated.'
#             },
#             {
#                 'question': 'Can you get Long COVID from a mild COVID infection?',
#                 'answer': 'Yes, even mild cases of COVID-19 can lead to Long COVID. The severity of the initial
# infection does not necessarily predict the likelihood of developing Post-COVID Syndrome.'
#             },
#             {
#                 'question': 'Is there a cure for Post-COVID Syndrome?',
#                 'answer': 'Currently, there is no specific cure for Post-COVID Syndrome. Treatment focuses on
# managing symptoms and providing rehabilitation, as well as monitoring the progress of recovery.'
#             },
#             {
#                 'question': 'What is the link between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome?',
#                 'answer': 'There is an overlap between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome (ME/CFS), with many Long COVID patients meeting the diagnostic criteria for ME/CFS [133,134,135].'
#             },
#             {
#                 'question': 'What is the impact of vaccination on Long COVID?',
#                 'answer': 'Vaccination against COVID-19 may reduce the incidence of long COVID [126]. Some studies
# also indicate that vaccination after infection can decrease the likelihood of persistent symptoms.'
#             },
#             {
#                 'question': 'What should I do if I think I have Long COVID?',
#                 'answer': 'If you suspect you have Long COVID, consult your primary care physician. They can
# evaluate your symptoms, perform necessary tests, and refer you to specialists if needed.'
#             },
#             {
#                 'question': 'Is there any support available for people with Long COVID?',
#                 'answer': 'Yes, various support groups and organizations are available to help individuals with
# Long COVID. These groups can provide information, peer support, and advocacy.'
#             },
#             {
#                 'question': 'Can Long COVID be considered a disability?',
#                 'answer': 'Yes, Long COVID can be considered a disability under the Americans with Disabilities Act
# if it substantially limits one or more major life activities .'
#             },
#             {
#                 'question': 'Are there any treatments being investigated for Long COVID?',
#                 'answer': 'Yes, several therapies are under investigation, including low-dose naltrexone, Paxlovid,
# and some gut microbiome modulators [145,146,147,149].'
#             }
#         ]
#     },
#     'references': {
#         'heading': 'References',
#         'content': [
#             {
#                 'reference_number': 47,
#                 'authors': 'Siripanthong B, Asatryan B, Hanff TC, et al.',
#                 'year': '2022',
#                 'title': 'The Pathogenesis and Long-Term Consequences of COVID-19 Cardiac Injury.',
#                 'journal_source': 'JACC Basic Transl Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 48,
#                 'authors': 'Peluso MJ, Deeks SG.',
#                 'year': '2022',
#                 'title': 'Early clues regarding the pathogenesis of long-COVID.',
#                 'journal_source': 'Trends Immunol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 49,
#                 'authors': 'Fogarty H, Townsend L, Morrin H, et al.',
#                 'year': '2021',
#                 'title': 'Persistent endotheliopathy in the pathogenesis of long COVID syndrome.',
#                 'journal_source': 'J Thromb Haemost',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 50,
#                 'authors': 'Clark IA.',
#                 'year': '2022',
#                 'title': 'Chronic cerebral aspects of long COVID, post-stroke syndromes and similar states share
# their pathogenesis and perispinal etanercept treatment logic.',
#                 'journal_source': 'Pharmacol Res Perspect',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 51,
#                 'authors': 'Thompson RC, Simons NW, Wilkins L, et al.',
#                 'year': '2023',
#                 'title': 'Molecular states during acute COVID-19 reveal distinct etiologies of long-term
# sequelae.',
#                 'journal_source': 'Nat Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 52,
#                 'authors': 'Davis HE, McCorkell L, Vogel JM, Topol EJ.',
#                 'year': '2023',
#                 'title': 'Long COVID: major findings, mechanisms and recommendations.',
#                 'journal_source': 'Nat Rev Microbiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 53,
#                 'authors': 'Yao Q, Doyle ME, Liu QR, et al.',
#                 'year': '2023',
#                 'title': 'Long-Term Dysfunction of Taste Papillae in SARS-CoV-2.',
#                 'journal_source': 'NEJM Evid',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 54,
#                 'authors': 'Wong AC, Devason AS, Umana IC, et al.',
#                 'year': '2023',
#                 'title': 'Serotonin reduction in post-acute sequelae of viral infection.',
#                 'journal_source': 'Cell',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 57,
#                 'authors': 'Cervia-Hasler C, Br\\u00fcningk SC, Hoch T, et al.',
#                 'year': '2024',
#                 'title': 'Persistent complement dysregulation with signs of thromboinflammation in active Long
# Covid.',
#                 'journal_source': 'Science',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 106,
#                 'authors': 'Global Burden of Disease Long COVID Collaborators, Wulf Hanson S, Abbafati C, et al.',
#                 'year': '2022',
#                 'title': 'Estimated Global Proportions of Individuals With Persistent Fatigue, Cognitive, and
# Respiratory Symptom Clusters Following Symptomatic COVID-19 in 2020 and 2021.',
#                 'journal_source': 'JAMA',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 108,
#                 'authors': 'Sedgley R, Winer-Jones J, Bonafede M.',
#                 'year': '2023',
#                 'title': 'Long COVID Incidence in a Large US Ambulatory Electronic Health Record System.',
#                 'journal_source': 'Am J Epidemiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 110,
#                 'authors': 'Cohen J, Rodgers YVM.',
#                 'year': '2024',
#                 'title': 'Long COVID Prevalence, Disability, and Accommodations: Analysis Across Demographic
# Groups.',
#                 'journal_source': 'J Occup Rehabil',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 111,
#                 'authors': 'Davis HE, Assaf GS, McCorkell L, et al.',
#                 'year': '2021',
#                 'title': 'Characterizing long COVID in an international cohort: 7 months of symptoms and their
# impact.',
#                 'journal_source': 'EClinicalMedicine',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 126,
#                 'authors': 'Byambasuren O, Stehlik P, Clark J, et al.',
#                 'year': '2023',
#                 'title': 'Effect of covid-19 vaccination on long covid: systematic review.',
#                 'journal_source': 'BMJ Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 133,
#                 'authors': 'Tate WP, Walker MOM, Peppercorn K, et al.',
#                 'year': '2023',
#                 'title': 'Towards a Better Understanding of the Complexities of Myalgic Encephalomyelitis/Chronic
# Fatigue Syndrome and Long COVID.',
#                 'journal_source': 'Int J Mol Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 134,
#                 'authors': 'Renz-Polster H, Scheibenbogen C.',
#                 'year': '2022',
#                 'title': '[Post-COVID syndrome with fatigue and exercise intolerance: myalgic
# encephalomyelitis/chronic fatigue syndrome].',
#                 'journal_source': 'Inn Med (Heidelb)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 135,
#                 'authors': 'Wong TL, Weitzer DJ.',
#                 'year': '2021',
#                 'title': 'Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue Syndrome (ME/CFS)-A Systemic
# Review and Comparison of Clinical Presentation and Symptomatology.',
#                 'journal_source': 'Medicina (Kaunas)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 140,
#                 'authors': 'Arnold DT, Hamilton FW, Milne A, et al.',
#                 'year': '2021',
#                 'title': 'Patient outcomes after hospitalisation with COVID-19 and implications for follow-up:
# results from a prospective UK cohort.',
#                 'journal_source': 'Thorax',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 145,
#                 'authors': 'Cohen AK, Jaudon TW, Schurman EM, et al.',
#                 'year': '2023',
#                 'title': 'Impact of extended-course oral nirmatrelvir/ritonavir (Paxlovid) in established Long
# COVID: Case series and research considerations.',
#                 'journal_source': 'Res Sq',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 146,
#                 'authors': "O'Kelly B, Vidal L, McHugh T, et al.",
#                 'year': '2022',
#                 'title': 'Safety and efficacy of low dose naltrexone in a long covid cohort; an interventional
# pre-post study.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 147,
#                 'authors': 'Isman A, Nyquist A, Strecker B, et al.',
#                 'year': '2024',
#                 'title': 'Low-dose naltrexone and NAD+ for the treatment of patients with persistent fatigue
# symptoms after COVID-19.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 149,
#                 'authors': 'Zhang L, Xu Z, Mak JWY, et al.',
#                 'year': '2022',
#                 'title': 'Gut microbiota-derived synbiotic formula (SIM01) as a novel adjuvant therapy for
# COVID-19: An open-label pilot study.',
#                 'journal_source': 'J Gastroenterol Hepatol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 150,
#                 'authors': 'Lau RI, Su Q, Lau ISF, et al.',
#                 'year': '2024',
#                 'title': 'A synbiotic preparation (SIM01) for post-acute COVID-19 syndrome in Hong Kong (RECOVERY):
# a randomised, double-blind, placebo-controlled trial.',
#                 'journal_source': 'Lancet Infect Dis',
#                 'url_doi': None
#             }
#         ]
#     }
# }

# %%
if not check_for_duplicate_references(article_data):
    print("No duplicates.")
    remap = create_remap_dictionary(article_data)
    article_data = update_reference_numbers(article_data, remap)
    article_data = update_inline_citations(article_data, remap)

rprint(article_data)
# Out:
# No duplicates.
# {
#     'title': 'Post-COVID Syndrome',
#     'subtitle': 'A complex condition characterized by persistent symptoms following a COVID-19 infection.',
#     'overview': {
#         'heading': 'Overview',
#         'content': "Post-COVID Syndrome, also known as Long COVID, refers to a wide range of health problems that
# can persist for weeks, months, or even years after an initial infection with the SARS-CoV-2 virus. It is a complex
# and multifaceted condition, and while research is ongoing, it is recognized as a significant public health concern.
# The symptoms of Post-COVID Syndrome can be quite varied, impacting nearly every organ system, making diagnosis and
# management challenging. It's important to note that the severity of the initial COVID infection does not
# necessarily correlate with the likelihood of developing Post-COVID Syndrome. While estimates vary, studies suggest
# that a substantial percentage of individuals who contract COVID-19 experience some form of Long COVID. Some studies
# suggest that 6 to 15 percent of patients may experience prolonged symptoms following acute infection [10,11]."
#     },
#     'key_facts': {
#         'heading': 'Key Facts',
#         'content': [
#             'Post-COVID Syndrome can affect people of all ages, including children.',
#             'Symptoms can fluctuate in severity and may appear and disappear over time.',
#             'The syndrome is not solely related to the severity of the initial COVID-19 infection; even mild cases
# can lead to Long COVID.',
#             'Ongoing research is crucial for better understanding and treatment strategies.',
#             "Fatigue, cognitive dysfunction ('brain fog'), and shortness of breath are commonly reported symptoms."
#         ]
#     },
#     'symptoms': {
#         'heading': 'Symptoms',
#         'content': [
#             'Fatigue that interferes with daily life',
#             'Shortness of breath or difficulty breathing',
#             'Cognitive dysfunction (brain fog, difficulty concentrating)',
#             'Headache',
#             'Dizziness',
#             'Heart palpitations',
#             'Chest pain',
#             'Joint and muscle pain',
#             'Sleep disturbances',
#             'Changes in taste or smell',
#             'Anxiety and depression',
#             'Gastrointestinal issues',
#             'Skin rashes'
#         ]
#     },
#     'types': {
#         'heading': 'Types',
#         'content': 'Post-COVID Syndrome does not have clearly defined types, but symptoms can be grouped by
# affected systems, often overlapping.  \n\n### Systemic\nThese types involve multiple body systems:\n*   **Fatigue
# Dominant**: Primarily characterized by persistent and severe fatigue.\n*   **Neurocognitive**: Predominantly
# manifests as cognitive issues and neurological symptoms.\n\n### Organ-Specific\nSymptoms can also be classified
# based on the affected organ or system:\n*   **Pulmonary**: Primarily impacting the respiratory system.\n*
# **Cardiovascular**: Mainly involves symptoms affecting the heart and blood vessels.\n*   **Gastrointestinal**:
# Primarily affecting the digestive system.\n\nThis classification is not definitive, and individuals may experience
# a combination of these types.'
#     },
#     'causes': {
#         'heading': 'Causes',
#         'content': "The exact causes of Post-COVID Syndrome are still under investigation, but several potential
# mechanisms have been proposed. These include: \n*   **Persistent Viral Reservoir:** The virus may remain in the
# body, triggering an ongoing immune response.\n*   **Immune Dysregulation:**  An overactive or misdirected immune
# response after the initial infection could be responsible.\n*   **Endothelial Dysfunction:** Damage to the lining
# of blood vessels may contribute to symptoms [3].\n*   **Autoimmunity:** The body's immune system might start
# attacking its own tissues.\n*   **Organ Damage:** Lingering damage to organs due to the initial infection can lead
# to persistent issues. It's likely a combination of these factors that contributes to Post-COVID Syndrome. Other
# potential mechanisms include cellular injury, select gene expression profiles, reduction in peripheral serotonin
# levels, microbiota dysbiosis, complement dysregulation and neurologic signaling dysfunction [1,2,4,5,6,7,8,9]."
#     },
#     'risk_factors': {
#         'heading': 'Risk Factors',
#         'content': [
#             'Severity of initial COVID-19 infection, although mild cases can still develop Long COVID.',
#             'Pre-existing conditions, such as diabetes, autoimmune disorders or respiratory issues.',
#             'Age, with older adults and those with comorbidities at higher risk.',
#             'Gender, with some studies suggesting women are slightly more susceptible.',
#             'Having a history of Epstein-Barr virus infection or other pre-existing conditions.',
#             'Lack of vaccination against COVID-19 may increase risk.'
#         ]
#     },
#     'diagnosis': {
#         'heading': 'Diagnosis',
#         'content': 'Diagnosing Post-COVID Syndrome can be challenging as there is no single diagnostic test.
# Diagnosis often involves a combination of factors:\n### Clinical Evaluation\nA thorough medical history, including
# the details of the initial COVID-19 infection, a physical exam, and assessment of reported symptoms.\n### Symptom
# Tracking\nMonitoring symptom patterns and severity over time through patient diaries or questionnaires can provide
# insights.\n### Exclusion of other conditions\nRule out other potential health issues that may be causing similar
# symptoms.\n### Diagnostic tests\nVarious laboratory tests and imaging such as chest X-rays, blood tests, and tests
# to evaluate organ function may be employed to assess the extent of the damage. There is no specific blood test that
# identifies long covid. The process is typically one of exclusion. Diagnosis is often based on the persistent
# symptoms after a period of time since initial infection, with no other clear cause. For patients with persistent
# symptoms recovering from moderate or severe illness, a complete blood count, blood chemistries, and liver function
# studies may be useful [18].'
#     },
#     'prevention': {
#         'heading': 'Prevention',
#         'content': [
#             'Vaccination against COVID-19 can reduce the risk of initial infection and may decrease the likelihood
# of developing Long COVID [14].',
#             'Following public health guidelines, such as wearing masks and practicing social distancing.',
#             'Prompt treatment of acute COVID-19 infection under medical guidance may help reduce the chances of
# Long COVID.',
#             'Maintaining a healthy lifestyle, including a balanced diet and regular exercise to support the immune
# system.',
#             'Reducing exposure to potential infection by taking precautions.'
#         ]
#     },
#     'specialist_to_visit': {
#         'heading': 'Specialist to Visit',
#         'content': 'Given the varied symptoms of Post-COVID Syndrome, several specialists may be involved in the
# diagnosis and management:\n*   **Primary Care Physician:** Initial evaluation and coordination of care.\n*
# **Pulmonologist:** For respiratory issues such as shortness of breath and lung problems.\n*   **Cardiologist:** For
# heart-related symptoms like chest pain and palpitations.\n*   **Neurologist:** For neurological issues, cognitive
# dysfunction, and headaches.\n*   **Psychiatrist/Psychologist:** To address mental health symptoms like anxiety and
# depression.\n*   **Physiotherapist/Occupational Therapist:**  To help with physical rehabilitation and daily
# functioning.\n*   **Infectious Disease Specialist:** To understand the underlying infection-related process.\nA
# multidisciplinary approach is often needed to address the wide array of symptoms associated with Post-COVID
# Syndrome.'
#     },
#     'treatment': {
#         'heading': 'Treatment',
#         'content': "Currently, there is no single cure for Post-COVID Syndrome, and treatment is largely focused on
# symptom management and rehabilitation. This often involves:\n*   **Medications:** Over-the-counter or prescription
# drugs to manage specific symptoms (e.g., pain relievers, anti-inflammatories, sleep aids).\n*   **Physical
# Therapy:** Exercises to improve strength, endurance, and respiratory function.\n*   **Cognitive Rehabilitation:**
# Strategies and therapies to address memory and attention problems ('brain fog').\n*   **Psychological Support:**
# Counseling or therapy to manage anxiety, depression, and other mental health challenges.\n*   **Multidisciplinary
# Approach:** Coordination of care among various specialists based on the individual's needs. Treatments are highly
# individualized based on the patient's unique symptoms and circumstances. More research is needed to identify
# effective treatments."
#     },
#     'home_care': {
#         'heading': 'Home-Care',
#         'content': [
#             'Pacing activities and avoiding overexertion, taking frequent breaks.',
#             'Maintaining a regular sleep schedule and creating a calming sleep environment.',
#             'Practicing relaxation techniques, such as deep breathing exercises or meditation.',
#             'Eating a nutritious diet and ensuring adequate hydration.',
#             'Monitoring symptoms and keeping a symptom diary to identify patterns.',
#             'Seeking emotional support from friends, family, or support groups.',
#             'Engaging in gentle exercise or movement as tolerated to promote recovery.'
#         ]
#     },
#     'living_with': {
#         'heading': 'Living With',
#         'content': 'Living with Post-COVID Syndrome can be challenging and requires a multifaceted approach. It
# involves:\n*   **Acceptance and Self-Compassion:** Recognizing that the condition is real and adjusting
# expectations accordingly.\n*   **Support Networks:** Joining support groups and connecting with others who
# understand the condition.\n*   **Advocating for Oneself:** Actively communicating with healthcare providers and
# seeking appropriate care.\n*   **Lifestyle Adjustments:** Making necessary modifications to daily routines to
# accommodate symptoms.\n*   **Mental Health Support:** Prioritizing mental well-being through therapy or counseling
# if needed. A holistic approach, focusing on physical, emotional, and social well-being is crucial to managing Long
# COVID.'
#     },
#     'complications': {
#         'heading': 'Complications',
#         'content': 'Post-COVID Syndrome can lead to several complications if not managed effectively. These
# include: \n*   **Reduced Quality of Life:** Chronic symptoms can impact daily functioning, employment, and social
# interactions. Post-exertional malaise, triggered by physical, cognitive, or psychological exertion, can also limit
# daily activities [12,13].\n*  **Mental Health Issues:** Anxiety, depression, and post-traumatic stress disorder are
# common and can worsen the overall condition.\n*   **Organ Damage:** Lingering issues with organs (e.g., heart,
# lungs) can result in long-term health problems.\n*   **Cardiovascular Problems:** An increased risk of conditions
# like blood clots, myocarditis, and other heart-related issues can occur.\n*  **Respiratory Issues:** Chronic
# shortness of breath, ongoing lung inflammation, or fibrosis can cause long-term pulmonary issues.\n*   **Cognitive
# Dysfunction:**  Persistent difficulties with memory, attention, and concentration may impact the ability to work or
# engage in regular daily activities.\n*   **Increased Healthcare Utilization:** Frequent visits to specialists and
# hospitalizations may be necessary, creating a strain on healthcare resources. Monitoring and addressing these
# issues early is important.'
#     },
#     'alternative_therapies': {
#         'heading': 'Alternative Therapies',
#         'content': "Some individuals with Post-COVID Syndrome explore alternative therapies to alleviate symptoms.
# While more research is needed to evaluate their effectiveness, they may include: \n*   **Acupuncture**: May be used
# to manage pain, fatigue, and improve energy flow.\n*   **Mindfulness and Meditation**: Used to reduce stress,
# improve focus, and manage mental health.\n*   **Yoga and Tai Chi**: Gentle forms of exercise to improve
# flexibility, strength and reduce stress.\n*   **Herbal Remedies:** Some people use herbal supplements or
# traditional medicines; however, it's important to consult with a healthcare professional before trying these
# therapies.\n*   **Nutritional Supplements:** Some supplements like vitamins may be helpful but it is essential to
# verify with your doctor that it is safe.\nIt is essential to use caution and discuss alternative therapies with a
# healthcare provider to ensure safety and avoid interactions with conventional treatments. It is also vital to
# ensure any practitioner is qualified."
#     },
#     'faqs': {
#         'heading': 'FAQs',
#         'content': [
#             {
#                 'question': 'How long does Post-COVID Syndrome last?',
#                 'answer': 'The duration of Post-COVID Syndrome varies widely. Some people recover within a few
# months, while others may experience symptoms for a year or longer. The long-term course is still being
# investigated.'
#             },
#             {
#                 'question': 'Can you get Long COVID from a mild COVID infection?',
#                 'answer': 'Yes, even mild cases of COVID-19 can lead to Long COVID. The severity of the initial
# infection does not necessarily predict the likelihood of developing Post-COVID Syndrome.'
#             },
#             {
#                 'question': 'Is there a cure for Post-COVID Syndrome?',
#                 'answer': 'Currently, there is no specific cure for Post-COVID Syndrome. Treatment focuses on
# managing symptoms and providing rehabilitation, as well as monitoring the progress of recovery.'
#             },
#             {
#                 'question': 'What is the link between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome?',
#                 'answer': 'There is an overlap between Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue
# Syndrome (ME/CFS), with many Long COVID patients meeting the diagnostic criteria for ME/CFS [15,16,17].'
#             },
#             {
#                 'question': 'What is the impact of vaccination on Long COVID?',
#                 'answer': 'Vaccination against COVID-19 may reduce the incidence of long COVID [14]. Some studies
# also indicate that vaccination after infection can decrease the likelihood of persistent symptoms.'
#             },
#             {
#                 'question': 'What should I do if I think I have Long COVID?',
#                 'answer': 'If you suspect you have Long COVID, consult your primary care physician. They can
# evaluate your symptoms, perform necessary tests, and refer you to specialists if needed.'
#             },
#             {
#                 'question': 'Is there any support available for people with Long COVID?',
#                 'answer': 'Yes, various support groups and organizations are available to help individuals with
# Long COVID. These groups can provide information, peer support, and advocacy.'
#             },
#             {
#                 'question': 'Can Long COVID be considered a disability?',
#                 'answer': 'Yes, Long COVID can be considered a disability under the Americans with Disabilities Act
# if it substantially limits one or more major life activities .'
#             },
#             {
#                 'question': 'Are there any treatments being investigated for Long COVID?',
#                 'answer': 'Yes, several therapies are under investigation, including low-dose naltrexone, Paxlovid,
# and some gut microbiome modulators [19,20,21,22].'
#             }
#         ]
#     },
#     'references': {
#         'heading': 'References',
#         'content': [
#             {
#                 'reference_number': 1,
#                 'authors': 'Siripanthong B, Asatryan B, Hanff TC, et al.',
#                 'year': '2022',
#                 'title': 'The Pathogenesis and Long-Term Consequences of COVID-19 Cardiac Injury.',
#                 'journal_source': 'JACC Basic Transl Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 2,
#                 'authors': 'Peluso MJ, Deeks SG.',
#                 'year': '2022',
#                 'title': 'Early clues regarding the pathogenesis of long-COVID.',
#                 'journal_source': 'Trends Immunol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 3,
#                 'authors': 'Fogarty H, Townsend L, Morrin H, et al.',
#                 'year': '2021',
#                 'title': 'Persistent endotheliopathy in the pathogenesis of long COVID syndrome.',
#                 'journal_source': 'J Thromb Haemost',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 4,
#                 'authors': 'Clark IA.',
#                 'year': '2022',
#                 'title': 'Chronic cerebral aspects of long COVID, post-stroke syndromes and similar states share
# their pathogenesis and perispinal etanercept treatment logic.',
#                 'journal_source': 'Pharmacol Res Perspect',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 5,
#                 'authors': 'Thompson RC, Simons NW, Wilkins L, et al.',
#                 'year': '2023',
#                 'title': 'Molecular states during acute COVID-19 reveal distinct etiologies of long-term
# sequelae.',
#                 'journal_source': 'Nat Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 6,
#                 'authors': 'Davis HE, McCorkell L, Vogel JM, Topol EJ.',
#                 'year': '2023',
#                 'title': 'Long COVID: major findings, mechanisms and recommendations.',
#                 'journal_source': 'Nat Rev Microbiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 7,
#                 'authors': 'Yao Q, Doyle ME, Liu QR, et al.',
#                 'year': '2023',
#                 'title': 'Long-Term Dysfunction of Taste Papillae in SARS-CoV-2.',
#                 'journal_source': 'NEJM Evid',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 8,
#                 'authors': 'Wong AC, Devason AS, Umana IC, et al.',
#                 'year': '2023',
#                 'title': 'Serotonin reduction in post-acute sequelae of viral infection.',
#                 'journal_source': 'Cell',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 9,
#                 'authors': 'Cervia-Hasler C, Br\\u00fcningk SC, Hoch T, et al.',
#                 'year': '2024',
#                 'title': 'Persistent complement dysregulation with signs of thromboinflammation in active Long
# Covid.',
#                 'journal_source': 'Science',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 10,
#                 'authors': 'Global Burden of Disease Long COVID Collaborators, Wulf Hanson S, Abbafati C, et al.',
#                 'year': '2022',
#                 'title': 'Estimated Global Proportions of Individuals With Persistent Fatigue, Cognitive, and
# Respiratory Symptom Clusters Following Symptomatic COVID-19 in 2020 and 2021.',
#                 'journal_source': 'JAMA',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 11,
#                 'authors': 'Sedgley R, Winer-Jones J, Bonafede M.',
#                 'year': '2023',
#                 'title': 'Long COVID Incidence in a Large US Ambulatory Electronic Health Record System.',
#                 'journal_source': 'Am J Epidemiol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 12,
#                 'authors': 'Cohen J, Rodgers YVM.',
#                 'year': '2024',
#                 'title': 'Long COVID Prevalence, Disability, and Accommodations: Analysis Across Demographic
# Groups.',
#                 'journal_source': 'J Occup Rehabil',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 13,
#                 'authors': 'Davis HE, Assaf GS, McCorkell L, et al.',
#                 'year': '2021',
#                 'title': 'Characterizing long COVID in an international cohort: 7 months of symptoms and their
# impact.',
#                 'journal_source': 'EClinicalMedicine',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 14,
#                 'authors': 'Byambasuren O, Stehlik P, Clark J, et al.',
#                 'year': '2023',
#                 'title': 'Effect of covid-19 vaccination on long covid: systematic review.',
#                 'journal_source': 'BMJ Med',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 15,
#                 'authors': 'Tate WP, Walker MOM, Peppercorn K, et al.',
#                 'year': '2023',
#                 'title': 'Towards a Better Understanding of the Complexities of Myalgic Encephalomyelitis/Chronic
# Fatigue Syndrome and Long COVID.',
#                 'journal_source': 'Int J Mol Sci',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 16,
#                 'authors': 'Renz-Polster H, Scheibenbogen C.',
#                 'year': '2022',
#                 'title': '[Post-COVID syndrome with fatigue and exercise intolerance: myalgic
# encephalomyelitis/chronic fatigue syndrome].',
#                 'journal_source': 'Inn Med (Heidelb)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 17,
#                 'authors': 'Wong TL, Weitzer DJ.',
#                 'year': '2021',
#                 'title': 'Long COVID and Myalgic Encephalomyelitis/Chronic Fatigue Syndrome (ME/CFS)-A Systemic
# Review and Comparison of Clinical Presentation and Symptomatology.',
#                 'journal_source': 'Medicina (Kaunas)',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 18,
#                 'authors': 'Arnold DT, Hamilton FW, Milne A, et al.',
#                 'year': '2021',
#                 'title': 'Patient outcomes after hospitalisation with COVID-19 and implications for follow-up:
# results from a prospective UK cohort.',
#                 'journal_source': 'Thorax',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 19,
#                 'authors': 'Cohen AK, Jaudon TW, Schurman EM, et al.',
#                 'year': '2023',
#                 'title': 'Impact of extended-course oral nirmatrelvir/ritonavir (Paxlovid) in established Long
# COVID: Case series and research considerations.',
#                 'journal_source': 'Res Sq',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 20,
#                 'authors': "O'Kelly B, Vidal L, McHugh T, et al.",
#                 'year': '2022',
#                 'title': 'Safety and efficacy of low dose naltrexone in a long covid cohort; an interventional
# pre-post study.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 21,
#                 'authors': 'Isman A, Nyquist A, Strecker B, et al.',
#                 'year': '2024',
#                 'title': 'Low-dose naltrexone and NAD+ for the treatment of patients with persistent fatigue
# symptoms after COVID-19.',
#                 'journal_source': 'Brain Behav Immun Health',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 22,
#                 'authors': 'Zhang L, Xu Z, Mak JWY, et al.',
#                 'year': '2022',
#                 'title': 'Gut microbiota-derived synbiotic formula (SIM01) as a novel adjuvant therapy for
# COVID-19: An open-label pilot study.',
#                 'journal_source': 'J Gastroenterol Hepatol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 23,
#                 'authors': 'Lau RI, Su Q, Lau ISF, et al.',
#                 'year': '2024',
#                 'title': 'A synbiotic preparation (SIM01) for post-acute COVID-19 syndrome in Hong Kong (RECOVERY):
# a randomised, double-blind, placebo-controlled trial.',
#                 'journal_source': 'Lancet Infect Dis',
#                 'url_doi': None
#             }
#         ]
#     }
# }

# %%
from typing import Any, List, Dict, Callable, Coroutine, TypeVar, ParamSpec, Union, Set

def identify_bad_references(data: Dict) -> Set[int]:
    """Identifies references that are missing required fields."""
    bad_references = set()
    if "references" in data and "content" in data["references"]:
        for ref in data["references"]["content"]:
            if (
                not ref.get("journal_source")
                or not ref.get("authors")
                or not ref.get("year")
            ):
                bad_references.add(ref["reference_number"])
    return bad_references



def identify_all_inline_citations(data: Dict) -> Set[int]:
    """
    Identifies all unique inline citations (e.g., [1], [2, 3]) in the document.

    Recursively processes nested dictionaries and lists within all sections,
    except for the "references" section.
    """

    def _extract_citations_from_text(text: str) -> Set[int]:
        """Helper function to extract citations from a text string."""
        citations = set()
        matches = re.findall(r"\[([^\]]+)\]", text)
        for match in matches:
            for ref in match.split(","):
                ref = ref.strip()
                if ref.isdigit():
                    citations.add(int(ref))
        return citations

    def _recursive_process(item: Any, in_references_section: bool = False) -> Set[int]:
        """Recursively processes dictionaries, lists, and strings."""
        citations = set()
        if isinstance(item, str):
            if not in_references_section:
                citations.update(_extract_citations_from_text(item))
        elif isinstance(item, dict):
            # Correctly set in_references_section for child elements
            is_current_references = "references" in item
            for value in item.values():
                citations.update(
                    _recursive_process(value, is_current_references)
                )  # Pass the flag based on the current item

        elif isinstance(item, list):
            for list_item in item:
                citations.update(_recursive_process(list_item, in_references_section))
        return citations

    return _recursive_process(data)


def get_all_reference_numbers(references_section: Dict) -> Set[int]:
    """
    Extracts all reference numbers from the 'references' section,
    even if they are not integers (for finding unused references).
    """
    reference_numbers = set()
    if isinstance(references_section, dict):
        for item in references_section.get("content", []):
            ref_num = item.get("reference_number")
            if ref_num is not None:
                reference_numbers.add(ref_num)
    return reference_numbers




def remove_references(data: Dict, references_to_remove: set) -> Dict:
    """Removes specified references from the 'references' section."""
    if "references" in data and "content" in data["references"]:
        data["references"]["content"] = [
            ref
            for ref in data["references"]["content"]
            if ref["reference_number"] not in references_to_remove
        ]
    return data


def remove_inline_citations(data: Dict, references_to_remove: set) -> Dict:
    """Removes inline citations corresponding to the specified reference numbers.

    Recursively processes nested dictionaries and lists within all sections,
    except for the "references" section.
    """

    def _process_text(text: str) -> str:
        """Helper function to process individual text strings."""
        return re.sub(
            r"\[([^\]]+)\]",
            lambda match: "["
            + ",".join(
                ref.strip()
                for ref in match.group(1).split(",")
                if not (ref.strip().isdigit() and int(ref.strip()) in references_to_remove)
            )
            + "]"
            if any(
                ref.strip().isdigit() and int(ref.strip()) not in references_to_remove
                for ref in match.group(1).split(",")
            )
            else "",
            text,
        )

    def _recursive_process(item: Any, in_references_section: bool = False) -> Any:
        """Recursively processes dictionaries, lists, and strings.
        Skips processing if inside the 'references' section.
        """
        if isinstance(item, str):
            return item if in_references_section else _process_text(item)
        elif isinstance(item, dict):
            if "references" in item:
                return {
                    key: _recursive_process(value, key == "references")
                    for key, value in item.items()
                }
            else:
                return {
                    key: _recursive_process(value, in_references_section)
                    for key, value in item.items()
                }

        elif isinstance(item, list):
            return [_recursive_process(list_item, in_references_section) for list_item in item]
        else:
            return item

    return _recursive_process(data)


def create_remap_dictionary(data: Dict) -> Dict:
    """Creates a dictionary to map old reference numbers to new sequential ones."""
    reference_numbers = []
    if "references" in data and "content" in data["references"]:
        for ref in data["references"]["content"]:
            if "reference_number" in ref:
                reference_numbers.append(ref["reference_number"])

    reference_numbers.sort()
    return {
        old_num: new_num
        for new_num, old_num in enumerate(reference_numbers, start=1)
    }


def update_reference_numbers(data: Dict, remap: Dict) -> Dict:
    """Updates reference numbers in the 'references' section based on the remap dictionary."""
    if "references" in data and "content" in data["references"]:
        for ref in data["references"]["content"]:
            if "reference_number" in ref:
                ref["reference_number"] = remap[ref["reference_number"]]
    return data


def update_inline_citations(data: Dict, remap: Dict) -> Dict:
    """Updates inline citations to reflect new reference numbers based on the remap dictionary.

    Recursively processes nested dictionaries and lists within all sections,
    except for the "references" section.
    """

    def _process_text(text: str, remap: Dict) -> str:
        """Helper function to process individual text strings."""

        def _replace_citation(match):
            updated_refs = []
            for ref in match.group(1).split(","):
                ref_str = ref.strip()
                if ref_str.isdigit():
                    ref_int = int(ref_str)
                    updated_ref = remap.get(ref_int, ref_str)  # Use int key, fallback to original if not found
                else:
                    updated_ref = ref_str
                updated_refs.append(str(updated_ref))
            return "[" + ",".join(updated_refs) + "]"

        return re.sub(r"\[([^\]]+)\]", _replace_citation, text)

    def _recursive_process(item: Any, remap:Dict, in_references_section: bool = False) -> Any:
        """Recursively processes dictionaries, lists, and strings.
        Skips processing if inside the 'references' section.
        """
        if isinstance(item, str):
            return item if in_references_section else _process_text(item, remap)
        elif isinstance(item, dict):
            if "references" in item:
                return {
                    key: _recursive_process(value, remap, key == "references")
                    for key, value in item.items()
                }
            else:
                return {
                    key: _recursive_process(value, remap, in_references_section)
                    for key, value in item.items()
                }
        elif isinstance(item, list):
            return [
                _recursive_process(list_item, remap, in_references_section)
                for list_item in item
            ]
        else:
            return item

    return _recursive_process(data, remap)


def check_for_duplicate_references(data: Dict) -> bool:
    """Checks if the references section contains duplicate reference numbers"""
    reference_numbers = []
    if "references" in data and "content" in data["references"]:
        for ref in data["references"]["content"]:
            if "reference_number" in ref:
                reference_numbers.append(ref["reference_number"])

    # Check for uniqueness
    return len(reference_numbers) != len(set(reference_numbers))


def clean_references(data: Dict) -> Dict:
    """
    Cleans up references in the document:

    1. Identifies and removes orphaned inline citations.
    2. Identifies and removes unused references.
    3. Renumbers references and updates inline citations.
    """

    # 1. Identify Inline Citations and Reference Numbers
    inline_citations = identify_all_inline_citations(data)
    all_reference_numbers = get_all_reference_numbers(data.get("references", {}))

    # 2. Find Orphaned and Unused
    orphaned_citations = inline_citations - all_reference_numbers
    unused_references = all_reference_numbers - inline_citations

    # 3. Identify bad references
    bad_references = identify_bad_references(data)

    # 4. Remove Orphaned Citations and Unused References
    data = remove_inline_citations(data, orphaned_citations)
    data = remove_references(data, unused_references)
    data = remove_references(data, bad_references)

    # 5. Renumber and Update
    remap_dict = create_remap_dictionary(data)
    data = update_reference_numbers(data, remap_dict)
    data = update_inline_citations(data, remap_dict)

    # 6. Check for Duplicates
    if check_for_duplicate_references(data):
        print("Warning: Duplicate reference numbers found after cleaning.")

    return data


rprint(clean_references(article_data))
# Out:
# {
#     'title': 'Liver Cancer',
#     'subtitle': 'A malignant tumor arising from the liver cells.',
#     'overview': {
#         'heading': 'Overview',
#         'content': 'Liver cancer, also known as hepatic cancer, is a malignancy that originates in the liver. It is
# a significant health concern worldwide and is often diagnosed at advanced stages. Primary liver cancer arises from
# the liver cells themselves, while secondary liver cancer occurs when cancer from other parts of the body spreads to
# the liver. The prognosis and treatment options vary greatly depending on the type and stage at diagnosis. Globally,
# it is among the leading causes of cancer-related deaths [1,2]. In 2022, there were approximately 20 million new
# cancer cases worldwide, with liver cancer accounting for 7.8% of cancer-related deaths [3]. '
#     },
#     'key_facts': {
#         'heading': 'Key Facts',
#         'content': [
#             'Liver cancer is the most common type of cancer worldwide.',
#             'Hepatocellular carcinoma (HCC) is the most common type of primary liver cancer.',
#             'Chronic hepatitis B and C infections are major risk factors for developing liver cancer [4].',
#             'Liver cancer often presents with non-specific symptoms, which makes early detection difficult.',
#             'Survival rates for liver cancer vary greatly depending on the stage of diagnosis.',
#             'Surgical resection offers the greatest chance of cure for liver-isolated colorectal cancer [3].'
#         ]
#     },
#     'symptoms': {
#         'heading': 'Symptoms',
#         'content': [
#             'Abdominal pain or discomfort, particularly in the upper right quadrant',
#             'Unexplained weight loss',
#             'Loss of appetite or feeling full quickly',
#             'Nausea and vomiting',
#             'Jaundice (yellowing of the skin and eyes)',
#             'Swelling or fluid build-up in the abdomen (ascites)',
#             'Enlarged liver or spleen',
#             'Fatigue and weakness'
#         ]
#     },
#     'types': {
#         'heading': 'Types',
#         'content': 'Liver cancer can be broadly classified into primary and secondary types.\n\n### Primary Liver
# Cancer\n\nPrimary liver cancer originates in the liver itself.\n\n#### Hepatocellular Carcinoma (HCC)\nHCC is the
# most common type of primary liver cancer, arising from the hepatocytes, the main liver cells [5].\n\n####
# Cholangiocarcinoma (Intrahepatic)\nIntrahepatic cholangiocarcinoma arises from the bile ducts within the liver. The
# incidence of intrahepatic cholangiocarcinoma has been rising in the US [6].\n\n#### Hepatoblastoma\nHepatoblastoma
# is a rare type of liver cancer that primarily affects children [7].\n\n### Secondary Liver Cancer\n\nSecondary
# liver cancer occurs when cancer from another part of the body spreads to the liver (metastasis). Common sources
# include colon, lung and breast cancer. Liver metastases from colon cancer are associated with increased expression
# of vascular endothelial growth factor (VEGF) [8].'
#     },
#     'causes': {
#         'heading': 'Causes',
#         'content': 'The exact causes of liver cancer are complex and often involve multiple factors. However,
# several major causes and associations have been identified:\n\n*   **Chronic Viral Hepatitis:** Chronic infections
# with hepatitis B and C viruses are significant risk factors for HCC [9]. Hepatitis B is responsible for 33% of
# liver cancer deaths worldwide [9].\n*   **Cirrhosis:** Long-term damage to the liver, often due to alcohol abuse or
# chronic hepatitis, leads to cirrhosis, which can increase cancer risk [10].\n*   **Non-Alcoholic Fatty Liver
# Disease (NAFLD):** This condition, often linked to obesity and diabetes, can cause inflammation and damage to the
# liver, increasing the risk of liver cancer [11].\n*   **Aflatoxins:** Exposure to aflatoxins, which are toxins
# produced by certain molds that can contaminate food, can increase the risk [12].\n*   **Genetic Conditions:**
# Certain genetic disorders, such as hemochromatosis, can also predispose individuals to liver cancer [13].'
#     },
#     'risk_factors': {
#         'heading': 'Risk Factors',
#         'content': [
#             'Chronic hepatitis B or C infection',
#             'Cirrhosis of the liver',
#             'Excessive alcohol consumption',
#             'Non-alcoholic fatty liver disease (NAFLD)',
#             'Exposure to aflatoxins',
#             'Family history of liver cancer',
#             "Certain inherited liver diseases such as hemochromatosis or Wilson's disease",
#             'Obesity and type 2 diabetes',
#             'Age (risk increases with age)'
#         ]
#     },
#     'diagnosis': {
#         'heading': 'Diagnosis',
#         'content': 'The diagnosis of liver cancer typically involves a combination of methods:\n\n### Physical
# Examination\n*   The doctor will perform a physical exam, feeling for an enlarged liver or any other
# abnormalities.\n\n### Blood Tests\n*   Liver function tests (LFTs) measure enzymes and other substances to assess
# liver health.\n*   Alpha-fetoprotein (AFP) test is a tumor marker that can be elevated in some cases of liver
# cancer [14].\n*   Viral hepatitis tests are performed to identify hepatitis B or C.\n\n### Imaging Tests\n*
# **Ultrasound:** An initial imaging method to visualize the liver.\n*   **CT Scan:** Provides detailed
# cross-sectional images of the liver.\n*   **MRI:** Offers another detailed view of the liver, often used for
# further characterization of lesions. MRI is often preferred over CT scans for liver imaging because of its
# sensitivity in detecting additional lesions [16].\n\n### Liver Biopsy\n*   A small sample of liver tissue is taken
# for microscopic examination to confirm the presence of cancer cells. Liver stiffness measurement using transient
# elastography is a noninvasive method that can detect significant fibrosis or cirrhosis, which can inform the
# decision to biopsy [15].\n\n### Staging\n* Once diagnosed, staging is performed to determine the extent of the
# cancer and guide treatment decisions.'
#     },
#     'prevention': {
#         'heading': 'Prevention',
#         'content': [
#             'Vaccination against hepatitis B [17]',
#             'Screening and treatment for chronic hepatitis B and C infections',
#             'Limiting alcohol consumption',
#             'Maintaining a healthy weight and managing diabetes',
#             'Avoiding exposure to aflatoxins by ensuring proper food storage',
#             'Regular check-ups and screenings, especially for high-risk individuals'
#         ]
#     },
#     'specialist_to_visit': {
#         'heading': 'Specialist to Visit',
#         'content': 'Several specialists may be involved in the diagnosis and treatment of liver cancer:\n\n*
# **Hepatologist:** A doctor specializing in liver diseases.\n*   **Oncologist:** A doctor specializing in cancer
# treatment, including medical oncology, radiation oncology, and surgical oncology.\n*   **Interventional
# Radiologist:** A doctor who uses imaging techniques to perform procedures such as biopsies and tumor ablations.\n*
# **Surgeon:** Specializes in performing liver surgery, which may include tumor removal or liver transplantation.'
#     },
#     'treatment': {
#         'heading': 'Treatment',
#         'content': "Treatment for liver cancer depends on the stage, size, location, and type of cancer, as well as
# the patient's overall health. Common treatments include:\n\n*   **Surgery:** Resection involves removing the
# cancerous part of the liver. Liver transplant is an option in select cases. \n*   **Ablation Therapies:**  These
# include radiofrequency ablation (RFA), microwave ablation, and cryoablation that use heat, microwaves or freezing
# to destroy cancer cells. For RFA, tumors less than 3 cm and margins greater than 5 mm are associated with better
# outcomes [18].\n*   **Radiation Therapy:** High-energy rays are used to target and kill cancer cells.\n*
# **Chemotherapy:** Medications are used to kill cancer cells or slow their growth.\n*   **Targeted Therapy:** Drugs
# that target specific molecules involved in cancer cell growth.\n*  **Immunotherapy:** Stimulates the body’s immune
# system to fight cancer cells. Immunotherapies may be less effective in patients with liver metastases [19].\n*
# **Transarterial Chemoembolization (TACE):** A procedure that blocks the blood supply to tumors and delivers
# chemotherapy directly to the liver. This is used in cases where surgery is not an option. Superselective
# conventional TACE is recommended as a first choice for suitable patients [20].\n\nFor patients with colorectal
# cancer that has spread to the liver, surgical removal of the liver metastases is an option. When the metastases
# cannot be removed surgically, other treatments include ablation and chemotherapy [1,2]."
#     },
#     'home_care': {
#         'heading': 'Home-Care',
#         'content': [
#             'Follow the treatment plan prescribed by the healthcare team',
#             'Maintain a balanced and nutritious diet to support liver function',
#             'Stay hydrated and avoid alcohol consumption',
#             'Manage pain and other symptoms with medications as directed',
#             'Get adequate rest and avoid strenuous activities',
#             'Engage in light physical activity as tolerated',
#             'Seek emotional support and consider counseling'
#         ]
#     },
#     'living_with': {
#         'heading': 'Living With',
#         'content': 'Living with liver cancer can be challenging. It is important to manage the condition with a
# holistic approach:\n\n*   **Medical Management:** Follow up regularly with doctors and adhere to prescribed
# treatment plans.\n*   **Lifestyle Adjustments:** Maintain a healthy diet, avoid alcohol, manage stress, and engage
# in regular low-impact physical activity as tolerated.\n*   **Emotional Well-being:** Seek support from family,
# friends, support groups, or mental health professionals to cope with the emotional burden.\n*   **Financial
# Planning:** Cancer treatment can be costly so exploring financial assistance programs might be necessary.\n*
# **Palliative Care:** When cancer is advanced, palliative care can provide relief from symptoms and improve quality
# of life.'
#     },
#     'complications': {
#         'heading': 'Complications',
#         'content': "Untreated or poorly managed liver cancer can lead to various complications:\n\n*   **Liver
# Failure:** The liver's inability to function properly, leading to jaundice, ascites, and other severe symptoms
# [21].\n*   **Metastasis:** Spread of cancer to other parts of the body, such as lungs, bones, or brain [22].\n*
# **Pain:** Can be severe and difficult to manage.\n*   **Bleeding:**  Liver dysfunction can affect blood clotting
# leading to bleeding complications.\n*   **Ascites:** Accumulation of fluid in the abdominal cavity, causing
# discomfort and difficulty breathing [23].\n*   **Encephalopathy:**  Liver dysfunction can result in build-up of
# toxins in the brain leading to cognitive impairment [23].\n*   **Weight loss and malnutrition**"
#     },
#     'alternative_therapies': {
#         'heading': 'Alternative Therapies',
#         'content': "Some patients explore alternative or complementary therapies to complement conventional
# treatment. It's vital to discuss these options with a healthcare provider as some may interact with conventional
# treatments, or may not have robust scientific evidence to support their use. Some commonly explored options include
# herbal medicine, acupuncture, meditation, and nutritional therapies. MRI-guided focused ultrasound (MRgFUS) is a
# non-invasive thermal ablation method that is being explored for liver cancer treatment [24]. Always consult with
# your oncologist before undertaking any alternative therapies."
#     },
#     'faqs': {
#         'heading': 'FAQs',
#         'content': [
#             {
#                 'question': 'What is the most common type of liver cancer?',
#                 'answer': 'The most common type of primary liver cancer is hepatocellular carcinoma (HCC).'
#             },
#             {
#                 'question': 'What are the main risk factors for developing liver cancer?',
#                 'answer': 'Main risk factors include chronic hepatitis B and C infections, liver cirrhosis,
# excessive alcohol consumption, and non-alcoholic fatty liver disease.'
#             },
#             {
#                 'question': 'Can liver cancer be cured?',
#                 'answer': 'Liver cancer can be cured if detected at an early stage and surgically removed or
# transplanted. However, advanced stages may be managed but not cured. Early detection is key.'
#             },
#             {
#                 'question': 'What is the survival rate for liver cancer?',
#                 'answer': 'Survival rates vary widely depending on the stage at diagnosis. Resection offers the
# greatest likelihood of cure for patients with liver-isolated colorectal cancer. Five-year survival rates after
# resection range from 24 to 58 percent, averaging 40 percent [3,4,5,6].'
#             },
#             {
#                 'question': 'What is a liver biopsy?',
#                 'answer': 'A liver biopsy involves taking a small sample of liver tissue for microscopic
# examination to confirm the presence of cancer cells. It is performed if imaging tests suggests cancer.'
#             },
#             {
#                 'question': 'Can liver cancer spread?',
#                 'answer': 'Yes, liver cancer can spread (metastasize) to other parts of the body, such as the
# lungs, bones, and brain.'
#             },
#             {
#                 'question': 'What is the role of chemotherapy in treating liver cancer?',
#                 'answer': "Chemotherapy is used to kill cancer cells or slow their growth. It can be used before
# surgery to shrink tumors or after surgery to eliminate remaining cancer cells. In some cases, it's the primary
# treatment if surgery is not an option."
#             },
#             {
#                 'question': 'When is liver transplantation considered?',
#                 'answer': "Liver transplantation is an option for some patients with early-stage liver cancer who
# meet specific criteria, including the absence of spread outside the liver. It's often considered if the cancer is
# unresectable."
#             },
#             {
#                 'question': 'Can a liver abscess be related to liver cancer?',
#                 'answer': 'Studies have indicated an association between pyogenic liver abscess and colorectal
# cancer [7,8,9,10,11,12,13,14,15].'
#             }
#         ]
#     },
#     'references': {
#         'heading': 'References',
#         'content': [
#             {
#                 'reference_number': 3,
#                 'authors': 'Fong Y, Fortner J, Sun RL, et al',
#                 'year': 1999,
#                 'title': 'Clinical score for predicting recurrence after hepatic resection for metastatic
# colorectal cancer: analysis of 1001 consecutive cases.',
#                 'journal_source': 'Ann Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 4,
#                 'authors': 'Nordlinger B, Guiguet M, Vaillant JC, et al',
#                 'year': 1996,
#                 'title': 'Surgical resection of colorectal carcinoma metastases to the liver. A prognostic scoring
# system to improve case selection, based on 1568 patients. Association Française de Chirurgie.',
#                 'journal_source': 'Cancer',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 5,
#                 'authors': 'Fernandez FG, Drebin JA, Linehan DC, et al',
#                 'year': 2004,
#                 'title': 'Five-year survival after resection of hepatic metastases from colorectal cancer in
# patients screened by positron emission tomography with F-18 fluorodeoxyglucose (FDG-PET).',
#                 'journal_source': 'Ann Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 6,
#                 'authors': 'Simmonds PC, Primrose JN, Colquitt JL, et al',
#                 'year': 2006,
#                 'title': 'Surgical resection of hepatic metastases from colorectal cancer: a systematic review of
# published studies.',
#                 'journal_source': 'Br J Cancer',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 1,
#                 'authors': 'Garden OJ, Rees M, Poston GJ, et al',
#                 'year': 2006,
#                 'title': 'Guidelines for resection of colorectal cancer liver metastases.',
#                 'journal_source': 'Gut',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 2,
#                 'authors': 'Petrelli NJ',
#                 'year': 2007,
#                 'title': 'Plenary program discussion.',
#                 'journal_source': '43rd Annual Meeting of the American Society of Clinical Oncology, Chicago, IL',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 7,
#                 'authors': 'Kao WY, Hwang CY, Chang YT, et al',
#                 'year': 2012,
#                 'title': 'Cancer risk in patients with pyogenic liver abscess: a nationwide cohort study.',
#                 'journal_source': 'Aliment Pharmacol Ther',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 8,
#                 'authors': 'Koo HC, Kim YS, Kim SG, et al',
#                 'year': 2013,
#                 'title': 'Should colonoscopy be performed in patients with cryptogenic liver abscess?',
#                 'journal_source': 'Clin Res Hepatol Gastroenterol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 9,
#                 'authors': 'Jeong SW, Jang JY, Lee TH, et al',
#                 'year': 2012,
#                 'title': 'Cryptogenic pyogenic liver abscess as the herald of colon cancer.',
#                 'journal_source': 'J Gastroenterol Hepatol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 10,
#                 'authors': 'Qu K, Liu C, Wang ZX, et al',
#                 'year': 2012,
#                 'title': 'Pyogenic liver abscesses associated with nonmetastatic colorectal cancers: an increasing
# problem in Eastern Asia.',
#                 'journal_source': 'World J Gastroenterol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 11,
#                 'authors': 'Huang WK, Chang JW, See LC, et al',
#                 'year': 2012,
#                 'title': 'Higher rate of colorectal cancer among patients with pyogenic liver abscess with
# Klebsiella pneumoniae than those without: an 11-year follow-up study.',
#                 'journal_source': 'Colorectal Dis',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 12,
#                 'authors': 'Lai HC, Lin CC, Cheng KS, et al',
#                 'year': 2014,
#                 'title': 'Increased incidence of gastrointestinal cancers among patients with pyogenic liver
# abscess: a population-based cohort study.',
#                 'journal_source': 'Gastroenterology',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 13,
#                 'authors': 'Mohan BP, Meyyur Aravamudan V, Khan SR, et al',
#                 'year': 2019,
#                 'title': 'Prevalence of colorectal cancer in cryptogenic pyogenic liver abscess patients. Do they
# need screening colonoscopy? A systematic review and meta-analysis.',
#                 'journal_source': 'Dig Liver Dis',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 14,
#                 'authors': 'Mezhir JJ, Fong Y, Jacks LM, et al',
#                 'year': 2010,
#                 'title': 'Current management of pyogenic liver abscess: surgery is now second-line treatment.',
#                 'journal_source': 'J Am Coll Surg',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 15,
#                 'authors': 'Suzuki H, Kidder I, Tanaka T, Goto M',
#                 'year': 2023,
#                 'title': 'Incidence of Colorectal Cancer in Patients Diagnosed With Pyogenic Liver Abscess.',
#                 'journal_source': 'JAMA Netw Open',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 16,
#                 'authors': 'Adam R, Wicherts DA, de Haas RJ, et al',
#                 'year': 2008,
#                 'title': 'Complete pathologic response after preoperative chemotherapy for colorectal liver
# metastases: myth or reality?',
#                 'journal_source': 'J Clin Oncol',
#                 'url_doi': None
#             },
#             {
#                 'reference_number': 17,
#                 'authors': 'Mei-Hwei Chang, Chien-Jen Chen, M. Lai',
#                 'year': 1997,
#                 'title': 'Universal hepatitis B vaccination in Taiwan and the incidence of hepatocellular carcinoma
# in children. Taiwan Childhood Hepatoma Study Group.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.nejm.org/doi/pdf/10.1056/NEJM199706263362602?articleTools=true'
#             },
#             {
#                 'reference_number': 18,
#                 'authors': 'Waleed Shady, E. Petre, M. Gonen',
#                 'year': 2016,
#                 'title': 'Percutaneous Radiofrequency Ablation of Colorectal Cancer Liver Metastases: Factors
# Affecting Outcomes--A 10-year Experience at a Single Center.',
#                 'journal_source': 'Radiology',
#                 'url_doi': 'https://europepmc.org/articles/pmc4734163?pdf=render'
#             },
#             {
#                 'reference_number': 19,
#                 'authors': 'James C. Lee, Sadaf Mehdizadeh, Jennifer Smith',
#                 'year': 2020,
#                 'title': 'Regulatory T cell control of systemic immunity and immunotherapy response in liver
# metastasis',
#                 'journal_source': 'Science immunology',
#                 'url_doi': 'https://www.semanticscholar.org/paper/d437e62cf94487ebc1bfc9ff6f2b0f6287616d07'
#             },
#             {
#                 'reference_number': 20,
#                 'authors': 'M. Kudo, K. Han, S. Ye',
#                 'year': 2020,
#                 'title': 'A Changing Paradigm for the Treatment of Intermediate-Stage Hepatocellular Carcinoma:
# Asia-Pacific Primary Liver Cancer Expert Consensus Statements',
#                 'journal_source': 'Liver Cancer',
#                 'url_doi': 'https://www.karger.com/Article/Pdf/507370'
#             },
#             {
#                 'reference_number': 21,
#                 'authors': 'M. Kudo, O. Matsui, N. Izumi',
#                 'year': 2014,
#                 'title': 'JSH Consensus-Based Clinical Practice Guidelines for the Management of Hepatocellular
# Carcinoma: 2014 Update by the Liver Cancer Study Group of Japan',
#                 'journal_source': 'Liver Cancer',
#                 'url_doi': 'https://www.karger.com/Article/Pdf/343875'
#             },
#             {
#                 'reference_number': 22,
#                 'authors': 'A. Studebaker, G. Storci, J. Werbeck',
#                 'year': 2008,
#                 'title': 'Fibroblasts isolated from common sites of breast cancer metastasis enhance cancer cell
# growth rates and invasiveness in an interleukin-6-dependent manner.',
#                 'journal_source': 'Cancer Research',
#                 'url_doi':
# 'https://figshare.com/articles/journal_contribution/Supplementary_Figure_1_from_Fibroblasts_Isolated_from_Common_Si
# tes_of_Breast_Cancer_Metastasis_Enhance_Cancer_Cell_Growth_Rates_and_Invasiveness_in_an_Interleukin-6_Dependent_Man
# ner/22374389/1/files/39819623.pdf'
#             },
#             {
#                 'reference_number': 23,
#                 'authors': 'A. Sanyal, M. V. Van Natta, J. Clark',
#                 'year': 2021,
#                 'title': 'Prospective Study of Outcomes in Adults with Nonalcoholic Fatty Liver Disease.',
#                 'journal_source': 'New England Journal of Medicine',
#                 'url_doi': 'https://www.nejm.org/doi/pdf/10.1056/NEJMoa2029349?articleTools=true'
#             },
#             {
#                 'reference_number': 24,
#                 'authors': 'F. Jolesz',
#                 'year': 2007,
#                 'title': 'MRI-guided focused ultrasound surgery.',
#                 'journal_source': 'Annual Review of Medicine',
#                 'url_doi': 'https://europepmc.org/articles/pmc4005559?pdf=render'
#             }
#         ]
#     }
# }
