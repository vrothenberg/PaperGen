# %%
import os 
import asyncio
import aiohttp
import random
from typing import List, Dict
from rich import print as rprint

from dotenv import load_dotenv

load_dotenv()

search_url = "https://api.semanticscholar.org/graph/v1/paper/search"

# %%
import requests
import time
import csv

# Constants
SEMANTIC_SCHOLAR_API_URL = "https://api.semanticscholar.org/graph/v1"
SEARCH_ENDPOINT = f"{SEMANTIC_SCHOLAR_API_URL}/paper/search"
PAPER_FIELDS = "title,abstract,authors,citationCount,influentialCitationCount,referenceCount,url,venue,publicationVenue,year,openAccessPdf,journal"

# Parameters
QUERY = "Systemic Lupus Erythematosus"  # Replace with your query
LIMIT = 100  # Number of papers to retrieve per request
OFFSET = 0  # Starting point for retrieval
MAX_RESULTS = 1000  # Maximum number of papers to retrieve
HIGH_IMPACT_JOURNALS_FILE = "high_impact_journals.csv"
MIN_CITATIONS = 50  # Minimum number of citations to consider a paper impactful
PUBLICATION_TYPES = "JournalArticle,Review,CaseReport,ClinicalTrial,Conference"

# Search papers using Semantic Scholar API
def search_papers(query, limit=100, offset=0):
    params = {
        "query": query,
        "limit": limit,
        "offset": offset,
        "fields": PAPER_FIELDS,
        "minCitationCount": MIN_CITATIONS,
        "publicationTypes": PUBLICATION_TYPES
    }
    response = requests.get(SEARCH_ENDPOINT, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None


results = search_papers(QUERY)

# %%
results['data'][0]
# Out:
# {'paperId': '6019cc5eb993f3490ddac510d0350b287098e7da',
#  'publicationVenue': {'id': 'd4a5fe3b-9c8d-4b96-a023-0fe8d2a3156b',
#   'name': 'Arthritis & Rheumatism',
#   'type': 'journal',
#   'alternate_names': ['Arthritis  Rheum'],
#   'issn': '0004-3591',
#   'url': 'http://www3.interscience.wiley.com/cgi-bin/jhome/76509746',
#   'alternate_urls': ['https://onlinelibrary.wiley.com/journal/15290131',
#    'http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)2326-5205',
#    'http://www3.interscience.wiley.com/cgi-bin/jhome/77005015',
#    'http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)2151-4658',
#    'http://www3.interscience.wiley.com/cgi-bin/jhome/76509746?CRETRY=1&SRETRY=0',
#    'http://onlinelibrary.wiley.com/journal/10.1002/(ISSN)1529-0131',
#    'http://www3.interscience.wiley.com/cgi-bin/jtoc/112142621/']},
#  'url': 'https://www.semanticscholar.org/paper/6019cc5eb993f3490ddac510d0350b287098e7da',
#  'title': 'The 1982 revised criteria for the classification of systemic lupus erythematosus.',
#  'abstract': "The 1971 preliminary criteria for the classification of systemic lupus erythematosus (SLE) were revised and updated to incorporate new immunologic knowledge and improve disease classification. The 1982 revised criteria include fluorescence antinuclear antibody and antibody to native DNA and Sm antigen. Some criteria involving the same organ systems were aggregated into single criteria. Raynaud's phenomenon and alopecia were not included in the 1982 revised criteria because of low sensitivity and specificity. The new criteria were 96% sensitive and 96% specific when tested with SLE and control patient data gathered from 18 participating clinics. When compared with the 1971 criteria, the 1982 revised criteria showed gains in sensitivity and specificity.",
#  'venue': 'Arthritis & Rheumatism',
#  'year': 1982,
#  'referenceCount': 7,
#  'citationCount': 14567,
#  'influentialCitationCount': 509,
#  'openAccessPdf': None,
#  'journal': {'name': 'Arthritis and rheumatism',
#   'pages': '\n          1271-7\n        ',
#   'volume': '25 11'},
#  'authors': [{'authorId': '2053719228', 'name': 'E. M. Tan'},
#   {'authorId': '2107206018', 'name': 'A. Cohen'},
#   {'authorId': '7448495', 'name': 'J. Fries'},
#   {'authorId': '1697736', 'name': 'A. Masi'},
#   {'authorId': '35198948', 'name': 'D. McShane'},
#   {'authorId': '3839149', 'name': 'N. Rothfield'},
#   {'authorId': '9512460', 'name': 'J. Schaller'},
#   {'authorId': '4916976', 'name': 'N. Talal'},
#   {'authorId': '144776733', 'name': 'R. Winchester'}]}

# %%
[paper['venue'] for paper in results['data']]
# Out:
# ['Italian National Conference on Sensors',
#  'Nature Machine Intelligence',
#  '2023 IEEE International Conference on Integrated Circuits and Communication Systems (ICICACS)',
#  'Progress in Biomedical Engineering',
#  'Int. J. Intell. Networks',
#  'Deep Learning, Machine Learning and IoT in Biomedical and Health Informatics',
#  'INTERANTIONAL JOURNAL OF SCIENTIFIC RESEARCH IN ENGINEERING AND MANAGEMENT',
#  'Current Genomics',
#  'IEEE International Conference on Healthcare Informatics',
#  'Intelligent Systems Reference Library',
#  'Encyclopedia',
#  'International journal  of research and innovation in applied science',
#  'BMJ Innovations',
#  '2018 Second International Conference on Electronics, Communication and Aerospace Technology (ICECA)',
#  'Nature Network Boston',
#  'arXiv.org',
#  'Smart Manufacturing - When Artificial Intelligence Meets the Internet of Things',
#  'Journal of Healthcare Leadership',
#  '2022 1st IEEE International Conference on Industrial Electronics: Developments & Applications (ICIDeA)',
#  'Frontiers in Digital Health',
#  'IEEE Transactions on Emerging Topics in Computing',
#  '',
#  '2022 6th International Conference on Trends in Electronics and Informatics (ICOEI)',
#  'Machine Learning and the Internet of Medical Things in Healthcare',
#  'Annual International Computer Software and Applications Conference',
#  'IEEE journal of biomedical and health informatics',
#  'Intelligent Medicine',
#  '2021 Innovations in Intelligent Systems and Applications Conference (ASYU)',
#  'Technical Advancements of Machine Learning in Healthcare',
#  '2021 3rd International Conference on Advances in Computing, Communication Control and Networking (ICAC3N)',
#  'International Journal of Sensors Wireless Communications and Control',
#  'Archives of Computational Methods in Engineering',
#  'AI Innovation in Medical Imaging Diagnostics',
#  'Frontiers in Digital Health',
#  'British Journal of Healthcare Management',
#  '2019 International Conference on Deep Learning and Machine Learning in Emerging Applications (Deep-ML)',
#  'Quality Assurance in the Era of Individualized Medicine',
#  'Pushing the Boundaries: Frontiers in Impactful OR/OM Research',
#  'Nature Machine Intelligence',
#  'Artificial Intelligence in Medical Imaging',
#  'Machine Learning in Healthcare Informatics',
#  'Critical reviews in clinical laboratory sciences',
#  'Machine Learning in Healthcare Informatics',
#  'IEEE Access',
#  '',
#  'AIMS Public Health',
#  'Sustainability',
#  'PROTEOMICS - Clinical Applications',
#  'Computational Intelligence for Machine Learning and Healthcare Informatics',
#  'IEEE Access',
#  'IEEE Internet of Things Journal',
#  'Journal of Electrical Systems and Information Technology',
#  'Studies in Engineering and Technology',
#  'Bioengineering',
#  'SpringerBriefs in Applied Sciences and Technology',
#  'Ethics and Information Technology',
#  'Electronics',
#  'Ai & Society',
#  'Healthcare',
#  'Knee Surgery, Sports Traumatology, Arthroscopy',
#  'International Journal of Intelligent Systems',
#  'PLOS Digital Health',
#  'Infection control and hospital epidemiology',
#  'Current Research in Biotechnology',
#  'Diagnostics',
#  'Network Modeling Analysis in Health Informatics and Bioinformatics',
#  'Network Modeling Analysis in Health Informatics and Bioinformatics',
#  'Frontiers in Artificial Intelligence',
#  'WIREs Data Mining Knowl. Discov.',
#  'Annals of Thoracic Surgery',
#  'IEEE Access',
#  'Journal of Healthcare Engineering',
#  'Journal of Healthcare Engineering',
#  'Nature Biomedical Engineering',
#  'Journal of Healthcare Engineering',
#  'Current Directions in Biomedical Engineering',
#  'Secur. Commun. Networks',
#  'BMJ Health & Care Informatics',
#  'Healthcare',
#  'Soft Computing - A Fusion of Foundations, Methodologies and Applications',
#  'Royal Society Open Science',
#  '',
#  'Panhellenic Conference on Informatics',
#  'American Journal of Bioethics',
#  'npj Digital Medicine',
#  'IEEE International Conference on Tools with Artificial Intelligence',
#  'Hybrid Artificial Intelligence and IoT in Healthcare',
#  'International Journal of Reliable and Quality E-Healthcare',
#  'Nature Biomedical Engineering',
#  'Journal of Healthcare Engineering',
#  'BMC Medical Informatics and Decision Making',
#  'Antimicrobial Stewardship and Healthcare Epidemiology',
#  'Nature Biomedical Engineering',
#  'IEEE Access',
#  'IEEE Reviews in Biomedical Engineering',
#  'J. Am. Medical Informatics Assoc.',
#  'Future Internet',
#  'Italian National Conference on Sensors',
#  'Antimicrobial Stewardship and Healthcare Epidemiology',
#  'Journal on spesial topics in mobile networks and applications']

# %%
os.environ['SEMANTIC_SCHOLAR_API_KEY']
# Out:
# 'JbDRuaZkji5Sca4LmFHCF5xSXzkM3BoR7pyeeB8b'

# %%
response = requests

# %%
os.environ

# %%
import requests
import xml.etree.ElementTree as ET
import json

def get_journal_metrics(issn):
    """
    Retrieves the SJR and SNIP metrics for a journal given its ISSN using the 
    Elsevier Serial Title API.

    Args:
      issn: The ISSN of the journal.

    Returns:
      A dictionary containing the SJR and SNIP values for the journal, or None 
      if the API request fails.
    """

    # Replace with your actual Elsevier API key
    api_key = os.environ['ELSEVIER_API_KEY']
    
    # Construct the API request URL
    base_url = "https://api.elsevier.com/content/serial/title"
    params = {
        "issn": issn,
        "field": "SJR,SNIP",
        "view": "STANDARD",
        "apiKey": api_key,
    }

    try:
        # Send the API request
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes

        # Parse the JSON response
        data = json.loads(response.content)

        # Extract SJR and SNIP values
        entry = data['serial-metadata-response']['entry'][0]
        sjr = {sjr['@year']: sjr['$'] for sjr in entry['SJRList']['SJR']}
        snip = {snip['@year']: snip['$'] for snip in entry['SNIPList']['SNIP']}

        return {
            "SJR": sjr,
            "SNIP": snip
        }

    except requests.exceptions.RequestException as e:
        print(f"API request failed: {e}")
        return None

# Example usage
issn = "0028-0836"  # Example ISSN
metrics = get_journal_metrics(issn)

if metrics:
    print(f"Metrics for ISSN {issn}:")
    print(f"SJR: {metrics['SJR']}")
    print(f"SNIP: {metrics['SNIP']}")
# Out:
# Metrics for ISSN 0028-0836:
# SJR: {'2023': '18.509'}
# SNIP: {'2023': '10.01'}

# %%
import pandas as pd
journals_df = pd.read_csv("journals/scimagojr 2023.csv", sep=";")
journals_df
# Out:
#         Rank     Sourceid                                              Title  \
# 0          1        28773                 Ca-A Cancer Journal for Clinicians
# 1          2  19300156903         Foundations and Trends in Machine Learning
# 2          3        20315              Nature Reviews Molecular Cell Biology
# 3          4        29431                     Quarterly Journal of Economics
# 4          5        12464                              Nature Reviews Cancer
# ...      ...          ...                                                ...
# 29160  29161       145515   Waves in Random and Complex Media (discontinued)
# 29161  29162        17543  Wireless Communications and Mobile Computing (...
# 29162  29163  21100874917     World Journal of Clinical Cases (discontinued)
# 29163  29164  21100897940                                                WSQ
# 29164  29165  21101142703                                           Yuridika
#
#           Type                Issn      SJR SJR Best Quartile  H index  \
# 0      journal  15424863, 00079235  106,094                Q1      211
# 1      journal  19358245, 19358237   37,044                Q1       39
# 2      journal  14710072, 14710080   35,910                Q1      508
# 3      journal  00335533, 15314650   30,448                Q1      306
# 4      journal  1474175X, 14741768   26,837                Q1      505
# ...        ...                 ...      ...               ...      ...
# 29160  journal  17455049, 17455030      NaN                 -       61
# 29161  journal  15308677, 15308669      NaN                 -       81
# 29162  journal            23078960      NaN                 -       30
# 29163  journal  19341520, 07321562      NaN                 -        8
# 29164  journal  0215840X, 25283103      NaN                 -        2
#
#        Total Docs. (2023)  Total Docs. (3years)  ...  Ref. / Doc.  %Female  \
# 0                      49                   124  ...        98,86    43,95
# 1                       3                    13  ...       299,00    27,78
# 2                     123                   336  ...        93,19    29,41
# 3                      47                   136  ...        77,55    26,67
# 4                     105                   304  ...       102,90    44,33
# ...                   ...                   ...  ...          ...      ...
# 29160                  44                  1397  ...        40,59    20,54
# 29161                 145                  4066  ...        31,90    29,40
# 29162                 106                  3584  ...        37,36    40,00
# 29163                  34                     0  ...        11,79    75,00
# 29164                  36                     0  ...        28,94    41,67
#
#        Overton SDG         Country            Region  \
# 0            2  35   United States  Northern America
# 1            0   0   United States  Northern America
# 2            1  20  United Kingdom    Western Europe
# 3           35  22  United Kingdom    Western Europe
# 4            1  59  United Kingdom    Western Europe
# ...        ...  ..             ...               ...
# 29160        0   2  United Kingdom    Western Europe
# 29161        0  24  United Kingdom    Western Europe
# 29162        1  44           China    Asiatic Region
# 29163        0   3   United States  Northern America
# 29164        0  18       Indonesia    Asiatic Region
#
#                          Publisher   Coverage  \
# 0                  Wiley-Blackwell  1950-2023
# 1               Now Publishers Inc  2008-2023
# 2          Nature Publishing Group  2000-2023
# 3          Oxford University Press  1886-2023
# 4          Nature Publishing Group  2001-2023
# ...                            ...        ...
# 29160      Taylor and Francis Ltd.  2005-2023
# 29161              Hindawi Limited  2001-2023
# 29162  Baishideng Publishing Group  2018-2023
# 29163       Feminist Press at CUNY  2018-2019
# 29164         Airlangga University       2023
#
#                                               Categories  \
# 0                         Hematology (Q1); Oncology (Q1)
# 1      Artificial Intelligence (Q1); Human-Computer I...
# 2              Cell Biology (Q1); Molecular Biology (Q1)
# 3                        Economics and Econometrics (Q1)
# 4                    Cancer Research (Q1); Oncology (Q1)
# ...                                                  ...
# 29160  Engineering (miscellaneous); Physics and Astro...
# 29161  Computer Networks and Communications; Electric...
# 29162                           Medicine (miscellaneous)
# 29163                                     Gender Studies
# 29164                                                Law
#
#                                                    Areas
# 0                                               Medicine
# 1                                       Computer Science
# 2           Biochemistry, Genetics and Molecular Biology
# 3                    Economics, Econometrics and Finance
# 4      Biochemistry, Genetics and Molecular Biology; ...
# ...                                                  ...
# 29160                 Engineering; Physics and Astronomy
# 29161                      Computer Science; Engineering
# 29162                                           Medicine
# 29163                                    Social Sciences
# 29164                                    Social Sciences
#
# [29165 rows x 24 columns]

# %%
journals_df = journals_df[['Sourceid', 'Title', 'Type', 'Issn', 'SJR', 'SJR Best Quartile', 'H index']]

# %%
journals_df[['Issn1', 'Issn2']] = journals_df['Issn'].str.split(", ", expand=True)
# Out:
# /var/folders/dv/lndb9rrs2kv2v5g8cyfyx0wr0000gn/T/ipykernel_52392/995896962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   journals_df[['Issn1', 'Issn2']] = journals_df['Issn'].str.split(", ", expand=True)
# /var/folders/dv/lndb9rrs2kv2v5g8cyfyx0wr0000gn/T/ipykernel_52392/995896962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   journals_df[['Issn1', 'Issn2']] = journals_df['Issn'].str.split(", ", expand=True)

# %%
journals_df['SJR'] = journals_df['SJR'].str.replace(',', '.').astype(float)
# Out:
# /var/folders/dv/lndb9rrs2kv2v5g8cyfyx0wr0000gn/T/ipykernel_52392/18759599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   journals_df['SJR'] = journals_df['SJR'].str.replace(',', '.').astype(float)

# %%
journals_df
# Out:
#           Sourceid                                              Title  \
# 0            28773                 Ca-A Cancer Journal for Clinicians
# 1      19300156903         Foundations and Trends in Machine Learning
# 2            20315              Nature Reviews Molecular Cell Biology
# 3            29431                     Quarterly Journal of Economics
# 4            12464                              Nature Reviews Cancer
# ...            ...                                                ...
# 29160       145515   Waves in Random and Complex Media (discontinued)
# 29161        17543  Wireless Communications and Mobile Computing (...
# 29162  21100874917     World Journal of Clinical Cases (discontinued)
# 29163  21100897940                                                WSQ
# 29164  21101142703                                           Yuridika
#
#           Type                Issn      SJR SJR Best Quartile  H index  \
# 0      journal  15424863, 00079235  106.094                Q1      211
# 1      journal  19358245, 19358237   37.044                Q1       39
# 2      journal  14710072, 14710080   35.910                Q1      508
# 3      journal  00335533, 15314650   30.448                Q1      306
# 4      journal  1474175X, 14741768   26.837                Q1      505
# ...        ...                 ...      ...               ...      ...
# 29160  journal  17455049, 17455030      NaN                 -       61
# 29161  journal  15308677, 15308669      NaN                 -       81
# 29162  journal            23078960      NaN                 -       30
# 29163  journal  19341520, 07321562      NaN                 -        8
# 29164  journal  0215840X, 25283103      NaN                 -        2
#
#           Issn1     Issn2
# 0      15424863  00079235
# 1      19358245  19358237
# 2      14710072  14710080
# 3      00335533  15314650
# 4      1474175X  14741768
# ...         ...       ...
# 29160  17455049  17455030
# 29161  15308677  15308669
# 29162  23078960      None
# 29163  19341520  07321562
# 29164  0215840X  25283103
#
# [29165 rows x 9 columns]

# %%
len(results['data'])
# Out:
# 100

# %%
journals_df.to_csv("journals_df.csv")

# %%
journals_df = pd.read_csv("journals_df.csv", index_col=0)
journals_df
# Out:
#           Sourceid                                              Title  \
# 0            28773                 Ca-A Cancer Journal for Clinicians
# 1      19300156903         Foundations and Trends in Machine Learning
# 2            20315              Nature Reviews Molecular Cell Biology
# 3            29431                     Quarterly Journal of Economics
# 4            12464                              Nature Reviews Cancer
# ...            ...                                                ...
# 29160       145515   Waves in Random and Complex Media (discontinued)
# 29161        17543  Wireless Communications and Mobile Computing (...
# 29162  21100874917     World Journal of Clinical Cases (discontinued)
# 29163  21100897940                                                WSQ
# 29164  21101142703                                           Yuridika
#
#           Type                Issn      SJR SJR Best Quartile  H index  \
# 0      journal  15424863, 00079235  106.094                Q1      211
# 1      journal  19358245, 19358237   37.044                Q1       39
# 2      journal  14710072, 14710080   35.910                Q1      508
# 3      journal  00335533, 15314650   30.448                Q1      306
# 4      journal  1474175X, 14741768   26.837                Q1      505
# ...        ...                 ...      ...               ...      ...
# 29160  journal  17455049, 17455030      NaN                 -       61
# 29161  journal  15308677, 15308669      NaN                 -       81
# 29162  journal            23078960      NaN                 -       30
# 29163  journal  19341520, 07321562      NaN                 -        8
# 29164  journal  0215840X, 25283103      NaN                 -        2
#
#           Issn1     Issn2
# 0      15424863  00079235
# 1      19358245  19358237
# 2      14710072  14710080
# 3      00335533  15314650
# 4      1474175X  14741768
# ...         ...       ...
# 29160  17455049  17455030
# 29161  15308677  15308669
# 29162  23078960       NaN
# 29163  19341520  07321562
# 29164  0215840X  25283103
#
# [29165 rows x 9 columns]

# %%
filtered_results = []

for paper in results['data']:
    try:
        journal = paper['publicationVenue']['name']
        issn = paper['publicationVenue']['issn']
        # print(journal)
        issn_reformat = issn.replace("-", "")
        # print(issn_reformat)
        matching_rows = journals_df[(journals_df['Issn1'] == issn_reformat) | 
                            (journals_df['Issn2'] == issn_reformat)]
        
        if matching_rows.shape[0] > 0:
            SJR = matching_rows.iloc[0]['SJR']
            H_index = matching_rows.iloc[0]['H index']
            # display(matching_rows)
            paper['publicationVenue']['SJR'] = SJR
            paper['publicationVenue']['H_Index'] = H_index
            if SJR > 1.0:
                filtered_results.append(paper)
    
    except Exception as e:
        print("ERROR: ", e)

len(filtered_results)
# Out:
# ERROR:  'NoneType' object is not subscriptable
# ERROR:  'NoneType' object is not subscriptable
# 72

# %%
# Out:
# 84
